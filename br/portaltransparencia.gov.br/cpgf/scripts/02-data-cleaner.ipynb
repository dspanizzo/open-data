# %%
import os
import codecs
from datetime import datetime

# %%
def encode_to_utf8(**kwargs):
    """
    Funcao para padronizar a codificacao dos arquivos originais em UTF-8.
    Facilita a futura leitura dos arquivos e elimina caracteres desconhecidos.
    
    Args:
        original_encode(str): Codificacao original do arquivo.
                              Ex.: 'cp1252'
        in_data_path(str): Caminho completo para acesso ao arquivo original.
                           Ex.: '..\data\01-collected\2012_Funcoes.csv'
        out_data_path(str): Caminho completo para escrita do arquivo codificado
                            em UTF-8.
                            Ex.: '..\data\02-cleaned\2012_Funcoes.csv'
    """
    
    # Log: Mensagem de inicio da codificacao
    print(str(datetime.now()) + ': Inicio da codificacao do arquivo ' + kwargs['in_data_path'])
    
    # Le arquivo na codificacao original
    with codecs.open(kwargs['in_data_path'], 'rb', encoding = kwargs['original_encode'], errors = 'replace') as file:
        
        # Substitui os caracteres desconhecidos por interrogacao
        lines = file.read().replace('\x1a', '?')

    # Escreve o arquivo codificado em UTF-8
    with codecs.open(kwargs['out_data_path'], 'w', encoding = 'utf-8') as file:
        file.write(lines)
    
    # Log: Mensagem de termino da codificacao
    print(str(datetime.now()) + ': Fim da codificacao do arquivo '+ kwargs['out_data_path'])

# %%
def clean_files():
    """
    Funcao para limpar os arquivos coletados, codificando em UTF-8 e elimando caracteres desconhecidos.
    """
    
    # Prepara o dicionario de variaveis (kwargs = keyworded arguments)
    kwargs = {}
    
    # Diretorio de armazenamento dos arquivos originais
    kwargs['in_data_dir'] = '..\\data\\01-collected'
    
    # Diretorio de armazenamento dos arquivos tratados
    kwargs['out_data_dir'] = '..\\data\\02-cleaned'
    
    # Codificacao dos arquivos originais
    kwargs['original_encode'] = 'latin-1'

    # Lista dos arquivos originais 
    kwargs['data_files'] = os.listdir(kwargs['in_data_dir'])
    
    # Log: Mensagem de inicio do processo 
    print(str(datetime.now()) + ': Limpeza dos arquivos iniciada.')

    # Para cada arquivo na lista de arquivos originais
    for file in kwargs['data_files']:

        # Define o caminho completo de acesso e escrita dos arquivos
        kwargs['data_file'] = file
        kwargs['in_data_path'] = os.path.join(kwargs['in_data_dir'], kwargs['data_file'])
        kwargs['out_data_path'] = os.path.join(kwargs['out_data_dir'], kwargs['data_file'])
        
        # Codifica o arquivo original em UTF-8
        encode_to_utf8(**kwargs)
      
    # Log: Mensagem de finalizacao do processo
    print(str(datetime.now()) + ': Limpeza dos arquivos finalizada.')

# %%
def main():
    """
    Limpa os dados de Cartao de Pagamento do Governo Federal (CPGF)
    Origem: Portal da Transparencia
    """
        
    ### Limpa os arquivos
    clean_files()

if __name__ == '__main__':
    main()
# Out:
# 2019-08-20 07:28:18.631102: Enviando 201301_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.631102: Inicio da codificacao do arquivo ..\data\01-collected\201301_CPGF.csv
# 2019-08-20 07:28:18.653559: Fim da codificacao do arquivo ..\data\02-cleaned\201301_CPGF.csv
# 2019-08-20 07:28:18.654171: Enviando 201302_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.654171: Inicio da codificacao do arquivo ..\data\01-collected\201302_CPGF.csv
# 2019-08-20 07:28:18.659192: Fim da codificacao do arquivo ..\data\02-cleaned\201302_CPGF.csv
# 2019-08-20 07:28:18.659468: Enviando 201303_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.659468: Inicio da codificacao do arquivo ..\data\01-collected\201303_CPGF.csv
# 2019-08-20 07:28:18.671479: Fim da codificacao do arquivo ..\data\02-cleaned\201303_CPGF.csv
# 2019-08-20 07:28:18.672226: Enviando 201304_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.672226: Inicio da codificacao do arquivo ..\data\01-collected\201304_CPGF.csv
# 2019-08-20 07:28:18.688080: Fim da codificacao do arquivo ..\data\02-cleaned\201304_CPGF.csv
# 2019-08-20 07:28:18.689077: Enviando 201305_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.689077: Inicio da codificacao do arquivo ..\data\01-collected\201305_CPGF.csv
# 2019-08-20 07:28:18.707029: Fim da codificacao do arquivo ..\data\02-cleaned\201305_CPGF.csv
# 2019-08-20 07:28:18.708029: Enviando 201306_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.708029: Inicio da codificacao do arquivo ..\data\01-collected\201306_CPGF.csv
# 2019-08-20 07:28:18.722987: Fim da codificacao do arquivo ..\data\02-cleaned\201306_CPGF.csv
# 2019-08-20 07:28:18.723984: Enviando 201307_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.723984: Inicio da codificacao do arquivo ..\data\01-collected\201307_CPGF.csv
# 2019-08-20 07:28:18.740939: Fim da codificacao do arquivo ..\data\02-cleaned\201307_CPGF.csv
# 2019-08-20 07:28:18.741946: Enviando 201308_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.741946: Inicio da codificacao do arquivo ..\data\01-collected\201308_CPGF.csv
# 2019-08-20 07:28:18.759888: Fim da codificacao do arquivo ..\data\02-cleaned\201308_CPGF.csv
# 2019-08-20 07:28:18.760705: Enviando 201309_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.760705: Inicio da codificacao do arquivo ..\data\01-collected\201309_CPGF.csv
# 2019-08-20 07:28:18.775845: Fim da codificacao do arquivo ..\data\02-cleaned\201309_CPGF.csv
# 2019-08-20 07:28:18.776843: Enviando 201310_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.776843: Inicio da codificacao do arquivo ..\data\01-collected\201310_CPGF.csv
# 2019-08-20 07:28:18.793833: Fim da codificacao do arquivo ..\data\02-cleaned\201310_CPGF.csv
# 2019-08-20 07:28:18.794122: Enviando 201311_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.794122: Inicio da codificacao do arquivo ..\data\01-collected\201311_CPGF.csv
# 2019-08-20 07:28:18.811949: Fim da codificacao do arquivo ..\data\02-cleaned\201311_CPGF.csv
# 2019-08-20 07:28:18.812747: Enviando 201312_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.812747: Inicio da codificacao do arquivo ..\data\01-collected\201312_CPGF.csv
# 2019-08-20 07:28:18.829736: Fim da codificacao do arquivo ..\data\02-cleaned\201312_CPGF.csv
# 2019-08-20 07:28:18.830699: Enviando 201401_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.830699: Inicio da codificacao do arquivo ..\data\01-collected\201401_CPGF.csv
# 2019-08-20 07:28:18.845768: Fim da codificacao do arquivo ..\data\02-cleaned\201401_CPGF.csv
# 2019-08-20 07:28:18.846205: Enviando 201402_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.846205: Inicio da codificacao do arquivo ..\data\01-collected\201402_CPGF.csv
# 2019-08-20 07:28:18.851830: Fim da codificacao do arquivo ..\data\02-cleaned\201402_CPGF.csv
# 2019-08-20 07:28:18.851830: Enviando 201403_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.851830: Inicio da codificacao do arquivo ..\data\01-collected\201403_CPGF.csv
# 2019-08-20 07:28:18.862800: Fim da codificacao do arquivo ..\data\02-cleaned\201403_CPGF.csv
# 2019-08-20 07:28:18.863498: Enviando 201404_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.863498: Inicio da codificacao do arquivo ..\data\01-collected\201404_CPGF.csv
# 2019-08-20 07:28:18.876763: Fim da codificacao do arquivo ..\data\02-cleaned\201404_CPGF.csv
# 2019-08-20 07:28:18.876763: Enviando 201405_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.877767: Inicio da codificacao do arquivo ..\data\01-collected\201405_CPGF.csv
# 2019-08-20 07:28:18.891723: Fim da codificacao do arquivo ..\data\02-cleaned\201405_CPGF.csv
# 2019-08-20 07:28:18.892816: Enviando 201406_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.892816: Inicio da codificacao do arquivo ..\data\01-collected\201406_CPGF.csv
# 2019-08-20 07:28:18.913664: Fim da codificacao do arquivo ..\data\02-cleaned\201406_CPGF.csv
# 2019-08-20 07:28:18.914661: Enviando 201407_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.914661: Inicio da codificacao do arquivo ..\data\01-collected\201407_CPGF.csv
# 2019-08-20 07:28:18.929797: Fim da codificacao do arquivo ..\data\02-cleaned\201407_CPGF.csv
# 2019-08-20 07:28:18.931416: Enviando 201408_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.931416: Inicio da codificacao do arquivo ..\data\01-collected\201408_CPGF.csv
# 2019-08-20 07:28:18.944709: Fim da codificacao do arquivo ..\data\02-cleaned\201408_CPGF.csv
# 2019-08-20 07:28:18.946168: Enviando 201409_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.946168: Inicio da codificacao do arquivo ..\data\01-collected\201409_CPGF.csv
# 2019-08-20 07:28:18.961662: Fim da codificacao do arquivo ..\data\02-cleaned\201409_CPGF.csv
# 2019-08-20 07:28:18.962636: Enviando 201410_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.962660: Inicio da codificacao do arquivo ..\data\01-collected\201410_CPGF.csv
# 2019-08-20 07:28:18.977623: Fim da codificacao do arquivo ..\data\02-cleaned\201410_CPGF.csv
# 2019-08-20 07:28:18.978791: Enviando 201411_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.978791: Inicio da codificacao do arquivo ..\data\01-collected\201411_CPGF.csv
# 2019-08-20 07:28:18.994577: Fim da codificacao do arquivo ..\data\02-cleaned\201411_CPGF.csv
# 2019-08-20 07:28:18.996334: Enviando 201412_CPGF.csv para limpeza.
# 2019-08-20 07:28:18.996570: Inicio da codificacao do arquivo ..\data\01-collected\201412_CPGF.csv
# 2019-08-20 07:28:19.013525: Fim da codificacao do arquivo ..\data\02-cleaned\201412_CPGF.csv
# 2019-08-20 07:28:19.014522: Enviando 201501_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.014522: Inicio da codificacao do arquivo ..\data\01-collected\201501_CPGF.csv
# 2019-08-20 07:28:19.028487: Fim da codificacao do arquivo ..\data\02-cleaned\201501_CPGF.csv
# 2019-08-20 07:28:19.029299: Enviando 201502_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.029299: Inicio da codificacao do arquivo ..\data\01-collected\201502_CPGF.csv
# 2019-08-20 07:28:19.032944: Fim da codificacao do arquivo ..\data\02-cleaned\201502_CPGF.csv
# 2019-08-20 07:28:19.032944: Enviando 201503_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.032944: Inicio da codificacao do arquivo ..\data\01-collected\201503_CPGF.csv
# 2019-08-20 07:28:19.054530: Fim da codificacao do arquivo ..\data\02-cleaned\201503_CPGF.csv
# 2019-08-20 07:28:19.055413: Enviando 201504_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.055413: Inicio da codificacao do arquivo ..\data\01-collected\201504_CPGF.csv
# 2019-08-20 07:28:19.070716: Fim da codificacao do arquivo ..\data\02-cleaned\201504_CPGF.csv
# 2019-08-20 07:28:19.071371: Enviando 201505_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.071371: Inicio da codificacao do arquivo ..\data\01-collected\201505_CPGF.csv
# 2019-08-20 07:28:19.086329: Fim da codificacao do arquivo ..\data\02-cleaned\201505_CPGF.csv
# 2019-08-20 07:28:19.087873: Enviando 201506_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.087873: Inicio da codificacao do arquivo ..\data\01-collected\201506_CPGF.csv
# 2019-08-20 07:28:19.101289: Fim da codificacao do arquivo ..\data\02-cleaned\201506_CPGF.csv
# 2019-08-20 07:28:19.102439: Enviando 201507_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.102439: Inicio da codificacao do arquivo ..\data\01-collected\201507_CPGF.csv
# 2019-08-20 07:28:19.116249: Fim da codificacao do arquivo ..\data\02-cleaned\201507_CPGF.csv
# 2019-08-20 07:28:19.117895: Enviando 201508_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.117895: Inicio da codificacao do arquivo ..\data\01-collected\201508_CPGF.csv
# 2019-08-20 07:28:19.131209: Fim da codificacao do arquivo ..\data\02-cleaned\201508_CPGF.csv
# 2019-08-20 07:28:19.132209: Enviando 201509_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.132209: Inicio da codificacao do arquivo ..\data\01-collected\201509_CPGF.csv
# 2019-08-20 07:28:19.150827: Fim da codificacao do arquivo ..\data\02-cleaned\201509_CPGF.csv
# 2019-08-20 07:28:19.151156: Enviando 201510_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.151156: Inicio da codificacao do arquivo ..\data\01-collected\201510_CPGF.csv
# 2019-08-20 07:28:19.165119: Fim da codificacao do arquivo ..\data\02-cleaned\201510_CPGF.csv
# 2019-08-20 07:28:19.166463: Enviando 201511_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.167114: Inicio da codificacao do arquivo ..\data\01-collected\201511_CPGF.csv
# 2019-08-20 07:28:19.184089: Fim da codificacao do arquivo ..\data\02-cleaned\201511_CPGF.csv
# 2019-08-20 07:28:19.185226: Enviando 201512_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.185226: Inicio da codificacao do arquivo ..\data\01-collected\201512_CPGF.csv
# 2019-08-20 07:28:19.201025: Fim da codificacao do arquivo ..\data\02-cleaned\201512_CPGF.csv
# 2019-08-20 07:28:19.202077: Enviando 201601_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.202077: Inicio da codificacao do arquivo ..\data\01-collected\201601_CPGF.csv
# 2019-08-20 07:28:19.215022: Fim da codificacao do arquivo ..\data\02-cleaned\201601_CPGF.csv
# 2019-08-20 07:28:19.215910: Enviando 201602_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.215910: Inicio da codificacao do arquivo ..\data\01-collected\201602_CPGF.csv
# 2019-08-20 07:28:19.219548: Fim da codificacao do arquivo ..\data\02-cleaned\201602_CPGF.csv
# 2019-08-20 07:28:19.219627: Enviando 201603_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.219627: Inicio da codificacao do arquivo ..\data\01-collected\201603_CPGF.csv
# 2019-08-20 07:28:19.238409: Fim da codificacao do arquivo ..\data\02-cleaned\201603_CPGF.csv
# 2019-08-20 07:28:19.238921: Enviando 201604_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.238921: Inicio da codificacao do arquivo ..\data\01-collected\201604_CPGF.csv
# 2019-08-20 07:28:19.253044: Fim da codificacao do arquivo ..\data\02-cleaned\201604_CPGF.csv
# 2019-08-20 07:28:19.254311: Enviando 201605_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.254311: Inicio da codificacao do arquivo ..\data\01-collected\201605_CPGF.csv
# 2019-08-20 07:28:19.268842: Fim da codificacao do arquivo ..\data\02-cleaned\201605_CPGF.csv
# 2019-08-20 07:28:19.270254: Enviando 201606_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.270254: Inicio da codificacao do arquivo ..\data\01-collected\201606_CPGF.csv
# 2019-08-20 07:28:19.283805: Fim da codificacao do arquivo ..\data\02-cleaned\201606_CPGF.csv
# 2019-08-20 07:28:19.285822: Enviando 201607_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.285822: Inicio da codificacao do arquivo ..\data\01-collected\201607_CPGF.csv
# 2019-08-20 07:28:19.301753: Fim da codificacao do arquivo ..\data\02-cleaned\201607_CPGF.csv
# 2019-08-20 07:28:19.303058: Enviando 201608_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.303058: Inicio da codificacao do arquivo ..\data\01-collected\201608_CPGF.csv
# 2019-08-20 07:28:19.315992: Fim da codificacao do arquivo ..\data\02-cleaned\201608_CPGF.csv
# 2019-08-20 07:28:19.316713: Enviando 201609_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.316713: Inicio da codificacao do arquivo ..\data\01-collected\201609_CPGF.csv
# 2019-08-20 07:28:19.330676: Fim da codificacao do arquivo ..\data\02-cleaned\201609_CPGF.csv
# 2019-08-20 07:28:19.331688: Enviando 201610_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.331688: Inicio da codificacao do arquivo ..\data\01-collected\201610_CPGF.csv
# 2019-08-20 07:28:19.345639: Fim da codificacao do arquivo ..\data\02-cleaned\201610_CPGF.csv
# 2019-08-20 07:28:19.347241: Enviando 201611_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.347241: Inicio da codificacao do arquivo ..\data\01-collected\201611_CPGF.csv
# 2019-08-20 07:28:19.360596: Fim da codificacao do arquivo ..\data\02-cleaned\201611_CPGF.csv
# 2019-08-20 07:28:19.360956: Enviando 201612_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.361321: Inicio da codificacao do arquivo ..\data\01-collected\201612_CPGF.csv
# 2019-08-20 07:28:19.377551: Fim da codificacao do arquivo ..\data\02-cleaned\201612_CPGF.csv
# 2019-08-20 07:28:19.379020: Enviando 201701_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.379020: Inicio da codificacao do arquivo ..\data\01-collected\201701_CPGF.csv
# 2019-08-20 07:28:19.390402: Fim da codificacao do arquivo ..\data\02-cleaned\201701_CPGF.csv
# 2019-08-20 07:28:19.390713: Enviando 201702_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.390713: Inicio da codificacao do arquivo ..\data\01-collected\201702_CPGF.csv
# 2019-08-20 07:28:19.394733: Fim da codificacao do arquivo ..\data\02-cleaned\201702_CPGF.csv
# 2019-08-20 07:28:19.394896: Enviando 201703_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.394896: Inicio da codificacao do arquivo ..\data\01-collected\201703_CPGF.csv
# 2019-08-20 07:28:19.403481: Fim da codificacao do arquivo ..\data\02-cleaned\201703_CPGF.csv
# 2019-08-20 07:28:19.404119: Enviando 201704_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.404119: Inicio da codificacao do arquivo ..\data\01-collected\201704_CPGF.csv
# 2019-08-20 07:28:19.415450: Fim da codificacao do arquivo ..\data\02-cleaned\201704_CPGF.csv
# 2019-08-20 07:28:19.416584: Enviando 201705_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.416584: Inicio da codificacao do arquivo ..\data\01-collected\201705_CPGF.csv
# 2019-08-20 07:28:19.427544: Fim da codificacao do arquivo ..\data\02-cleaned\201705_CPGF.csv
# 2019-08-20 07:28:19.428058: Enviando 201706_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.428506: Inicio da codificacao do arquivo ..\data\01-collected\201706_CPGF.csv
# 2019-08-20 07:28:19.440585: Fim da codificacao do arquivo ..\data\02-cleaned\201706_CPGF.csv
# 2019-08-20 07:28:19.441582: Enviando 201707_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.441582: Inicio da codificacao do arquivo ..\data\01-collected\201707_CPGF.csv
# 2019-08-20 07:28:19.456061: Fim da codificacao do arquivo ..\data\02-cleaned\201707_CPGF.csv
# 2019-08-20 07:28:19.457016: Enviando 201708_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.457016: Inicio da codificacao do arquivo ..\data\01-collected\201708_CPGF.csv
# 2019-08-20 07:28:19.483470: Fim da codificacao do arquivo ..\data\02-cleaned\201708_CPGF.csv
# 2019-08-20 07:28:19.484470: Enviando 201709_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.484470: Inicio da codificacao do arquivo ..\data\01-collected\201709_CPGF.csv
# 2019-08-20 07:28:19.504415: Fim da codificacao do arquivo ..\data\02-cleaned\201709_CPGF.csv
# 2019-08-20 07:28:19.506693: Enviando 201710_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.506693: Inicio da codificacao do arquivo ..\data\01-collected\201710_CPGF.csv
# 2019-08-20 07:28:19.521490: Fim da codificacao do arquivo ..\data\02-cleaned\201710_CPGF.csv
# 2019-08-20 07:28:19.522375: Enviando 201711_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.522375: Inicio da codificacao do arquivo ..\data\01-collected\201711_CPGF.csv
# 2019-08-20 07:28:19.541682: Fim da codificacao do arquivo ..\data\02-cleaned\201711_CPGF.csv
# 2019-08-20 07:28:19.543678: Enviando 201712_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.543678: Inicio da codificacao do arquivo ..\data\01-collected\201712_CPGF.csv
# 2019-08-20 07:28:19.565618: Fim da codificacao do arquivo ..\data\02-cleaned\201712_CPGF.csv
# 2019-08-20 07:28:19.567613: Enviando 201801_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.567613: Inicio da codificacao do arquivo ..\data\01-collected\201801_CPGF.csv
# 2019-08-20 07:28:19.582326: Fim da codificacao do arquivo ..\data\02-cleaned\201801_CPGF.csv
# 2019-08-20 07:28:19.583384: Enviando 201802_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.583384: Inicio da codificacao do arquivo ..\data\01-collected\201802_CPGF.csv
# 2019-08-20 07:28:19.589554: Fim da codificacao do arquivo ..\data\02-cleaned\201802_CPGF.csv
# 2019-08-20 07:28:19.590020: Enviando 201803_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.590020: Inicio da codificacao do arquivo ..\data\01-collected\201803_CPGF.csv
# 2019-08-20 07:28:19.600526: Fim da codificacao do arquivo ..\data\02-cleaned\201803_CPGF.csv
# 2019-08-20 07:28:19.600526: Enviando 201804_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.600526: Inicio da codificacao do arquivo ..\data\01-collected\201804_CPGF.csv
# 2019-08-20 07:28:19.616483: Fim da codificacao do arquivo ..\data\02-cleaned\201804_CPGF.csv
# 2019-08-20 07:28:19.617482: Enviando 201805_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.617482: Inicio da codificacao do arquivo ..\data\01-collected\201805_CPGF.csv
# 2019-08-20 07:28:19.631473: Fim da codificacao do arquivo ..\data\02-cleaned\201805_CPGF.csv
# 2019-08-20 07:28:19.632441: Enviando 201806_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.632441: Inicio da codificacao do arquivo ..\data\01-collected\201806_CPGF.csv
# 2019-08-20 07:28:19.648398: Fim da codificacao do arquivo ..\data\02-cleaned\201806_CPGF.csv
# 2019-08-20 07:28:19.649394: Enviando 201807_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.650392: Inicio da codificacao do arquivo ..\data\01-collected\201807_CPGF.csv
# 2019-08-20 07:28:19.664472: Fim da codificacao do arquivo ..\data\02-cleaned\201807_CPGF.csv
# 2019-08-20 07:28:19.664472: Enviando 201808_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.664472: Inicio da codificacao do arquivo ..\data\01-collected\201808_CPGF.csv
# 2019-08-20 07:28:19.684300: Fim da codificacao do arquivo ..\data\02-cleaned\201808_CPGF.csv
# 2019-08-20 07:28:19.685303: Enviando 201809_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.685303: Inicio da codificacao do arquivo ..\data\01-collected\201809_CPGF.csv
# 2019-08-20 07:28:19.700291: Fim da codificacao do arquivo ..\data\02-cleaned\201809_CPGF.csv
# 2019-08-20 07:28:19.701794: Enviando 201810_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.701896: Inicio da codificacao do arquivo ..\data\01-collected\201810_CPGF.csv
# 2019-08-20 07:28:19.717212: Fim da codificacao do arquivo ..\data\02-cleaned\201810_CPGF.csv
# 2019-08-20 07:28:19.718710: Enviando 201811_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.719043: Inicio da codificacao do arquivo ..\data\01-collected\201811_CPGF.csv
# 2019-08-20 07:28:19.735164: Fim da codificacao do arquivo ..\data\02-cleaned\201811_CPGF.csv
# 2019-08-20 07:28:19.736162: Enviando 201812_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.736162: Inicio da codificacao do arquivo ..\data\01-collected\201812_CPGF.csv
# 2019-08-20 07:28:19.758103: Fim da codificacao do arquivo ..\data\02-cleaned\201812_CPGF.csv
# 2019-08-20 07:28:19.759100: Enviando 201901_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.759100: Inicio da codificacao do arquivo ..\data\01-collected\201901_CPGF.csv
# 2019-08-20 07:28:19.773063: Fim da codificacao do arquivo ..\data\02-cleaned\201901_CPGF.csv
# 2019-08-20 07:28:19.774656: Enviando 201902_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.774656: Inicio da codificacao do arquivo ..\data\01-collected\201902_CPGF.csv
# 2019-08-20 07:28:19.780947: Fim da codificacao do arquivo ..\data\02-cleaned\201902_CPGF.csv
# 2019-08-20 07:28:19.781262: Enviando 201903_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.781262: Inicio da codificacao do arquivo ..\data\01-collected\201903_CPGF.csv
# 2019-08-20 07:28:19.793011: Fim da codificacao do arquivo ..\data\02-cleaned\201903_CPGF.csv
# 2019-08-20 07:28:19.794007: Enviando 201904_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.794007: Inicio da codificacao do arquivo ..\data\01-collected\201904_CPGF.csv
# 2019-08-20 07:28:19.804978: Fim da codificacao do arquivo ..\data\02-cleaned\201904_CPGF.csv
# 2019-08-20 07:28:19.805515: Enviando 201905_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.805515: Inicio da codificacao do arquivo ..\data\01-collected\201905_CPGF.csv
# 2019-08-20 07:28:19.817947: Fim da codificacao do arquivo ..\data\02-cleaned\201905_CPGF.csv
# 2019-08-20 07:28:19.818940: Enviando 201906_CPGF.csv para limpeza.
# 2019-08-20 07:28:19.818940: Inicio da codificacao do arquivo ..\data\01-collected\201906_CPGF.csv
# 2019-08-20 07:28:19.831585: Fim da codificacao do arquivo ..\data\02-cleaned\201906_CPGF.csv
# 2019-08-20 07:28:19.832362: Limpeza dos arquivos finalizada.
