# %%
import os
import codecs
from datetime import datetime

# %%
def join_lines(**kwargs):
    """
    Le o arquivo de entrada, caso alguma das linhas tenha quantidade de colunas diferente
    da do cabecalho, a linha seguinte e concatenada com a atual e escrita no arquivo de saida.
    """
    
    # Log: Mensagem de inicio da verificacao dos registros
    print(str(datetime.now()) + ': Verificando registros do arquivo ' + kwargs['data_file'] + ' .')
    
    # Le o arquivo de entrada
    with codecs.open(kwargs['in_data_path'], 'r', encoding = 'utf-8') as reader:
        
        # Prepara o arquivo de saida
        with codecs.open(kwargs['out_data_path'], 'w', encoding = 'utf-8') as writer:
            
            # Armazena o header
            header = reader.readline()
            
            # Conta a quantidade de colunas no header
            qt_columns = header.count('\";\"')
            
            # Contadores
            qt_lines = 0
            qt_joins = 0
            
            writer.write(header)
            
            for line in reader:
                
                if line.count('\";\"') != qt_columns:
                    qt_joins += 1
                    writer.write(line.replace("\r\n", "") + reader.readline())
                else:
                    qt_lines += 1
                    writer.write(line)
                    
    # Log: Resultado da verificacao dos registros
    print(str(datetime.now()) + ': Resultado: Normais = ' + str(qt_lines) + ' - Corrigidas = ' + str(qt_joins))

# %%
def organize_files():
    """
    Para cada arquivo de origem, e verificado se a quantidade de colunas de cada registros corresponde
    com a quantidade de colunas do cabecalho do arquivo.        
    """
    
    # Prepara o dicionario de variaveis (kwargs = keyworded arguments)
    kwargs = {}
    
    # Diretorio de armazenamento dos arquivos originais
    kwargs['in_data_dir'] = '..\\data\\02-cleaned'
    
    # Diretorio de armazenamento dos arquivos tratados
    kwargs['out_data_dir'] = '..\\data\\03-organized'
    
    # Lista dos arquivos originais 
    kwargs['data_files'] = os.listdir(kwargs['in_data_dir'])
    
    # Log: Mensagem de inicio do processo 
    print(str(datetime.now()) + ': Organizacao dos arquivos iniciada.')
    
    # Para cada arquivo na lista de arquivos originais
    for file in kwargs['data_files']:
        
        kwargs['data_file'] = file

        # Define o caminho completo de acesso e escrita dos arquivos
        kwargs['in_data_path'] = os.path.join(kwargs['in_data_dir'], kwargs['data_file'])
        kwargs['out_data_path'] = os.path.join(kwargs['out_data_dir'], kwargs['data_file'])
        
        # Log: Corrige registros com menos colunas que o esperado
        print(str(datetime.now()) + ': Enviando ' + kwargs['data_file'] + ' para organizacao.')
        join_lines(**kwargs)
      
    # Log: Mensagem de finalizacao do processo de limpeza
    print(str(datetime.now()) + ': Organizacao dos arquivos finalizada.')

# %%
def main():
    """
    Organiza os dados de Cartao de Pagamento do Governo Federal (CPGF)
    Origem: Portal da Transparencia
    """
    
    ### Organiza os arquivos
    organize_files()

if __name__ == '__main__':
    main()
# Out:
# 2019-08-21 07:50:06.356855: Organizacao dos arquivos iniciada.
# 2019-08-21 07:50:06.356855: Enviando 201301_CPGF.csv para organizacao.
# 2019-08-21 07:50:06.356855: Verificando registros do arquivo 201301_CPGF.csv .
# 2019-08-21 07:50:06.612344: Resultado: Normais = 17550 - Corrigidas = 0
# 2019-08-21 07:50:06.612344: Enviando 201302_CPGF.csv para organizacao.
# 2019-08-21 07:50:06.612344: Verificando registros do arquivo 201302_CPGF.csv .
# 2019-08-21 07:50:06.659217: Resultado: Normais = 3310 - Corrigidas = 0
# 2019-08-21 07:50:06.659217: Enviando 201303_CPGF.csv para organizacao.
# 2019-08-21 07:50:06.659217: Verificando registros do arquivo 201303_CPGF.csv .
# 2019-08-21 07:50:06.778941: Resultado: Normais = 9473 - Corrigidas = 0
# 2019-08-21 07:50:06.778941: Enviando 201304_CPGF.csv para organizacao.
# 2019-08-21 07:50:06.778941: Verificando registros do arquivo 201304_CPGF.csv .
# 2019-08-21 07:50:06.986345: Resultado: Normais = 16190 - Corrigidas = 0
# 2019-08-21 07:50:06.986345: Enviando 201305_CPGF.csv para organizacao.
# 2019-08-21 07:50:06.986345: Verificando registros do arquivo 201305_CPGF.csv .
# 2019-08-21 07:50:07.251154: Resultado: Normais = 19377 - Corrigidas = 0
# 2019-08-21 07:50:07.251392: Enviando 201306_CPGF.csv para organizacao.
# 2019-08-21 07:50:07.251450: Verificando registros do arquivo 201306_CPGF.csv .
# 2019-08-21 07:50:07.468094: Resultado: Normais = 15470 - Corrigidas = 0
# 2019-08-21 07:50:07.468094: Enviando 201307_CPGF.csv para organizacao.
# 2019-08-21 07:50:07.468094: Verificando registros do arquivo 201307_CPGF.csv .
# 2019-08-21 07:50:07.749304: Resultado: Normais = 18587 - Corrigidas = 0
# 2019-08-21 07:50:07.749304: Enviando 201308_CPGF.csv para organizacao.
# 2019-08-21 07:50:07.749304: Verificando registros do arquivo 201308_CPGF.csv .
# 2019-08-21 07:50:08.023505: Resultado: Normais = 18725 - Corrigidas = 0
# 2019-08-21 07:50:08.023505: Enviando 201309_CPGF.csv para organizacao.
# 2019-08-21 07:50:08.023505: Verificando registros do arquivo 201309_CPGF.csv .
# 2019-08-21 07:50:08.300766: Resultado: Normais = 17276 - Corrigidas = 0
# 2019-08-21 07:50:08.300766: Enviando 201310_CPGF.csv para organizacao.
# 2019-08-21 07:50:08.300766: Verificando registros do arquivo 201310_CPGF.csv .
# 2019-08-21 07:50:08.653823: Resultado: Normais = 18057 - Corrigidas = 0
# 2019-08-21 07:50:08.653823: Enviando 201311_CPGF.csv para organizacao.
# 2019-08-21 07:50:08.653823: Verificando registros do arquivo 201311_CPGF.csv .
# 2019-08-21 07:50:08.921337: Resultado: Normais = 18633 - Corrigidas = 0
# 2019-08-21 07:50:08.921533: Enviando 201312_CPGF.csv para organizacao.
# 2019-08-21 07:50:08.921533: Verificando registros do arquivo 201312_CPGF.csv .
# 2019-08-21 07:50:09.213739: Resultado: Normais = 18843 - Corrigidas = 0
# 2019-08-21 07:50:09.213865: Enviando 201401_CPGF.csv para organizacao.
# 2019-08-21 07:50:09.213865: Verificando registros do arquivo 201401_CPGF.csv .
# 2019-08-21 07:50:09.490000: Resultado: Normais = 14542 - Corrigidas = 0
# 2019-08-21 07:50:09.490998: Enviando 201402_CPGF.csv para organizacao.
# 2019-08-21 07:50:09.490998: Verificando registros do arquivo 201402_CPGF.csv .
# 2019-08-21 07:50:09.561808: Resultado: Normais = 2698 - Corrigidas = 0
# 2019-08-21 07:50:09.561808: Enviando 201403_CPGF.csv para organizacao.
# 2019-08-21 07:50:09.561808: Verificando registros do arquivo 201403_CPGF.csv .
# 2019-08-21 07:50:09.797179: Resultado: Normais = 10214 - Corrigidas = 0
# 2019-08-21 07:50:09.797179: Enviando 201404_CPGF.csv para organizacao.
# 2019-08-21 07:50:09.797179: Verificando registros do arquivo 201404_CPGF.csv .
# 2019-08-21 07:50:10.011316: Resultado: Normais = 13807 - Corrigidas = 0
# 2019-08-21 07:50:10.011720: Enviando 201405_CPGF.csv para organizacao.
# 2019-08-21 07:50:10.011783: Verificando registros do arquivo 201405_CPGF.csv .
# 2019-08-21 07:50:10.261937: Resultado: Normais = 15068 - Corrigidas = 0
# 2019-08-21 07:50:10.262936: Enviando 201406_CPGF.csv para organizacao.
# 2019-08-21 07:50:10.262936: Verificando registros do arquivo 201406_CPGF.csv .
# 2019-08-21 07:50:10.557736: Resultado: Normais = 16575 - Corrigidas = 0
# 2019-08-21 07:50:10.557905: Enviando 201407_CPGF.csv para organizacao.
# 2019-08-21 07:50:10.557905: Verificando registros do arquivo 201407_CPGF.csv .
# 2019-08-21 07:50:10.839102: Resultado: Normais = 17044 - Corrigidas = 0
# 2019-08-21 07:50:10.839102: Enviando 201408_CPGF.csv para organizacao.
# 2019-08-21 07:50:10.839102: Verificando registros do arquivo 201408_CPGF.csv .
# 2019-08-21 07:50:11.036574: Resultado: Normais = 14854 - Corrigidas = 0
# 2019-08-21 07:50:11.036574: Enviando 201409_CPGF.csv para organizacao.
# 2019-08-21 07:50:11.036574: Verificando registros do arquivo 201409_CPGF.csv .
# 2019-08-21 07:50:11.343753: Resultado: Normais = 16880 - Corrigidas = 0
# 2019-08-21 07:50:11.343753: Enviando 201410_CPGF.csv para organizacao.
# 2019-08-21 07:50:11.343753: Verificando registros do arquivo 201410_CPGF.csv .
# 2019-08-21 07:50:11.592090: Resultado: Normais = 16389 - Corrigidas = 0
# 2019-08-21 07:50:11.593090: Enviando 201411_CPGF.csv para organizacao.
# 2019-08-21 07:50:11.593090: Verificando registros do arquivo 201411_CPGF.csv .
# 2019-08-21 07:50:11.976129: Resultado: Normais = 18408 - Corrigidas = 0
# 2019-08-21 07:50:11.976129: Enviando 201412_CPGF.csv para organizacao.
# 2019-08-21 07:50:11.976129: Verificando registros do arquivo 201412_CPGF.csv .
# 2019-08-21 07:50:12.266359: Resultado: Normais = 19099 - Corrigidas = 0
# 2019-08-21 07:50:12.266359: Enviando 201501_CPGF.csv para organizacao.
# 2019-08-21 07:50:12.266359: Verificando registros do arquivo 201501_CPGF.csv .
# 2019-08-21 07:50:12.463317: Resultado: Normais = 13908 - Corrigidas = 0
# 2019-08-21 07:50:12.463317: Enviando 201502_CPGF.csv para organizacao.
# 2019-08-21 07:50:12.463317: Verificando registros do arquivo 201502_CPGF.csv .
# 2019-08-21 07:50:12.499730: Resultado: Normais = 1888 - Corrigidas = 0
# 2019-08-21 07:50:12.499730: Enviando 201503_CPGF.csv para organizacao.
# 2019-08-21 07:50:12.499730: Verificando registros do arquivo 201503_CPGF.csv .
# 2019-08-21 07:50:12.601457: Resultado: Normais = 7870 - Corrigidas = 0
# 2019-08-21 07:50:12.601457: Enviando 201504_CPGF.csv para organizacao.
# 2019-08-21 07:50:12.601457: Verificando registros do arquivo 201504_CPGF.csv .
# 2019-08-21 07:50:12.892260: Resultado: Normais = 14484 - Corrigidas = 0
# 2019-08-21 07:50:12.892260: Enviando 201505_CPGF.csv para organizacao.
# 2019-08-21 07:50:12.892260: Verificando registros do arquivo 201505_CPGF.csv .
# 2019-08-21 07:50:13.059856: Resultado: Normais = 12807 - Corrigidas = 0
# 2019-08-21 07:50:13.059856: Enviando 201506_CPGF.csv para organizacao.
# 2019-08-21 07:50:13.059856: Verificando registros do arquivo 201506_CPGF.csv .
# 2019-08-21 07:50:13.302246: Resultado: Normais = 14354 - Corrigidas = 0
# 2019-08-21 07:50:13.302246: Enviando 201507_CPGF.csv para organizacao.
# 2019-08-21 07:50:13.302246: Verificando registros do arquivo 201507_CPGF.csv .
# 2019-08-21 07:50:13.487749: Resultado: Normais = 14387 - Corrigidas = 0
# 2019-08-21 07:50:13.488747: Enviando 201508_CPGF.csv para organizacao.
# 2019-08-21 07:50:13.488747: Verificando registros do arquivo 201508_CPGF.csv .
# 2019-08-21 07:50:13.658292: Resultado: Normais = 13514 - Corrigidas = 0
# 2019-08-21 07:50:13.659291: Enviando 201509_CPGF.csv para organizacao.
# 2019-08-21 07:50:13.659291: Verificando registros do arquivo 201509_CPGF.csv .
# 2019-08-21 07:50:13.847787: Resultado: Normais = 13720 - Corrigidas = 0
# 2019-08-21 07:50:13.847787: Enviando 201510_CPGF.csv para organizacao.
# 2019-08-21 07:50:13.847787: Verificando registros do arquivo 201510_CPGF.csv .
# 2019-08-21 07:50:14.028338: Resultado: Normais = 13166 - Corrigidas = 0
# 2019-08-21 07:50:14.028338: Enviando 201511_CPGF.csv para organizacao.
# 2019-08-21 07:50:14.028338: Verificando registros do arquivo 201511_CPGF.csv .
# 2019-08-21 07:50:14.223336: Resultado: Normais = 14278 - Corrigidas = 0
# 2019-08-21 07:50:14.223336: Enviando 201512_CPGF.csv para organizacao.
# 2019-08-21 07:50:14.223336: Verificando registros do arquivo 201512_CPGF.csv .
# 2019-08-21 07:50:14.450176: Resultado: Normais = 15866 - Corrigidas = 0
# 2019-08-21 07:50:14.450176: Enviando 201601_CPGF.csv para organizacao.
# 2019-08-21 07:50:14.450176: Verificando registros do arquivo 201601_CPGF.csv .
# 2019-08-21 07:50:14.605210: Resultado: Normais = 12115 - Corrigidas = 0
# 2019-08-21 07:50:14.605210: Enviando 201602_CPGF.csv para organizacao.
# 2019-08-21 07:50:14.605210: Verificando registros do arquivo 201602_CPGF.csv .
# 2019-08-21 07:50:14.637903: Resultado: Normais = 1629 - Corrigidas = 0
# 2019-08-21 07:50:14.638301: Enviando 201603_CPGF.csv para organizacao.
# 2019-08-21 07:50:14.638301: Verificando registros do arquivo 201603_CPGF.csv .
# 2019-08-21 07:50:14.749005: Resultado: Normais = 6970 - Corrigidas = 0
# 2019-08-21 07:50:14.749005: Enviando 201604_CPGF.csv para organizacao.
# 2019-08-21 07:50:14.749005: Verificando registros do arquivo 201604_CPGF.csv .
# 2019-08-21 07:50:14.910606: Resultado: Normais = 13019 - Corrigidas = 0
# 2019-08-21 07:50:14.910606: Enviando 201605_CPGF.csv para organizacao.
# 2019-08-21 07:50:14.910606: Verificando registros do arquivo 201605_CPGF.csv .
# 2019-08-21 07:50:15.075166: Resultado: Normais = 12485 - Corrigidas = 0
# 2019-08-21 07:50:15.075166: Enviando 201606_CPGF.csv para organizacao.
# 2019-08-21 07:50:15.076130: Verificando registros do arquivo 201606_CPGF.csv .
# 2019-08-21 07:50:15.243716: Resultado: Normais = 13512 - Corrigidas = 0
# 2019-08-21 07:50:15.244512: Enviando 201607_CPGF.csv para organizacao.
# 2019-08-21 07:50:15.244545: Verificando registros do arquivo 201607_CPGF.csv .
# 2019-08-21 07:50:15.409240: Resultado: Normais = 13159 - Corrigidas = 0
# 2019-08-21 07:50:15.409240: Enviando 201608_CPGF.csv para organizacao.
# 2019-08-21 07:50:15.409240: Verificando registros do arquivo 201608_CPGF.csv .
# 2019-08-21 07:50:15.589250: Resultado: Normais = 13172 - Corrigidas = 0
# 2019-08-21 07:50:15.589504: Enviando 201609_CPGF.csv para organizacao.
# 2019-08-21 07:50:15.589504: Verificando registros do arquivo 201609_CPGF.csv .
# 2019-08-21 07:50:15.845108: Resultado: Normais = 14227 - Corrigidas = 0
# 2019-08-21 07:50:15.845108: Enviando 201610_CPGF.csv para organizacao.
# 2019-08-21 07:50:15.845108: Verificando registros do arquivo 201610_CPGF.csv .
# 2019-08-21 07:50:16.024659: Resultado: Normais = 12316 - Corrigidas = 0
# 2019-08-21 07:50:16.025506: Enviando 201611_CPGF.csv para organizacao.
# 2019-08-21 07:50:16.025506: Verificando registros do arquivo 201611_CPGF.csv .
# 2019-08-21 07:50:16.186225: Resultado: Normais = 12214 - Corrigidas = 0
# 2019-08-21 07:50:16.186225: Enviando 201612_CPGF.csv para organizacao.
# 2019-08-21 07:50:16.186225: Verificando registros do arquivo 201612_CPGF.csv .
# 2019-08-21 07:50:16.357923: Resultado: Normais = 13423 - Corrigidas = 0
# 2019-08-21 07:50:16.357923: Enviando 201701_CPGF.csv para organizacao.
# 2019-08-21 07:50:16.357923: Verificando registros do arquivo 201701_CPGF.csv .
# 2019-08-21 07:50:16.510480: Resultado: Normais = 10927 - Corrigidas = 0
# 2019-08-21 07:50:16.510480: Enviando 201702_CPGF.csv para organizacao.
# 2019-08-21 07:50:16.510480: Verificando registros do arquivo 201702_CPGF.csv .
# 2019-08-21 07:50:16.532421: Resultado: Normais = 1586 - Corrigidas = 0
# 2019-08-21 07:50:16.533418: Enviando 201703_CPGF.csv para organizacao.
# 2019-08-21 07:50:16.533544: Verificando registros do arquivo 201703_CPGF.csv .
# 2019-08-21 07:50:16.665069: Resultado: Normais = 7632 - Corrigidas = 0
# 2019-08-21 07:50:16.665069: Enviando 201704_CPGF.csv para organizacao.
# 2019-08-21 07:50:16.666065: Verificando registros do arquivo 201704_CPGF.csv .
# 2019-08-21 07:50:16.840598: Resultado: Normais = 11769 - Corrigidas = 0
# 2019-08-21 07:50:16.840598: Enviando 201705_CPGF.csv para organizacao.
# 2019-08-21 07:50:16.840598: Verificando registros do arquivo 201705_CPGF.csv .
# 2019-08-21 07:50:16.979257: Resultado: Normais = 10558 - Corrigidas = 0
# 2019-08-21 07:50:16.979257: Enviando 201706_CPGF.csv para organizacao.
# 2019-08-21 07:50:16.979257: Verificando registros do arquivo 201706_CPGF.csv .
# 2019-08-21 07:50:17.163953: Resultado: Normais = 12841 - Corrigidas = 0
# 2019-08-21 07:50:17.163953: Enviando 201707_CPGF.csv para organizacao.
# 2019-08-21 07:50:17.163953: Verificando registros do arquivo 201707_CPGF.csv .
# 2019-08-21 07:50:17.341258: Resultado: Normais = 12585 - Corrigidas = 0
# 2019-08-21 07:50:17.341258: Enviando 201708_CPGF.csv para organizacao.
# 2019-08-21 07:50:17.342256: Verificando registros do arquivo 201708_CPGF.csv .
# 2019-08-21 07:50:17.528848: Resultado: Normais = 11473 - Corrigidas = 0
# 2019-08-21 07:50:17.528848: Enviando 201709_CPGF.csv para organizacao.
# 2019-08-21 07:50:17.528848: Verificando registros do arquivo 201709_CPGF.csv .
# 2019-08-21 07:50:17.749658: Resultado: Normais = 13271 - Corrigidas = 0
# 2019-08-21 07:50:17.750653: Enviando 201710_CPGF.csv para organizacao.
# 2019-08-21 07:50:17.750653: Verificando registros do arquivo 201710_CPGF.csv .
# 2019-08-21 07:50:17.954525: Resultado: Normais = 13231 - Corrigidas = 0
# 2019-08-21 07:50:17.954525: Enviando 201711_CPGF.csv para organizacao.
# 2019-08-21 07:50:17.954525: Verificando registros do arquivo 201711_CPGF.csv .
# 2019-08-21 07:50:18.248769: Resultado: Normais = 16347 - Corrigidas = 0
# 2019-08-21 07:50:18.249258: Enviando 201712_CPGF.csv para organizacao.
# 2019-08-21 07:50:18.249258: Verificando registros do arquivo 201712_CPGF.csv .
# 2019-08-21 07:50:18.482945: Resultado: Normais = 18154 - Corrigidas = 0
# 2019-08-21 07:50:18.483110: Enviando 201801_CPGF.csv para organizacao.
# 2019-08-21 07:50:18.483110: Verificando registros do arquivo 201801_CPGF.csv .
# 2019-08-21 07:50:18.659640: Resultado: Normais = 13931 - Corrigidas = 0
# 2019-08-21 07:50:18.660637: Enviando 201802_CPGF.csv para organizacao.
# 2019-08-21 07:50:18.660637: Verificando registros do arquivo 201802_CPGF.csv .
# 2019-08-21 07:50:18.756070: Resultado: Normais = 5392 - Corrigidas = 0
# 2019-08-21 07:50:18.756070: Enviando 201803_CPGF.csv para organizacao.
# 2019-08-21 07:50:18.756070: Verificando registros do arquivo 201803_CPGF.csv .
# 2019-08-21 07:50:18.877744: Resultado: Normais = 8204 - Corrigidas = 0
# 2019-08-21 07:50:18.877744: Enviando 201804_CPGF.csv para organizacao.
# 2019-08-21 07:50:18.877744: Verificando registros do arquivo 201804_CPGF.csv .
# 2019-08-21 07:50:19.051281: Resultado: Normais = 13872 - Corrigidas = 0
# 2019-08-21 07:50:19.051281: Enviando 201805_CPGF.csv para organizacao.
# 2019-08-21 07:50:19.051281: Verificando registros do arquivo 201805_CPGF.csv .
# 2019-08-21 07:50:19.245760: Resultado: Normais = 14908 - Corrigidas = 0
# 2019-08-21 07:50:19.246758: Enviando 201806_CPGF.csv para organizacao.
# 2019-08-21 07:50:19.246758: Verificando registros do arquivo 201806_CPGF.csv .
# 2019-08-21 07:50:19.444268: Resultado: Normais = 13401 - Corrigidas = 0
# 2019-08-21 07:50:19.444268: Enviando 201807_CPGF.csv para organizacao.
# 2019-08-21 07:50:19.444268: Verificando registros do arquivo 201807_CPGF.csv .
# 2019-08-21 07:50:19.583899: Resultado: Normais = 11260 - Corrigidas = 0
# 2019-08-21 07:50:19.583899: Enviando 201808_CPGF.csv para organizacao.
# 2019-08-21 07:50:19.583899: Verificando registros do arquivo 201808_CPGF.csv .
# 2019-08-21 07:50:19.778336: Resultado: Normais = 10525 - Corrigidas = 0
# 2019-08-21 07:50:19.778336: Enviando 201809_CPGF.csv para organizacao.
# 2019-08-21 07:50:19.778336: Verificando registros do arquivo 201809_CPGF.csv .
# 2019-08-21 07:50:19.943895: Resultado: Normais = 11773 - Corrigidas = 0
# 2019-08-21 07:50:19.943895: Enviando 201810_CPGF.csv para organizacao.
# 2019-08-21 07:50:19.943895: Verificando registros do arquivo 201810_CPGF.csv .
# 2019-08-21 07:50:20.110668: Resultado: Normais = 11578 - Corrigidas = 0
# 2019-08-21 07:50:20.110668: Enviando 201811_CPGF.csv para organizacao.
# 2019-08-21 07:50:20.110668: Verificando registros do arquivo 201811_CPGF.csv .
# 2019-08-21 07:50:20.347002: Resultado: Normais = 13924 - Corrigidas = 0
# 2019-08-21 07:50:20.347002: Enviando 201812_CPGF.csv para organizacao.
# 2019-08-21 07:50:20.347002: Verificando registros do arquivo 201812_CPGF.csv .
# 2019-08-21 07:50:20.560467: Resultado: Normais = 14234 - Corrigidas = 0
# 2019-08-21 07:50:20.560467: Enviando 201901_CPGF.csv para organizacao.
# 2019-08-21 07:50:20.560467: Verificando registros do arquivo 201901_CPGF.csv .
# 2019-08-21 07:50:20.715018: Resultado: Normais = 8988 - Corrigidas = 0
# 2019-08-21 07:50:20.715170: Enviando 201902_CPGF.csv para organizacao.
# 2019-08-21 07:50:20.715170: Verificando registros do arquivo 201902_CPGF.csv .
# 2019-08-21 07:50:20.747930: Resultado: Normais = 1985 - Corrigidas = 0
# 2019-08-21 07:50:20.747930: Enviando 201903_CPGF.csv para organizacao.
# 2019-08-21 07:50:20.747930: Verificando registros do arquivo 201903_CPGF.csv .
# 2019-08-21 07:50:20.843674: Resultado: Normais = 7129 - Corrigidas = 0
# 2019-08-21 07:50:20.843744: Enviando 201904_CPGF.csv para organizacao.
# 2019-08-21 07:50:20.843744: Verificando registros do arquivo 201904_CPGF.csv .
# 2019-08-21 07:50:20.952383: Resultado: Normais = 8361 - Corrigidas = 0
# 2019-08-21 07:50:20.952383: Enviando 201905_CPGF.csv para organizacao.
# 2019-08-21 07:50:20.952383: Verificando registros do arquivo 201905_CPGF.csv .
# 2019-08-21 07:50:21.092044: Resultado: Normais = 10876 - Corrigidas = 0
# 2019-08-21 07:50:21.093089: Enviando 201906_CPGF.csv para organizacao.
# 2019-08-21 07:50:21.093089: Verificando registros do arquivo 201906_CPGF.csv .
# 2019-08-21 07:50:21.252626: Resultado: Normais = 11708 - Corrigidas = 0
# 2019-08-21 07:50:21.252626: Organizacao dos arquivos finalizada.
