# %%
import os as os
import requests as req
import zipfile as zipfile
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
def data_directories():
    """
    Funcao de criacao das pastas para armazenamento dos dados, caso nao existam.
    
    """

    # Diretorios para armazenamento dos dados coletados
    directories = ['..\\data\\01-collected'
                  ,'..\\data\\02-cleaned'
                  ,'..\\data\\03-organized'
                  ,'..\\data\\04-standardized']
    
    # Log: Mensagem de inicio da criacao dos diretorios
    print(str(datetime.now()) + ': Criacao dos diretorios para armazenamento dos dados iniciada.')
    
    # Para cada diretorio na lista de diretorios
    for directory in directories:
        
        # Verifica se o diretorio existe
        if not os.path.exists(directory):
            
            # Cria o diretorio
            os.makedirs(directory)
            
            # Log: Mensagem de criacao do diretorio
            print(str(datetime.now()) + ': Diretorio ' + directory + ' criado.')
        
        else:
            
            # Log: Mensagem de diretorio existente
            print(str(datetime.now()) + ': Diretorio ' + directory + ' ja existe.')
    
    # Log: Mensagem de fim da criacao dos diretorios
    print(str(datetime.now()) + ': Criacao dos diretorios para armazenamento dos dados finalizada.')

# %%
def download_file(**kwargs):
    """
    Funcao que realiza o download do arquivo. Ao final do download, e verificado
    se o arquivo solicitado esta vazio. Caso esteja vazio, o arquivo e apagado. Caso contrario,
    o arquivo e descompactado.
    
    Args:
        url_query (str): URL parametrizada para download do arquivo.
        download_path (str): Caminho do diretorio onde sera salvo o arquivo.
        download_directory (str): Caminho do diretorio para decompactacao do arquivo
    """
    
    # Log: Mensagem de inicio do download do arquivo
    print(str(datetime.now()) + ': Inicio do download do arquivo ' + kwargs['download_path'])
    
    # Prepara a requisicao de download do arquivo
    res = req.get(kwargs['url_query'], stream = True)
    
    # Se for encontrada a URL para download
    if res.status_code == 200:
        
        # Faz o download do arquivo
        with open(kwargs['download_path'], 'wb') as f:
            
            # Log: Mensagem de URL encontrada e de inicio do download
            print(str(datetime.now()) + ': URL encontrada, fazendo o download do arquivo: ' + kwargs['download_path'])
            
            # Download do arquivo em pedacos
            for chunk in res.iter_content(chunk_size = 1024):
                f.write(chunk)
        
        # Verifica o tamanho do arquivo recebido
        file_size = os.stat(kwargs['download_path']).st_size
        
        # Se o tamanho do arquivo for muito 
        # pequeno remove o arquivo da pasta 
        if file_size <= 100:
            
            # Log: Mensagem de remocao por arquivo por nao conter dados
            print(str(datetime.now()) + ': Arquivo ' + kwargs['download_path'] + ' removido por conter poucos dados.')
            
            # Remove o arquivo sem dados
            os.remove(kwargs['download_path'])
            
        # Caso contrario, descompacta o arquivo csv 
        # na pasta e remove o arquivo compactado
        else:
            
            # Log: Mensagem de inicio da descompactacao do arquivo zip
            print(str(datetime.now()) + ': Descompactando o arquivo ' + kwargs['download_path'])
            
            # Descompacta o arquivo zip mantem apenas o csv
            zip_ref = zipfile.ZipFile(kwargs['download_path'], 'r')
            zip_ref.extractall(path=kwargs['download_directory'])
            zip_ref.close()
            os.remove(kwargs['download_path'])
            
            # log: Mensagem de finalizacao do download do arquivo
            print(str(datetime.now()) + ': Fim do download do arquivo ' + kwargs['download_path'])

# %%
def collect_data(**kwargs):
    """
    Coleta os dados para cada mes de referencia dentro das datas de inicio e fim informadas.
    
    Args:
        dt_ini_ref (date): Data inicial para coleta dos dados
        dt_fim_ref (date): Data final para coleta dos dados
    """
    
    # Cria os diretorios para armazenamento dos dados
    data_directories()
    
    # Define a data de referencia inicial
    kwargs['dt_ref'] = kwargs['dt_ini_ref']
    
    # Define o diretorio para download dos arquivos
    kwargs['download_directory'] = '..\\data\\01-collected\\'
    
    # Define a URL base de busca dos arquivos para download
    kwargs['download_url'] = 'http://www.portaltransparencia.gov.br/download-de-dados/licitacoes/'
    
    # Define o nome e extensao do arquivo para download
    kwargs['file_name'] = '_Licitacoes'
    kwargs['file_ext'] = '.zip'
    
    # Log: Mensagem de inicio do processo 
    print(str(datetime.now()) + ': Coleta dos arquivos iniciada.')
       
    # Para cada mes de referencia dentro das datas de inicio e fim
    while kwargs['dt_ref'] <= kwargs['dt_fim_ref']:
        
        # Prepara as variaveis do mes de referencia
        kwargs['file_date_ref'] = kwargs['dt_ref'].strftime('%Y%m')
        kwargs['download_file'] = kwargs['file_date_ref'] + kwargs['file_name'] + kwargs['file_ext']
        
        # Define a URL completa para download do arquivo
        kwargs['url_query'] = kwargs['download_url'] + kwargs['file_date_ref']
        
        # Define o caminho completo para armazenamento do arquivo de download
        kwargs['download_path'] = kwargs['download_directory'] + kwargs['download_file']
        
        # Inicia o download do arquivo
        download_file(**kwargs)
        
        # Atualiza o mes de refencia
        kwargs['dt_ref'] += relativedelta(months=1)

    # Log: Mensagem de finalizacao do processo 
    print(str(datetime.now()) + ': Coleta dos arquivos finalizada.')

# %%
def main():
    """
    Coleta os dados de Licitacoes do Governo Federal (Licitacoes).
    Origem: Portal da Transparencia
    """
    
    # Prepara o dicionario de variaveis (kwargs = keyworded arguments)
    kwargs = {}
    
    # Datas de Inicio e Fim (YYYY-MM-DD) 
    # Obs.: Dados disponiveis a partir de 2013-01-01
    kwargs['dt_ini_ref'] = datetime.strptime('2013-01-01', "%Y-%m-%d")
    kwargs['dt_fim_ref'] = datetime.strptime('2019-06-01', "%Y-%m-%d")
    
    # Coleta os arquivos
    collect_data(**kwargs)

if __name__ == '__main__':
    main()
# Out:
# 2019-09-12 09:04:22.104246: Criacao dos diretorios para armazenamento dos dados iniciada.
# 2019-09-12 09:04:22.105244: Diretorio ..\data\01-collected ja existe.
# 2019-09-12 09:04:22.105244: Diretorio ..\data\02-cleaned ja existe.
# 2019-09-12 09:04:22.105244: Diretorio ..\data\03-organized ja existe.
# 2019-09-12 09:04:22.106241: Diretorio ..\data\04-standardized ja existe.
# 2019-09-12 09:04:22.106241: Criacao dos diretorios para armazenamento dos dados finalizada.
# 2019-09-12 09:04:22.106241: Coleta dos arquivos iniciada.
# 2019-09-12 09:04:22.106241: Inicio do download do arquivo ..\data\01-collected\201301_Licitacoes.zip
# 2019-09-12 09:04:39.535363: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201301_Licitacoes.zip
# 2019-09-12 09:04:44.602840: Descompactando o arquivo ..\data\01-collected\201301_Licitacoes.zip
# 2019-09-12 09:04:44.758425: Fim do download do arquivo ..\data\01-collected\201301_Licitacoes.zip
# 2019-09-12 09:04:44.759421: Inicio do download do arquivo ..\data\01-collected\201302_Licitacoes.zip
# 2019-09-12 09:04:50.535478: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201302_Licitacoes.zip
# 2019-09-12 09:05:01.443780: Descompactando o arquivo ..\data\01-collected\201302_Licitacoes.zip
# 2019-09-12 09:05:01.623300: Fim do download do arquivo ..\data\01-collected\201302_Licitacoes.zip
# 2019-09-12 09:05:01.623300: Inicio do download do arquivo ..\data\01-collected\201303_Licitacoes.zip
# 2019-09-12 09:05:01.991624: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201303_Licitacoes.zip
# 2019-09-12 09:05:30.511209: Descompactando o arquivo ..\data\01-collected\201303_Licitacoes.zip
# 2019-09-12 09:05:30.883789: Fim do download do arquivo ..\data\01-collected\201303_Licitacoes.zip
# 2019-09-12 09:05:30.883789: Inicio do download do arquivo ..\data\01-collected\201304_Licitacoes.zip
# 2019-09-12 09:05:31.301800: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201304_Licitacoes.zip
# 2019-09-12 09:06:14.744028: Descompactando o arquivo ..\data\01-collected\201304_Licitacoes.zip
# 2019-09-12 09:06:15.403837: Fim do download do arquivo ..\data\01-collected\201304_Licitacoes.zip
# 2019-09-12 09:06:15.404835: Inicio do download do arquivo ..\data\01-collected\201305_Licitacoes.zip
# 2019-09-12 09:06:15.876608: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201305_Licitacoes.zip
# 2019-09-12 09:07:07.081914: Descompactando o arquivo ..\data\01-collected\201305_Licitacoes.zip
# 2019-09-12 09:07:07.841879: Fim do download do arquivo ..\data\01-collected\201305_Licitacoes.zip
# 2019-09-12 09:07:07.841879: Inicio do download do arquivo ..\data\01-collected\201306_Licitacoes.zip
# 2019-09-12 09:07:14.830033: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201306_Licitacoes.zip
# 2019-09-12 09:08:08.720756: Descompactando o arquivo ..\data\01-collected\201306_Licitacoes.zip
# 2019-09-12 09:08:09.576466: Fim do download do arquivo ..\data\01-collected\201306_Licitacoes.zip
# 2019-09-12 09:08:09.576466: Inicio do download do arquivo ..\data\01-collected\201307_Licitacoes.zip
# 2019-09-12 09:08:10.047206: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201307_Licitacoes.zip
# 2019-09-12 09:09:06.852167: Descompactando o arquivo ..\data\01-collected\201307_Licitacoes.zip
# 2019-09-12 09:09:07.896375: Fim do download do arquivo ..\data\01-collected\201307_Licitacoes.zip
# 2019-09-12 09:09:07.896375: Inicio do download do arquivo ..\data\01-collected\201308_Licitacoes.zip
# 2019-09-12 09:09:08.267382: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201308_Licitacoes.zip
# 2019-09-12 09:10:08.613239: Descompactando o arquivo ..\data\01-collected\201308_Licitacoes.zip
# 2019-09-12 09:10:09.624533: Fim do download do arquivo ..\data\01-collected\201308_Licitacoes.zip
# 2019-09-12 09:10:09.624533: Inicio do download do arquivo ..\data\01-collected\201309_Licitacoes.zip
# 2019-09-12 09:10:12.778100: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201309_Licitacoes.zip
# 2019-09-12 09:11:08.669768: Descompactando o arquivo ..\data\01-collected\201309_Licitacoes.zip
# 2019-09-12 09:11:09.586312: Fim do download do arquivo ..\data\01-collected\201309_Licitacoes.zip
# 2019-09-12 09:11:09.586312: Inicio do download do arquivo ..\data\01-collected\201310_Licitacoes.zip
# 2019-09-12 09:11:09.965883: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201310_Licitacoes.zip
# 2019-09-12 09:12:16.392812: Descompactando o arquivo ..\data\01-collected\201310_Licitacoes.zip
# 2019-09-12 09:12:17.605197: Fim do download do arquivo ..\data\01-collected\201310_Licitacoes.zip
# 2019-09-12 09:12:17.605197: Inicio do download do arquivo ..\data\01-collected\201311_Licitacoes.zip
# 2019-09-12 09:12:17.984235: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201311_Licitacoes.zip
# 2019-09-12 09:13:41.730736: Descompactando o arquivo ..\data\01-collected\201311_Licitacoes.zip
# 2019-09-12 09:13:43.077158: Fim do download do arquivo ..\data\01-collected\201311_Licitacoes.zip
# 2019-09-12 09:13:43.077158: Inicio do download do arquivo ..\data\01-collected\201312_Licitacoes.zip
# 2019-09-12 09:13:54.850458: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201312_Licitacoes.zip
# 2019-09-12 09:14:54.955774: Descompactando o arquivo ..\data\01-collected\201312_Licitacoes.zip
# 2019-09-12 09:14:55.957599: Fim do download do arquivo ..\data\01-collected\201312_Licitacoes.zip
# 2019-09-12 09:14:55.958596: Inicio do download do arquivo ..\data\01-collected\201401_Licitacoes.zip
# 2019-09-12 09:14:56.354485: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201401_Licitacoes.zip
# 2019-09-12 09:15:19.997561: Descompactando o arquivo ..\data\01-collected\201401_Licitacoes.zip
# 2019-09-12 09:15:20.408463: Fim do download do arquivo ..\data\01-collected\201401_Licitacoes.zip
# 2019-09-12 09:15:20.408463: Inicio do download do arquivo ..\data\01-collected\201402_Licitacoes.zip
# 2019-09-12 09:15:20.796668: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201402_Licitacoes.zip
# 2019-09-12 09:15:51.636197: Descompactando o arquivo ..\data\01-collected\201402_Licitacoes.zip
# 2019-09-12 09:15:52.117941: Fim do download do arquivo ..\data\01-collected\201402_Licitacoes.zip
# 2019-09-12 09:15:52.117941: Inicio do download do arquivo ..\data\01-collected\201403_Licitacoes.zip
# 2019-09-12 09:15:52.503340: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201403_Licitacoes.zip
# 2019-09-12 09:16:26.134684: Descompactando o arquivo ..\data\01-collected\201403_Licitacoes.zip
# 2019-09-12 09:16:26.620385: Fim do download do arquivo ..\data\01-collected\201403_Licitacoes.zip
# 2019-09-12 09:16:26.620385: Inicio do download do arquivo ..\data\01-collected\201404_Licitacoes.zip
# 2019-09-12 09:16:51.176856: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201404_Licitacoes.zip
# 2019-09-12 09:17:31.488210: Descompactando o arquivo ..\data\01-collected\201404_Licitacoes.zip
# 2019-09-12 09:17:32.269120: Fim do download do arquivo ..\data\01-collected\201404_Licitacoes.zip
# 2019-09-12 09:17:32.270120: Inicio do download do arquivo ..\data\01-collected\201405_Licitacoes.zip
# 2019-09-12 09:17:49.196551: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201405_Licitacoes.zip
# 2019-09-12 09:18:35.135371: Descompactando o arquivo ..\data\01-collected\201405_Licitacoes.zip
# 2019-09-12 09:18:35.859433: Fim do download do arquivo ..\data\01-collected\201405_Licitacoes.zip
# 2019-09-12 09:18:35.859433: Inicio do download do arquivo ..\data\01-collected\201406_Licitacoes.zip
# 2019-09-12 09:18:39.612601: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201406_Licitacoes.zip
# 2019-09-12 09:19:23.177473: Descompactando o arquivo ..\data\01-collected\201406_Licitacoes.zip
# 2019-09-12 09:19:23.856861: Fim do download do arquivo ..\data\01-collected\201406_Licitacoes.zip
# 2019-09-12 09:19:23.856861: Inicio do download do arquivo ..\data\01-collected\201407_Licitacoes.zip
# 2019-09-12 09:19:24.234730: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201407_Licitacoes.zip
# 2019-09-12 09:20:18.130386: Descompactando o arquivo ..\data\01-collected\201407_Licitacoes.zip
# 2019-09-12 09:20:19.055424: Fim do download do arquivo ..\data\01-collected\201407_Licitacoes.zip
# 2019-09-12 09:20:19.056419: Inicio do download do arquivo ..\data\01-collected\201408_Licitacoes.zip
# 2019-09-12 09:20:19.439429: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201408_Licitacoes.zip
# 2019-09-12 09:21:13.122166: Descompactando o arquivo ..\data\01-collected\201408_Licitacoes.zip
# 2019-09-12 09:21:13.991082: Fim do download do arquivo ..\data\01-collected\201408_Licitacoes.zip
# 2019-09-12 09:21:13.992077: Inicio do download do arquivo ..\data\01-collected\201409_Licitacoes.zip
# 2019-09-12 09:21:14.362241: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201409_Licitacoes.zip
# 2019-09-12 09:22:10.106667: Descompactando o arquivo ..\data\01-collected\201409_Licitacoes.zip
# 2019-09-12 09:22:10.961926: Fim do download do arquivo ..\data\01-collected\201409_Licitacoes.zip
# 2019-09-12 09:22:10.961926: Inicio do download do arquivo ..\data\01-collected\201410_Licitacoes.zip
# 2019-09-12 09:22:11.307579: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201410_Licitacoes.zip
# 2019-09-12 09:23:12.819398: Descompactando o arquivo ..\data\01-collected\201410_Licitacoes.zip
# 2019-09-12 09:23:13.727563: Fim do download do arquivo ..\data\01-collected\201410_Licitacoes.zip
# 2019-09-12 09:23:13.728560: Inicio do download do arquivo ..\data\01-collected\201411_Licitacoes.zip
# 2019-09-12 09:23:14.082831: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201411_Licitacoes.zip
# 2019-09-12 09:24:27.936173: Descompactando o arquivo ..\data\01-collected\201411_Licitacoes.zip
# 2019-09-12 09:24:29.027283: Fim do download do arquivo ..\data\01-collected\201411_Licitacoes.zip
# 2019-09-12 09:24:29.027283: Inicio do download do arquivo ..\data\01-collected\201412_Licitacoes.zip
# 2019-09-12 09:24:29.372028: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201412_Licitacoes.zip
# 2019-09-12 09:25:19.694023: Descompactando o arquivo ..\data\01-collected\201412_Licitacoes.zip
# 2019-09-12 09:25:20.664430: Fim do download do arquivo ..\data\01-collected\201412_Licitacoes.zip
# 2019-09-12 09:25:20.665424: Inicio do download do arquivo ..\data\01-collected\201501_Licitacoes.zip
# 2019-09-12 09:25:26.641574: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201501_Licitacoes.zip
# 2019-09-12 09:25:44.518847: Descompactando o arquivo ..\data\01-collected\201501_Licitacoes.zip
# 2019-09-12 09:25:44.878455: Fim do download do arquivo ..\data\01-collected\201501_Licitacoes.zip
# 2019-09-12 09:25:44.878455: Inicio do download do arquivo ..\data\01-collected\201502_Licitacoes.zip
# 2019-09-12 09:25:50.620644: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201502_Licitacoes.zip
# 2019-09-12 09:26:11.424845: Descompactando o arquivo ..\data\01-collected\201502_Licitacoes.zip
# 2019-09-12 09:26:11.779926: Fim do download do arquivo ..\data\01-collected\201502_Licitacoes.zip
# 2019-09-12 09:26:11.779926: Inicio do download do arquivo ..\data\01-collected\201503_Licitacoes.zip
# 2019-09-12 09:26:12.151687: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201503_Licitacoes.zip
# 2019-09-12 09:26:45.597033: Descompactando o arquivo ..\data\01-collected\201503_Licitacoes.zip
# 2019-09-12 09:26:46.140579: Fim do download do arquivo ..\data\01-collected\201503_Licitacoes.zip
# 2019-09-12 09:26:46.141575: Inicio do download do arquivo ..\data\01-collected\201504_Licitacoes.zip
# 2019-09-12 09:26:59.524594: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201504_Licitacoes.zip
# 2019-09-12 09:27:31.947228: Descompactando o arquivo ..\data\01-collected\201504_Licitacoes.zip
# 2019-09-12 09:27:32.430440: Fim do download do arquivo ..\data\01-collected\201504_Licitacoes.zip
# 2019-09-12 09:27:32.431437: Inicio do download do arquivo ..\data\01-collected\201505_Licitacoes.zip
# 2019-09-12 09:27:50.309562: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201505_Licitacoes.zip
# 2019-09-12 09:28:27.784823: Descompactando o arquivo ..\data\01-collected\201505_Licitacoes.zip
# 2019-09-12 09:28:28.545786: Fim do download do arquivo ..\data\01-collected\201505_Licitacoes.zip
# 2019-09-12 09:28:28.545786: Inicio do download do arquivo ..\data\01-collected\201506_Licitacoes.zip
# 2019-09-12 09:28:28.992592: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201506_Licitacoes.zip
# 2019-09-12 09:29:08.841283: Descompactando o arquivo ..\data\01-collected\201506_Licitacoes.zip
# 2019-09-12 09:29:09.487587: Fim do download do arquivo ..\data\01-collected\201506_Licitacoes.zip
# 2019-09-12 09:29:09.487587: Inicio do download do arquivo ..\data\01-collected\201507_Licitacoes.zip
# 2019-09-12 09:29:09.833883: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201507_Licitacoes.zip
# 2019-09-12 09:29:55.271935: Descompactando o arquivo ..\data\01-collected\201507_Licitacoes.zip
# 2019-09-12 09:29:55.965067: Fim do download do arquivo ..\data\01-collected\201507_Licitacoes.zip
# 2019-09-12 09:29:55.966065: Inicio do download do arquivo ..\data\01-collected\201508_Licitacoes.zip
# 2019-09-12 09:29:56.317125: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201508_Licitacoes.zip
# 2019-09-12 09:30:39.203495: Descompactando o arquivo ..\data\01-collected\201508_Licitacoes.zip
# 2019-09-12 09:30:39.903619: Fim do download do arquivo ..\data\01-collected\201508_Licitacoes.zip
# 2019-09-12 09:30:39.903619: Inicio do download do arquivo ..\data\01-collected\201509_Licitacoes.zip
# 2019-09-12 09:30:40.263917: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201509_Licitacoes.zip
# 2019-09-12 09:31:25.772938: Descompactando o arquivo ..\data\01-collected\201509_Licitacoes.zip
# 2019-09-12 09:31:26.490021: Fim do download do arquivo ..\data\01-collected\201509_Licitacoes.zip
# 2019-09-12 09:31:26.490021: Inicio do download do arquivo ..\data\01-collected\201510_Licitacoes.zip
# 2019-09-12 09:31:26.853100: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201510_Licitacoes.zip
# 2019-09-12 09:32:19.577796: Descompactando o arquivo ..\data\01-collected\201510_Licitacoes.zip
# 2019-09-12 09:32:20.391862: Fim do download do arquivo ..\data\01-collected\201510_Licitacoes.zip
# 2019-09-12 09:32:20.391862: Inicio do download do arquivo ..\data\01-collected\201511_Licitacoes.zip
# 2019-09-12 09:32:20.753893: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201511_Licitacoes.zip
# 2019-09-12 09:33:21.524612: Descompactando o arquivo ..\data\01-collected\201511_Licitacoes.zip
# 2019-09-12 09:33:22.505986: Fim do download do arquivo ..\data\01-collected\201511_Licitacoes.zip
# 2019-09-12 09:33:22.506983: Inicio do download do arquivo ..\data\01-collected\201512_Licitacoes.zip
# 2019-09-12 09:33:26.379833: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201512_Licitacoes.zip
# 2019-09-12 09:34:04.515440: Descompactando o arquivo ..\data\01-collected\201512_Licitacoes.zip
# 2019-09-12 09:34:05.155803: Fim do download do arquivo ..\data\01-collected\201512_Licitacoes.zip
# 2019-09-12 09:34:05.156801: Inicio do download do arquivo ..\data\01-collected\201601_Licitacoes.zip
# 2019-09-12 09:34:10.655707: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201601_Licitacoes.zip
# 2019-09-12 09:34:24.548647: Descompactando o arquivo ..\data\01-collected\201601_Licitacoes.zip
# 2019-09-12 09:34:24.837905: Fim do download do arquivo ..\data\01-collected\201601_Licitacoes.zip
# 2019-09-12 09:34:24.837905: Inicio do download do arquivo ..\data\01-collected\201602_Licitacoes.zip
# 2019-09-12 09:34:25.211384: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201602_Licitacoes.zip
# 2019-09-12 09:34:49.510142: Descompactando o arquivo ..\data\01-collected\201602_Licitacoes.zip
# 2019-09-12 09:34:49.940026: Fim do download do arquivo ..\data\01-collected\201602_Licitacoes.zip
# 2019-09-12 09:34:49.940990: Inicio do download do arquivo ..\data\01-collected\201603_Licitacoes.zip
# 2019-09-12 09:34:50.308360: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201603_Licitacoes.zip
# 2019-09-12 09:35:25.752802: Descompactando o arquivo ..\data\01-collected\201603_Licitacoes.zip
# 2019-09-12 09:35:26.317860: Fim do download do arquivo ..\data\01-collected\201603_Licitacoes.zip
# 2019-09-12 09:35:26.317860: Inicio do download do arquivo ..\data\01-collected\201604_Licitacoes.zip
# 2019-09-12 09:35:26.667079: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201604_Licitacoes.zip
# 2019-09-12 09:35:58.292264: Descompactando o arquivo ..\data\01-collected\201604_Licitacoes.zip
# 2019-09-12 09:35:58.796913: Fim do download do arquivo ..\data\01-collected\201604_Licitacoes.zip
# 2019-09-12 09:35:58.796913: Inicio do download do arquivo ..\data\01-collected\201605_Licitacoes.zip
# 2019-09-12 09:35:59.194270: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201605_Licitacoes.zip
# 2019-09-12 09:36:37.467002: Descompactando o arquivo ..\data\01-collected\201605_Licitacoes.zip
# 2019-09-12 09:36:38.071390: Fim do download do arquivo ..\data\01-collected\201605_Licitacoes.zip
# 2019-09-12 09:36:38.071390: Inicio do download do arquivo ..\data\01-collected\201606_Licitacoes.zip
# 2019-09-12 09:36:38.461390: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201606_Licitacoes.zip
# 2019-09-12 09:37:20.310083: Descompactando o arquivo ..\data\01-collected\201606_Licitacoes.zip
# 2019-09-12 09:37:20.964870: Fim do download do arquivo ..\data\01-collected\201606_Licitacoes.zip
# 2019-09-12 09:37:20.965867: Inicio do download do arquivo ..\data\01-collected\201607_Licitacoes.zip
# 2019-09-12 09:37:21.360812: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201607_Licitacoes.zip
# 2019-09-12 09:38:00.317694: Descompactando o arquivo ..\data\01-collected\201607_Licitacoes.zip
# 2019-09-12 09:38:00.935620: Fim do download do arquivo ..\data\01-collected\201607_Licitacoes.zip
# 2019-09-12 09:38:00.936616: Inicio do download do arquivo ..\data\01-collected\201608_Licitacoes.zip
# 2019-09-12 09:38:01.333100: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201608_Licitacoes.zip
# 2019-09-12 09:38:44.570634: Descompactando o arquivo ..\data\01-collected\201608_Licitacoes.zip
# 2019-09-12 09:38:45.197952: Fim do download do arquivo ..\data\01-collected\201608_Licitacoes.zip
# 2019-09-12 09:38:45.198950: Inicio do download do arquivo ..\data\01-collected\201609_Licitacoes.zip
# 2019-09-12 09:38:57.865285: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201609_Licitacoes.zip
# 2019-09-12 09:39:40.011312: Descompactando o arquivo ..\data\01-collected\201609_Licitacoes.zip
# 2019-09-12 09:39:40.655130: Fim do download do arquivo ..\data\01-collected\201609_Licitacoes.zip
# 2019-09-12 09:39:40.655130: Inicio do download do arquivo ..\data\01-collected\201610_Licitacoes.zip
# 2019-09-12 09:39:41.019609: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201610_Licitacoes.zip
# 2019-09-12 09:40:31.193892: Descompactando o arquivo ..\data\01-collected\201610_Licitacoes.zip
# 2019-09-12 09:40:31.930480: Fim do download do arquivo ..\data\01-collected\201610_Licitacoes.zip
# 2019-09-12 09:40:31.930480: Inicio do download do arquivo ..\data\01-collected\201611_Licitacoes.zip
# 2019-09-12 09:40:32.292569: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201611_Licitacoes.zip
# 2019-09-12 09:41:33.666703: Descompactando o arquivo ..\data\01-collected\201611_Licitacoes.zip
# 2019-09-12 09:41:34.717915: Fim do download do arquivo ..\data\01-collected\201611_Licitacoes.zip
# 2019-09-12 09:41:34.717915: Inicio do download do arquivo ..\data\01-collected\201612_Licitacoes.zip
# 2019-09-12 09:41:35.104882: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201612_Licitacoes.zip
# 2019-09-12 09:42:23.142808: Descompactando o arquivo ..\data\01-collected\201612_Licitacoes.zip
# 2019-09-12 09:42:23.918241: Fim do download do arquivo ..\data\01-collected\201612_Licitacoes.zip
# 2019-09-12 09:42:23.919239: Inicio do download do arquivo ..\data\01-collected\201701_Licitacoes.zip
# 2019-09-12 09:42:29.689121: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201701_Licitacoes.zip
# 2019-09-12 09:42:45.899827: Descompactando o arquivo ..\data\01-collected\201701_Licitacoes.zip
# 2019-09-12 09:42:46.237924: Fim do download do arquivo ..\data\01-collected\201701_Licitacoes.zip
# 2019-09-12 09:42:46.237924: Inicio do download do arquivo ..\data\01-collected\201702_Licitacoes.zip
# 2019-09-12 09:42:51.690280: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201702_Licitacoes.zip
# 2019-09-12 09:43:09.049552: Descompactando o arquivo ..\data\01-collected\201702_Licitacoes.zip
# 2019-09-12 09:43:09.399482: Fim do download do arquivo ..\data\01-collected\201702_Licitacoes.zip
# 2019-09-12 09:43:09.399482: Inicio do download do arquivo ..\data\01-collected\201703_Licitacoes.zip
# 2019-09-12 09:43:18.246973: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201703_Licitacoes.zip
# 2019-09-12 09:43:51.697208: Descompactando o arquivo ..\data\01-collected\201703_Licitacoes.zip
# 2019-09-12 09:43:52.240334: Fim do download do arquivo ..\data\01-collected\201703_Licitacoes.zip
# 2019-09-12 09:43:52.241331: Inicio do download do arquivo ..\data\01-collected\201704_Licitacoes.zip
# 2019-09-12 09:44:07.527216: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201704_Licitacoes.zip
# 2019-09-12 09:44:38.286418: Descompactando o arquivo ..\data\01-collected\201704_Licitacoes.zip
# 2019-09-12 09:44:38.777274: Fim do download do arquivo ..\data\01-collected\201704_Licitacoes.zip
# 2019-09-12 09:44:38.777274: Inicio do download do arquivo ..\data\01-collected\201705_Licitacoes.zip
# 2019-09-12 09:44:39.173423: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201705_Licitacoes.zip
# 2019-09-12 09:45:18.969199: Descompactando o arquivo ..\data\01-collected\201705_Licitacoes.zip
# 2019-09-12 09:45:19.583133: Fim do download do arquivo ..\data\01-collected\201705_Licitacoes.zip
# 2019-09-12 09:45:19.583133: Inicio do download do arquivo ..\data\01-collected\201706_Licitacoes.zip
# 2019-09-12 09:45:19.963248: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201706_Licitacoes.zip
# 2019-09-12 09:46:00.916350: Descompactando o arquivo ..\data\01-collected\201706_Licitacoes.zip
# 2019-09-12 09:46:01.507343: Fim do download do arquivo ..\data\01-collected\201706_Licitacoes.zip
# 2019-09-12 09:46:01.508340: Inicio do download do arquivo ..\data\01-collected\201707_Licitacoes.zip
# 2019-09-12 09:46:01.872274: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201707_Licitacoes.zip
# 2019-09-12 09:46:45.153324: Descompactando o arquivo ..\data\01-collected\201707_Licitacoes.zip
# 2019-09-12 09:46:45.783638: Fim do download do arquivo ..\data\01-collected\201707_Licitacoes.zip
# 2019-09-12 09:46:45.783638: Inicio do download do arquivo ..\data\01-collected\201708_Licitacoes.zip
# 2019-09-12 09:46:46.164019: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201708_Licitacoes.zip
# 2019-09-12 09:47:33.051498: Descompactando o arquivo ..\data\01-collected\201708_Licitacoes.zip
# 2019-09-12 09:47:33.787529: Fim do download do arquivo ..\data\01-collected\201708_Licitacoes.zip
# 2019-09-12 09:47:33.788524: Inicio do download do arquivo ..\data\01-collected\201709_Licitacoes.zip
# 2019-09-12 09:47:34.178482: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201709_Licitacoes.zip
# 2019-09-12 09:48:14.274944: Descompactando o arquivo ..\data\01-collected\201709_Licitacoes.zip
# 2019-09-12 09:48:14.880355: Fim do download do arquivo ..\data\01-collected\201709_Licitacoes.zip
# 2019-09-12 09:48:14.880355: Inicio do download do arquivo ..\data\01-collected\201710_Licitacoes.zip
# 2019-09-12 09:48:15.575783: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201710_Licitacoes.zip
# 2019-09-12 09:49:04.340933: Descompactando o arquivo ..\data\01-collected\201710_Licitacoes.zip
# 2019-09-12 09:49:05.150768: Fim do download do arquivo ..\data\01-collected\201710_Licitacoes.zip
# 2019-09-12 09:49:05.151763: Inicio do download do arquivo ..\data\01-collected\201711_Licitacoes.zip
# 2019-09-12 09:49:05.529751: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201711_Licitacoes.zip
# 2019-09-12 09:50:02.965499: Descompactando o arquivo ..\data\01-collected\201711_Licitacoes.zip
# 2019-09-12 09:50:03.824200: Fim do download do arquivo ..\data\01-collected\201711_Licitacoes.zip
# 2019-09-12 09:50:03.825196: Inicio do download do arquivo ..\data\01-collected\201712_Licitacoes.zip
# 2019-09-12 09:50:04.217149: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201712_Licitacoes.zip
# 2019-09-12 09:50:50.384068: Descompactando o arquivo ..\data\01-collected\201712_Licitacoes.zip
# 2019-09-12 09:50:51.061256: Fim do download do arquivo ..\data\01-collected\201712_Licitacoes.zip
# 2019-09-12 09:50:51.061256: Inicio do download do arquivo ..\data\01-collected\201801_Licitacoes.zip
# 2019-09-12 09:50:56.722032: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201801_Licitacoes.zip
# 2019-09-12 09:51:14.896921: Descompactando o arquivo ..\data\01-collected\201801_Licitacoes.zip
# 2019-09-12 09:51:15.216065: Fim do download do arquivo ..\data\01-collected\201801_Licitacoes.zip
# 2019-09-12 09:51:15.217062: Inicio do download do arquivo ..\data\01-collected\201802_Licitacoes.zip
# 2019-09-12 09:51:20.724214: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201802_Licitacoes.zip
# 2019-09-12 09:51:40.079181: Descompactando o arquivo ..\data\01-collected\201802_Licitacoes.zip
# 2019-09-12 09:51:40.438788: Fim do download do arquivo ..\data\01-collected\201802_Licitacoes.zip
# 2019-09-12 09:51:40.438788: Inicio do download do arquivo ..\data\01-collected\201803_Licitacoes.zip
# 2019-09-12 09:51:40.842824: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201803_Licitacoes.zip
# 2019-09-12 09:52:10.674653: Descompactando o arquivo ..\data\01-collected\201803_Licitacoes.zip
# 2019-09-12 09:52:11.130048: Fim do download do arquivo ..\data\01-collected\201803_Licitacoes.zip
# 2019-09-12 09:52:11.130048: Inicio do download do arquivo ..\data\01-collected\201804_Licitacoes.zip
# 2019-09-12 09:52:11.505498: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201804_Licitacoes.zip
# 2019-09-12 09:52:47.543474: Descompactando o arquivo ..\data\01-collected\201804_Licitacoes.zip
# 2019-09-12 09:52:48.056102: Fim do download do arquivo ..\data\01-collected\201804_Licitacoes.zip
# 2019-09-12 09:52:48.057098: Inicio do download do arquivo ..\data\01-collected\201805_Licitacoes.zip
# 2019-09-12 09:52:57.675484: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201805_Licitacoes.zip
# 2019-09-12 09:53:35.557957: Descompactando o arquivo ..\data\01-collected\201805_Licitacoes.zip
# 2019-09-12 09:53:36.136916: Fim do download do arquivo ..\data\01-collected\201805_Licitacoes.zip
# 2019-09-12 09:53:36.137916: Inicio do download do arquivo ..\data\01-collected\201806_Licitacoes.zip
# 2019-09-12 09:53:36.519352: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201806_Licitacoes.zip
# 2019-09-12 09:54:15.233249: Descompactando o arquivo ..\data\01-collected\201806_Licitacoes.zip
# 2019-09-12 09:54:15.822678: Fim do download do arquivo ..\data\01-collected\201806_Licitacoes.zip
# 2019-09-12 09:54:15.823113: Inicio do download do arquivo ..\data\01-collected\201807_Licitacoes.zip
# 2019-09-12 09:54:16.221099: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201807_Licitacoes.zip
# 2019-09-12 09:55:01.940004: Descompactando o arquivo ..\data\01-collected\201807_Licitacoes.zip
# 2019-09-12 09:55:02.614198: Fim do download do arquivo ..\data\01-collected\201807_Licitacoes.zip
# 2019-09-12 09:55:02.615196: Inicio do download do arquivo ..\data\01-collected\201808_Licitacoes.zip
# 2019-09-12 09:55:02.976329: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201808_Licitacoes.zip
# 2019-09-12 09:55:54.149672: Descompactando o arquivo ..\data\01-collected\201808_Licitacoes.zip
# 2019-09-12 09:55:55.053767: Fim do download do arquivo ..\data\01-collected\201808_Licitacoes.zip
# 2019-09-12 09:55:55.053767: Inicio do download do arquivo ..\data\01-collected\201809_Licitacoes.zip
# 2019-09-12 09:55:55.761872: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201809_Licitacoes.zip
# 2019-09-12 09:56:39.881738: Descompactando o arquivo ..\data\01-collected\201809_Licitacoes.zip
# 2019-09-12 09:56:40.568927: Fim do download do arquivo ..\data\01-collected\201809_Licitacoes.zip
# 2019-09-12 09:56:40.568927: Inicio do download do arquivo ..\data\01-collected\201810_Licitacoes.zip
# 2019-09-12 09:56:40.940905: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201810_Licitacoes.zip
# 2019-09-12 09:57:36.998200: Descompactando o arquivo ..\data\01-collected\201810_Licitacoes.zip
# 2019-09-12 09:57:37.839757: Fim do download do arquivo ..\data\01-collected\201810_Licitacoes.zip
# 2019-09-12 09:57:37.840754: Inicio do download do arquivo ..\data\01-collected\201811_Licitacoes.zip
# 2019-09-12 09:57:38.233969: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201811_Licitacoes.zip
# 2019-09-12 09:58:37.950388: Descompactando o arquivo ..\data\01-collected\201811_Licitacoes.zip
# 2019-09-12 09:58:38.990135: Fim do download do arquivo ..\data\01-collected\201811_Licitacoes.zip
# 2019-09-12 09:58:38.990135: Inicio do download do arquivo ..\data\01-collected\201812_Licitacoes.zip
# 2019-09-12 09:58:39.387106: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201812_Licitacoes.zip
# 2019-09-12 09:59:28.493141: Descompactando o arquivo ..\data\01-collected\201812_Licitacoes.zip
# 2019-09-12 09:59:29.267117: Fim do download do arquivo ..\data\01-collected\201812_Licitacoes.zip
# 2019-09-12 09:59:29.267117: Inicio do download do arquivo ..\data\01-collected\201901_Licitacoes.zip
# 2019-09-12 09:59:34.755469: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201901_Licitacoes.zip
# 2019-09-12 09:59:52.477519: Descompactando o arquivo ..\data\01-collected\201901_Licitacoes.zip
# 2019-09-12 09:59:52.852515: Fim do download do arquivo ..\data\01-collected\201901_Licitacoes.zip
# 2019-09-12 09:59:52.852515: Inicio do download do arquivo ..\data\01-collected\201902_Licitacoes.zip
# 2019-09-12 09:59:53.198592: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201902_Licitacoes.zip
# 2019-09-12 10:00:21.169733: Descompactando o arquivo ..\data\01-collected\201902_Licitacoes.zip
# 2019-09-12 10:00:21.586456: Fim do download do arquivo ..\data\01-collected\201902_Licitacoes.zip
# 2019-09-12 10:00:21.586456: Inicio do download do arquivo ..\data\01-collected\201903_Licitacoes.zip
# 2019-09-12 10:00:22.688331: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201903_Licitacoes.zip
# 2019-09-12 10:00:50.859376: Descompactando o arquivo ..\data\01-collected\201903_Licitacoes.zip
# 2019-09-12 10:00:51.275308: Fim do download do arquivo ..\data\01-collected\201903_Licitacoes.zip
# 2019-09-12 10:00:51.275308: Inicio do download do arquivo ..\data\01-collected\201904_Licitacoes.zip
# 2019-09-12 10:00:51.643266: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201904_Licitacoes.zip
# 2019-09-12 10:01:30.315673: Descompactando o arquivo ..\data\01-collected\201904_Licitacoes.zip
# 2019-09-12 10:01:30.912075: Fim do download do arquivo ..\data\01-collected\201904_Licitacoes.zip
# 2019-09-12 10:01:30.912075: Inicio do download do arquivo ..\data\01-collected\201905_Licitacoes.zip
# 2019-09-12 10:01:36.361824: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\201905_Licitacoes.zip
# 2019-09-12 10:01:38.335001: Descompactando o arquivo ..\data\01-collected\201905_Licitacoes.zip
# 2019-09-12 10:01:38.431747: Fim do download do arquivo ..\data\01-collected\201905_Licitacoes.zip
# 2019-09-12 10:01:38.431747: Inicio do download do arquivo ..\data\01-collected\201906_Licitacoes.zip
# 2019-09-12 10:01:59.452255: Coleta dos arquivos finalizada.
