# %%
import os
import codecs
from datetime import datetime

# %%
def join_lines(**kwargs):
    """
    Le o arquivo de entrada, caso algum dos registros tenha quantidade de colunas diferente
    do cabecalho, a linha seguinte e concatenada com a atual e escrita no arquivo de saida.
    """
    
    # Log: Mensagem de inicio da verificacao dos registros
    print(str(datetime.now()) + ': Verificando registros do arquivo ' + kwargs['data_file'])
    
    # Le o arquivo de entrada
    with codecs.open(kwargs['in_data_path'], 'r', encoding = 'utf-8') as reader:
        
        # Prepara o arquivo de saida
        with codecs.open(kwargs['out_data_path'], 'w', encoding = 'utf-8') as writer:
            
            # Armazena o header do arquivo de entrada
            header = reader.readline()
            
            # Conta a quantidade de colunas no header
            qt_columns = header.count('\";\"')
            
            # Define os contadores
            qt_lines = 0
            qt_joins = 0
            
            # Escreve o cabecalho no arquivo de saida
            writer.write(header)
            
            # Para cada linha no arquivo de entrada
            for line in reader:
                
                # Escreve o registro do arquivo de entrada no arquivo de saida 
                # Caso o registro tenha quantidade de colunas diferente do cabecalho
                # a linha seguinte e concatenada com a atual
                if line.count('\";\"') != qt_columns:
                    qt_joins += 1
                    writer.write(line.replace("\r\n", "") + reader.readline())
                else:
                    qt_lines += 1
                    writer.write(line)
                    
    # Log: Resultado da verificacao dos registros
    print(str(datetime.now()) + ': Resultado: Normais = ' + str(qt_lines) + ' - Corrigidas = ' + str(qt_joins))

# %%
def organize_files():
    """
    Para cada arquivo de origem, e verificado se a quantidade de colunas de cada registro corresponde
    com a quantidade de colunas do cabecalho do arquivo.        
    """
    
    # Prepara o dicionario de variaveis (kwargs = keyworded arguments)
    kwargs = {}
    
    # Diretorio de armazenamento dos arquivos originais
    kwargs['in_data_dir'] = '..\\data\\02-cleaned'
    
    # Diretorio de armazenamento dos arquivos tratados
    kwargs['out_data_dir'] = '..\\data\\03-organized'
    
    # Lista dos arquivos originais 
    kwargs['data_files'] = os.listdir(kwargs['in_data_dir'])
    
    # Log: Mensagem de inicio do processo 
    print(str(datetime.now()) + ': Organizacao dos arquivos iniciada.')
    
    # Para cada arquivo na lista de arquivos originais
    for file in kwargs['data_files']:
        
        # Define o caminho completo de acesso e escrita dos arquivos
        kwargs['data_file'] = file
        kwargs['in_data_path'] = os.path.join(kwargs['in_data_dir'], kwargs['data_file'])
        kwargs['out_data_path'] = os.path.join(kwargs['out_data_dir'], kwargs['data_file'])
        
        # Corrige registros com menos colunas que o esperado
        join_lines(**kwargs)
      
    # Log: Mensagem de finalizacao do processo de limpeza
    print(str(datetime.now()) + ': Organizacao dos arquivos finalizada.')

# %%
def main():
    """
    Organiza os dados de Licitacoes do Governo Federal (Licitacoes).
    Origem: Portal da Transparencia
    """
    
    ### Organiza os arquivos
    organize_files()

if __name__ == '__main__':
    main()
# Out:
# 2019-09-12 10:07:37.527083: Organizacao dos arquivos iniciada.
# 2019-09-12 10:07:37.527083: Verificando registros do arquivo 201301_ItemLicitacao.csv
# 2019-09-12 10:07:37.782399: Resultado: Normais = 20619 - Corrigidas = 0
# 2019-09-12 10:07:37.782399: Verificando registros do arquivo 201301_Licitacao.csv
# 2019-09-12 10:07:37.919065: Resultado: Normais = 7122 - Corrigidas = 0
# 2019-09-12 10:07:37.920033: Verificando registros do arquivo 201301_ParticipantesLicitacao.csv
# 2019-09-12 10:07:39.208590: Resultado: Normais = 112226 - Corrigidas = 0
# 2019-09-12 10:07:39.208590: Verificando registros do arquivo 201302_ItemLicitacao.csv
# 2019-09-12 10:07:39.545716: Resultado: Normais = 34596 - Corrigidas = 0
# 2019-09-12 10:07:39.545716: Verificando registros do arquivo 201302_Licitacao.csv
# 2019-09-12 10:07:39.725202: Resultado: Normais = 10609 - Corrigidas = 0
# 2019-09-12 10:07:39.725202: Verificando registros do arquivo 201302_ParticipantesLicitacao.csv
# 2019-09-12 10:07:41.561323: Resultado: Normais = 134550 - Corrigidas = 0
# 2019-09-12 10:07:41.561323: Verificando registros do arquivo 201303_ItemLicitacao.csv
# 2019-09-12 10:07:42.393067: Resultado: Normais = 72015 - Corrigidas = 0
# 2019-09-12 10:07:42.393067: Verificando registros do arquivo 201303_Licitacao.csv
# 2019-09-12 10:07:42.719192: Resultado: Normais = 15196 - Corrigidas = 0
# 2019-09-12 10:07:42.719192: Verificando registros do arquivo 201303_ParticipantesLicitacao.csv
# 2019-09-12 10:07:47.302924: Resultado: Normais = 355585 - Corrigidas = 0
# 2019-09-12 10:07:47.302924: Verificando registros do arquivo 201304_ItemLicitacao.csv
# 2019-09-12 10:07:48.733098: Resultado: Normais = 122443 - Corrigidas = 0
# 2019-09-12 10:07:48.733098: Verificando registros do arquivo 201304_Licitacao.csv
# 2019-09-12 10:07:49.028308: Resultado: Normais = 20820 - Corrigidas = 0
# 2019-09-12 10:07:49.028308: Verificando registros do arquivo 201304_ParticipantesLicitacao.csv
# 2019-09-12 10:07:57.525573: Resultado: Normais = 687012 - Corrigidas = 0
# 2019-09-12 10:07:57.525573: Verificando registros do arquivo 201305_ItemLicitacao.csv
# 2019-09-12 10:07:59.128285: Resultado: Normais = 141790 - Corrigidas = 0
# 2019-09-12 10:07:59.128285: Verificando registros do arquivo 201305_Licitacao.csv
# 2019-09-12 10:07:59.545202: Resultado: Normais = 22872 - Corrigidas = 0
# 2019-09-12 10:07:59.545202: Verificando registros do arquivo 201305_ParticipantesLicitacao.csv
# 2019-09-12 10:08:09.668398: Resultado: Normais = 792955 - Corrigidas = 0
# 2019-09-12 10:08:09.668398: Verificando registros do arquivo 201306_ItemLicitacao.csv
# 2019-09-12 10:08:11.458609: Resultado: Normais = 161103 - Corrigidas = 0
# 2019-09-12 10:08:11.458609: Verificando registros do arquivo 201306_Licitacao.csv
# 2019-09-12 10:08:11.844606: Resultado: Normais = 21775 - Corrigidas = 0
# 2019-09-12 10:08:11.844606: Verificando registros do arquivo 201306_ParticipantesLicitacao.csv
# 2019-09-12 10:08:23.636229: Resultado: Normais = 948150 - Corrigidas = 0
# 2019-09-12 10:08:23.636229: Verificando registros do arquivo 201307_ItemLicitacao.csv
# 2019-09-12 10:08:25.688737: Resultado: Normais = 171197 - Corrigidas = 0
# 2019-09-12 10:08:25.688737: Verificando registros do arquivo 201307_Licitacao.csv
# 2019-09-12 10:08:26.073709: Resultado: Normais = 22966 - Corrigidas = 0
# 2019-09-12 10:08:26.073709: Verificando registros do arquivo 201307_ParticipantesLicitacao.csv
# 2019-09-12 10:08:37.927639: Resultado: Normais = 995457 - Corrigidas = 0
# 2019-09-12 10:08:37.928636: Verificando registros do arquivo 201308_ItemLicitacao.csv
# 2019-09-12 10:08:40.052958: Resultado: Normais = 184571 - Corrigidas = 0
# 2019-09-12 10:08:40.052958: Verificando registros do arquivo 201308_Licitacao.csv
# 2019-09-12 10:08:40.493772: Resultado: Normais = 22217 - Corrigidas = 0
# 2019-09-12 10:08:40.493772: Verificando registros do arquivo 201308_ParticipantesLicitacao.csv
# 2019-09-12 10:08:54.316825: Resultado: Normais = 1137286 - Corrigidas = 0
# 2019-09-12 10:08:54.316825: Verificando registros do arquivo 201309_ItemLicitacao.csv
# 2019-09-12 10:08:56.491007: Resultado: Normais = 170460 - Corrigidas = 0
# 2019-09-12 10:08:56.491007: Verificando registros do arquivo 201309_Licitacao.csv
# 2019-09-12 10:08:56.872984: Resultado: Normais = 21997 - Corrigidas = 0
# 2019-09-12 10:08:56.872984: Verificando registros do arquivo 201309_ParticipantesLicitacao.csv
# 2019-09-12 10:09:09.356970: Resultado: Normais = 1005864 - Corrigidas = 0
# 2019-09-12 10:09:09.357968: Verificando registros do arquivo 201310_ItemLicitacao.csv
# 2019-09-12 10:09:11.908149: Resultado: Normais = 212814 - Corrigidas = 0
# 2019-09-12 10:09:11.908149: Verificando registros do arquivo 201310_Licitacao.csv
# 2019-09-12 10:09:12.349961: Resultado: Normais = 26336 - Corrigidas = 0
# 2019-09-12 10:09:12.349961: Verificando registros do arquivo 201310_ParticipantesLicitacao.csv
# 2019-09-12 10:09:27.865274: Resultado: Normais = 1222154 - Corrigidas = 0
# 2019-09-12 10:09:27.865274: Verificando registros do arquivo 201311_ItemLicitacao.csv
# 2019-09-12 10:09:31.371893: Resultado: Normais = 276830 - Corrigidas = 0
# 2019-09-12 10:09:31.371893: Verificando registros do arquivo 201311_Licitacao.csv
# 2019-09-12 10:09:31.972286: Resultado: Normais = 30455 - Corrigidas = 0
# 2019-09-12 10:09:31.972286: Verificando registros do arquivo 201311_ParticipantesLicitacao.csv
# 2019-09-12 10:09:49.985888: Resultado: Normais = 1474699 - Corrigidas = 0
# 2019-09-12 10:09:49.986885: Verificando registros do arquivo 201312_ItemLicitacao.csv
# 2019-09-12 10:09:52.205514: Resultado: Normais = 195176 - Corrigidas = 0
# 2019-09-12 10:09:52.205514: Verificando registros do arquivo 201312_Licitacao.csv
# 2019-09-12 10:09:52.643341: Resultado: Normais = 20734 - Corrigidas = 0
# 2019-09-12 10:09:52.644339: Verificando registros do arquivo 201312_ParticipantesLicitacao.csv
# 2019-09-12 10:10:06.458132: Resultado: Normais = 1087720 - Corrigidas = 0
# 2019-09-12 10:10:06.458132: Verificando registros do arquivo 201401_ItemLicitacao.csv
# 2019-09-12 10:10:07.501339: Resultado: Normais = 79566 - Corrigidas = 0
# 2019-09-12 10:10:07.501339: Verificando registros do arquivo 201401_Licitacao.csv
# 2019-09-12 10:10:07.714769: Resultado: Normais = 8899 - Corrigidas = 0
# 2019-09-12 10:10:07.715768: Verificando registros do arquivo 201401_ParticipantesLicitacao.csv
# 2019-09-12 10:10:13.421499: Resultado: Normais = 443191 - Corrigidas = 0
# 2019-09-12 10:10:13.421499: Verificando registros do arquivo 201402_ItemLicitacao.csv
# 2019-09-12 10:10:14.607326: Resultado: Normais = 87414 - Corrigidas = 0
# 2019-09-12 10:10:14.607326: Verificando registros do arquivo 201402_Licitacao.csv
# 2019-09-12 10:10:14.960381: Resultado: Normais = 14069 - Corrigidas = 0
# 2019-09-12 10:10:14.960381: Verificando registros do arquivo 201402_ParticipantesLicitacao.csv
# 2019-09-12 10:10:22.080356: Resultado: Normais = 496455 - Corrigidas = 0
# 2019-09-12 10:10:22.080356: Verificando registros do arquivo 201403_ItemLicitacao.csv
# 2019-09-12 10:10:23.233244: Resultado: Normais = 89752 - Corrigidas = 0
# 2019-09-12 10:10:23.233244: Verificando registros do arquivo 201403_Licitacao.csv
# 2019-09-12 10:10:23.598268: Resultado: Normais = 14630 - Corrigidas = 0
# 2019-09-12 10:10:23.598268: Verificando registros do arquivo 201403_ParticipantesLicitacao.csv
# 2019-09-12 10:10:30.399071: Resultado: Normais = 490157 - Corrigidas = 0
# 2019-09-12 10:10:30.399071: Verificando registros do arquivo 201404_ItemLicitacao.csv
# 2019-09-12 10:10:32.021730: Resultado: Normais = 118966 - Corrigidas = 0
# 2019-09-12 10:10:32.022727: Verificando registros do arquivo 201404_Licitacao.csv
# 2019-09-12 10:10:32.368832: Resultado: Normais = 17798 - Corrigidas = 0
# 2019-09-12 10:10:32.368832: Verificando registros do arquivo 201404_ParticipantesLicitacao.csv
# 2019-09-12 10:10:40.359333: Resultado: Normais = 648603 - Corrigidas = 0
# 2019-09-12 10:10:40.359333: Verificando registros do arquivo 201405_ItemLicitacao.csv
# 2019-09-12 10:10:41.978002: Resultado: Normais = 131529 - Corrigidas = 0
# 2019-09-12 10:10:41.978002: Verificando registros do arquivo 201405_Licitacao.csv
# 2019-09-12 10:10:42.305129: Resultado: Normais = 19061 - Corrigidas = 0
# 2019-09-12 10:10:42.305129: Verificando registros do arquivo 201405_ParticipantesLicitacao.csv
# 2019-09-12 10:10:52.089945: Resultado: Normais = 755717 - Corrigidas = 0
# 2019-09-12 10:10:52.089945: Verificando registros do arquivo 201406_ItemLicitacao.csv
# 2019-09-12 10:10:53.649773: Resultado: Normais = 125397 - Corrigidas = 0
# 2019-09-12 10:10:53.649773: Verificando registros do arquivo 201406_Licitacao.csv
# 2019-09-12 10:10:53.940302: Resultado: Normais = 16203 - Corrigidas = 0
# 2019-09-12 10:10:53.940302: Verificando registros do arquivo 201406_ParticipantesLicitacao.csv
# 2019-09-12 10:11:02.705846: Resultado: Normais = 732589 - Corrigidas = 0
# 2019-09-12 10:11:02.705846: Verificando registros do arquivo 201407_ItemLicitacao.csv
# 2019-09-12 10:11:04.558911: Resultado: Normais = 165970 - Corrigidas = 0
# 2019-09-12 10:11:04.558911: Verificando registros do arquivo 201407_Licitacao.csv
# 2019-09-12 10:11:04.938710: Resultado: Normais = 20824 - Corrigidas = 0
# 2019-09-12 10:11:04.938710: Verificando registros do arquivo 201407_ParticipantesLicitacao.csv
# 2019-09-12 10:11:16.477409: Resultado: Normais = 926561 - Corrigidas = 0
# 2019-09-12 10:11:16.477409: Verificando registros do arquivo 201408_ItemLicitacao.csv
# 2019-09-12 10:11:18.339571: Resultado: Normais = 162941 - Corrigidas = 0
# 2019-09-12 10:11:18.339571: Verificando registros do arquivo 201408_Licitacao.csv
# 2019-09-12 10:11:18.682618: Resultado: Normais = 21391 - Corrigidas = 0
# 2019-09-12 10:11:18.682618: Verificando registros do arquivo 201408_ParticipantesLicitacao.csv
# 2019-09-12 10:11:30.682953: Resultado: Normais = 929299 - Corrigidas = 0
# 2019-09-12 10:11:30.683950: Verificando registros do arquivo 201409_ItemLicitacao.csv
# 2019-09-12 10:11:32.744437: Resultado: Normais = 164741 - Corrigidas = 0
# 2019-09-12 10:11:32.744437: Verificando registros do arquivo 201409_Licitacao.csv
# 2019-09-12 10:11:33.120432: Resultado: Normais = 22358 - Corrigidas = 0
# 2019-09-12 10:11:33.121429: Verificando registros do arquivo 201409_ParticipantesLicitacao.csv
# 2019-09-12 10:11:46.057543: Resultado: Normais = 927434 - Corrigidas = 0
# 2019-09-12 10:11:46.058540: Verificando registros do arquivo 201410_ItemLicitacao.csv
# 2019-09-12 10:11:48.610711: Resultado: Normais = 187784 - Corrigidas = 0
# 2019-09-12 10:11:48.610711: Verificando registros do arquivo 201410_Licitacao.csv
# 2019-09-12 10:11:49.034579: Resultado: Normais = 24685 - Corrigidas = 0
# 2019-09-12 10:11:49.034579: Verificando registros do arquivo 201410_ParticipantesLicitacao.csv
# 2019-09-12 10:12:04.788296: Resultado: Normais = 1009290 - Corrigidas = 0
# 2019-09-12 10:12:04.788296: Verificando registros do arquivo 201411_ItemLicitacao.csv
# 2019-09-12 10:12:07.906924: Resultado: Normais = 239529 - Corrigidas = 0
# 2019-09-12 10:12:07.907923: Verificando registros do arquivo 201411_Licitacao.csv
# 2019-09-12 10:12:08.450473: Resultado: Normais = 28665 - Corrigidas = 0
# 2019-09-12 10:12:08.450473: Verificando registros do arquivo 201411_ParticipantesLicitacao.csv
# 2019-09-12 10:12:24.601048: Resultado: Normais = 1193018 - Corrigidas = 0
# 2019-09-12 10:12:24.601048: Verificando registros do arquivo 201412_ItemLicitacao.csv
# 2019-09-12 10:12:26.711403: Resultado: Normais = 159359 - Corrigidas = 0
# 2019-09-12 10:12:26.711403: Verificando registros do arquivo 201412_Licitacao.csv
# 2019-09-12 10:12:27.130281: Resultado: Normais = 15703 - Corrigidas = 0
# 2019-09-12 10:12:27.130281: Verificando registros do arquivo 201412_ParticipantesLicitacao.csv
# 2019-09-12 10:12:38.963695: Resultado: Normais = 873955 - Corrigidas = 0
# 2019-09-12 10:12:38.963695: Verificando registros do arquivo 201501_ItemLicitacao.csv
# 2019-09-12 10:12:39.639896: Resultado: Normais = 58274 - Corrigidas = 0
# 2019-09-12 10:12:39.639896: Verificando registros do arquivo 201501_Licitacao.csv
# 2019-09-12 10:12:39.763528: Resultado: Normais = 6792 - Corrigidas = 0
# 2019-09-12 10:12:39.763528: Verificando registros do arquivo 201501_ParticipantesLicitacao.csv
# 2019-09-12 10:12:44.376712: Resultado: Normais = 368971 - Corrigidas = 0
# 2019-09-12 10:12:44.377711: Verificando registros do arquivo 201502_ItemLicitacao.csv
# 2019-09-12 10:12:45.418923: Resultado: Normais = 62775 - Corrigidas = 0
# 2019-09-12 10:12:45.419920: Verificando registros do arquivo 201502_Licitacao.csv
# 2019-09-12 10:12:45.711153: Resultado: Normais = 9086 - Corrigidas = 0
# 2019-09-12 10:12:45.711153: Verificando registros do arquivo 201502_ParticipantesLicitacao.csv
# 2019-09-12 10:12:50.602055: Resultado: Normais = 356338 - Corrigidas = 0
# 2019-09-12 10:12:50.602055: Verificando registros do arquivo 201503_ItemLicitacao.csv
# 2019-09-12 10:12:51.769932: Resultado: Normais = 101984 - Corrigidas = 0
# 2019-09-12 10:12:51.769932: Verificando registros do arquivo 201503_Licitacao.csv
# 2019-09-12 10:12:52.031230: Resultado: Normais = 12973 - Corrigidas = 0
# 2019-09-12 10:12:52.031230: Verificando registros do arquivo 201503_ParticipantesLicitacao.csv
# 2019-09-12 10:12:59.810417: Resultado: Normais = 575842 - Corrigidas = 0
# 2019-09-12 10:12:59.810417: Verificando registros do arquivo 201504_ItemLicitacao.csv
# 2019-09-12 10:13:00.872607: Resultado: Normais = 88895 - Corrigidas = 0
# 2019-09-12 10:13:00.872607: Verificando registros do arquivo 201504_Licitacao.csv
# 2019-09-12 10:13:01.068088: Resultado: Normais = 12031 - Corrigidas = 0
# 2019-09-12 10:13:01.068088: Verificando registros do arquivo 201504_ParticipantesLicitacao.csv
# 2019-09-12 10:13:07.543770: Resultado: Normais = 495695 - Corrigidas = 0
# 2019-09-12 10:13:07.543770: Verificando registros do arquivo 201505_ItemLicitacao.csv
# 2019-09-12 10:13:09.007851: Resultado: Normais = 110497 - Corrigidas = 0
# 2019-09-12 10:13:09.007851: Verificando registros do arquivo 201505_Licitacao.csv
# 2019-09-12 10:13:09.346942: Resultado: Normais = 13938 - Corrigidas = 0
# 2019-09-12 10:13:09.347940: Verificando registros do arquivo 201505_ParticipantesLicitacao.csv
# 2019-09-12 10:13:18.127513: Resultado: Normais = 660897 - Corrigidas = 0
# 2019-09-12 10:13:18.127513: Verificando registros do arquivo 201506_ItemLicitacao.csv
# 2019-09-12 10:13:19.618577: Resultado: Normais = 118692 - Corrigidas = 0
# 2019-09-12 10:13:19.618577: Verificando registros do arquivo 201506_Licitacao.csv
# 2019-09-12 10:13:19.937725: Resultado: Normais = 14374 - Corrigidas = 0
# 2019-09-12 10:13:19.937725: Verificando registros do arquivo 201506_ParticipantesLicitacao.csv
# 2019-09-12 10:13:28.871618: Resultado: Normais = 696284 - Corrigidas = 0
# 2019-09-12 10:13:28.871618: Verificando registros do arquivo 201507_ItemLicitacao.csv
# 2019-09-12 10:13:30.522201: Resultado: Normais = 128966 - Corrigidas = 0
# 2019-09-12 10:13:30.522201: Verificando registros do arquivo 201507_Licitacao.csv
# 2019-09-12 10:13:30.835365: Resultado: Normais = 16140 - Corrigidas = 0
# 2019-09-12 10:13:30.835365: Verificando registros do arquivo 201507_ParticipantesLicitacao.csv
# 2019-09-12 10:13:42.362599: Resultado: Normais = 804305 - Corrigidas = 0
# 2019-09-12 10:13:42.362599: Verificando registros do arquivo 201508_ItemLicitacao.csv
# 2019-09-12 10:13:43.860591: Resultado: Normais = 127380 - Corrigidas = 0
# 2019-09-12 10:13:43.860591: Verificando registros do arquivo 201508_Licitacao.csv
# 2019-09-12 10:13:44.173752: Resultado: Normais = 15279 - Corrigidas = 0
# 2019-09-12 10:13:44.173752: Verificando registros do arquivo 201508_ParticipantesLicitacao.csv
# 2019-09-12 10:13:54.107915: Resultado: Normais = 748921 - Corrigidas = 0
# 2019-09-12 10:13:54.108910: Verificando registros do arquivo 201509_ItemLicitacao.csv
# 2019-09-12 10:13:55.781435: Resultado: Normais = 140007 - Corrigidas = 0
# 2019-09-12 10:13:55.781435: Verificando registros do arquivo 201509_Licitacao.csv
# 2019-09-12 10:13:56.073652: Resultado: Normais = 16585 - Corrigidas = 0
# 2019-09-12 10:13:56.074653: Verificando registros do arquivo 201509_ParticipantesLicitacao.csv
# 2019-09-12 10:14:06.615357: Resultado: Normais = 821952 - Corrigidas = 0
# 2019-09-12 10:14:06.615357: Verificando registros do arquivo 201510_ItemLicitacao.csv
# 2019-09-12 10:14:08.644798: Resultado: Normais = 163588 - Corrigidas = 0
# 2019-09-12 10:14:08.644798: Verificando registros do arquivo 201510_Licitacao.csv
# 2019-09-12 10:14:09.060731: Resultado: Normais = 20542 - Corrigidas = 0
# 2019-09-12 10:14:09.060731: Verificando registros do arquivo 201510_ParticipantesLicitacao.csv
# 2019-09-12 10:14:21.354908: Resultado: Normais = 907656 - Corrigidas = 0
# 2019-09-12 10:14:21.354908: Verificando registros do arquivo 201511_ItemLicitacao.csv
# 2019-09-12 10:14:23.823306: Resultado: Normais = 195313 - Corrigidas = 0
# 2019-09-12 10:14:23.823306: Verificando registros do arquivo 201511_Licitacao.csv
# 2019-09-12 10:14:24.201257: Resultado: Normais = 20300 - Corrigidas = 0
# 2019-09-12 10:14:24.201257: Verificando registros do arquivo 201511_ParticipantesLicitacao.csv
# 2019-09-12 10:14:38.800897: Resultado: Normais = 1082981 - Corrigidas = 0
# 2019-09-12 10:14:38.801895: Verificando registros do arquivo 201512_ItemLicitacao.csv
# 2019-09-12 10:14:40.335791: Resultado: Normais = 116606 - Corrigidas = 0
# 2019-09-12 10:14:40.335791: Verificando registros do arquivo 201512_Licitacao.csv
# 2019-09-12 10:14:40.565209: Resultado: Normais = 11852 - Corrigidas = 0
# 2019-09-12 10:14:40.565209: Verificando registros do arquivo 201512_ParticipantesLicitacao.csv
# 2019-09-12 10:14:49.590623: Resultado: Normais = 685311 - Corrigidas = 0
# 2019-09-12 10:14:49.591604: Verificando registros do arquivo 201601_ItemLicitacao.csv
# 2019-09-12 10:14:50.227918: Resultado: Normais = 48853 - Corrigidas = 0
# 2019-09-12 10:14:50.227918: Verificando registros do arquivo 201601_Licitacao.csv
# 2019-09-12 10:14:50.343576: Resultado: Normais = 6161 - Corrigidas = 0
# 2019-09-12 10:14:50.343576: Verificando registros do arquivo 201601_ParticipantesLicitacao.csv
# 2019-09-12 10:14:54.705904: Resultado: Normais = 307902 - Corrigidas = 0
# 2019-09-12 10:14:54.705904: Verificando registros do arquivo 201602_ItemLicitacao.csv
# 2019-09-12 10:14:55.582559: Resultado: Normais = 71934 - Corrigidas = 0
# 2019-09-12 10:14:55.582559: Verificando registros do arquivo 201602_Licitacao.csv
# 2019-09-12 10:14:55.732160: Resultado: Normais = 9177 - Corrigidas = 0
# 2019-09-12 10:14:55.732160: Verificando registros do arquivo 201602_ParticipantesLicitacao.csv
# 2019-09-12 10:15:01.416429: Resultado: Normais = 398787 - Corrigidas = 0
# 2019-09-12 10:15:01.416429: Verificando registros do arquivo 201603_ItemLicitacao.csv
# 2019-09-12 10:15:02.732946: Resultado: Normais = 101889 - Corrigidas = 0
# 2019-09-12 10:15:02.732946: Verificando registros do arquivo 201603_Licitacao.csv
# 2019-09-12 10:15:02.991248: Resultado: Normais = 13733 - Corrigidas = 0
# 2019-09-12 10:15:02.991248: Verificando registros do arquivo 201603_ParticipantesLicitacao.csv
# 2019-09-12 10:15:11.065611: Resultado: Normais = 596682 - Corrigidas = 0
# 2019-09-12 10:15:11.065611: Verificando registros do arquivo 201604_ItemLicitacao.csv
# 2019-09-12 10:15:12.366162: Resultado: Normais = 94412 - Corrigidas = 0
# 2019-09-12 10:15:12.366162: Verificando registros do arquivo 201604_Licitacao.csv
# 2019-09-12 10:15:12.596514: Resultado: Normais = 12894 - Corrigidas = 0
# 2019-09-12 10:15:12.596514: Verificando registros do arquivo 201604_ParticipantesLicitacao.csv
# 2019-09-12 10:15:19.275643: Resultado: Normais = 501624 - Corrigidas = 0
# 2019-09-12 10:15:19.275643: Verificando registros do arquivo 201605_ItemLicitacao.csv
# 2019-09-12 10:15:20.655948: Resultado: Normais = 115816 - Corrigidas = 0
# 2019-09-12 10:15:20.655948: Verificando registros do arquivo 201605_Licitacao.csv
# 2019-09-12 10:15:20.957143: Resultado: Normais = 14195 - Corrigidas = 0
# 2019-09-12 10:15:20.958140: Verificando registros do arquivo 201605_ParticipantesLicitacao.csv
# 2019-09-12 10:15:28.968706: Resultado: Normais = 609590 - Corrigidas = 0
# 2019-09-12 10:15:28.968706: Verificando registros do arquivo 201606_ItemLicitacao.csv
# 2019-09-12 10:15:30.411844: Resultado: Normais = 133233 - Corrigidas = 0
# 2019-09-12 10:15:30.411844: Verificando registros do arquivo 201606_Licitacao.csv
# 2019-09-12 10:15:30.701072: Resultado: Normais = 14641 - Corrigidas = 0
# 2019-09-12 10:15:30.701072: Verificando registros do arquivo 201606_ParticipantesLicitacao.csv
# 2019-09-12 10:15:40.749215: Resultado: Normais = 748977 - Corrigidas = 0
# 2019-09-12 10:15:40.749215: Verificando registros do arquivo 201607_ItemLicitacao.csv
# 2019-09-12 10:15:42.114561: Resultado: Normais = 118639 - Corrigidas = 0
# 2019-09-12 10:15:42.114561: Verificando registros do arquivo 201607_Licitacao.csv
# 2019-09-12 10:15:42.376861: Resultado: Normais = 13574 - Corrigidas = 0
# 2019-09-12 10:15:42.376861: Verificando registros do arquivo 201607_ParticipantesLicitacao.csv
# 2019-09-12 10:15:51.454673: Resultado: Normais = 664219 - Corrigidas = 0
# 2019-09-12 10:15:51.454673: Verificando registros do arquivo 201608_ItemLicitacao.csv
# 2019-09-12 10:15:52.937707: Resultado: Normais = 128259 - Corrigidas = 0
# 2019-09-12 10:15:52.937707: Verificando registros do arquivo 201608_Licitacao.csv
# 2019-09-12 10:15:53.249838: Resultado: Normais = 14971 - Corrigidas = 0
# 2019-09-12 10:15:53.249838: Verificando registros do arquivo 201608_ParticipantesLicitacao.csv
# 2019-09-12 10:16:02.529272: Resultado: Normais = 682248 - Corrigidas = 0
# 2019-09-12 10:16:02.529272: Verificando registros do arquivo 201609_ItemLicitacao.csv
# 2019-09-12 10:16:04.071148: Resultado: Normais = 126897 - Corrigidas = 0
# 2019-09-12 10:16:04.071148: Verificando registros do arquivo 201609_Licitacao.csv
# 2019-09-12 10:16:04.441158: Resultado: Normais = 15512 - Corrigidas = 0
# 2019-09-12 10:16:04.442155: Verificando registros do arquivo 201609_ParticipantesLicitacao.csv
# 2019-09-12 10:16:14.129807: Resultado: Normais = 701904 - Corrigidas = 0
# 2019-09-12 10:16:14.129807: Verificando registros do arquivo 201610_ItemLicitacao.csv
# 2019-09-12 10:16:16.177433: Resultado: Normais = 148834 - Corrigidas = 0
# 2019-09-12 10:16:16.177433: Verificando registros do arquivo 201610_Licitacao.csv
# 2019-09-12 10:16:16.525450: Resultado: Normais = 17752 - Corrigidas = 0
# 2019-09-12 10:16:16.525450: Verificando registros do arquivo 201610_ParticipantesLicitacao.csv
# 2019-09-12 10:16:27.115419: Resultado: Normais = 784259 - Corrigidas = 0
# 2019-09-12 10:16:27.115419: Verificando registros do arquivo 201611_ItemLicitacao.csv
# 2019-09-12 10:16:29.260631: Resultado: Normais = 190273 - Corrigidas = 0
# 2019-09-12 10:16:29.260631: Verificando registros do arquivo 201611_Licitacao.csv
# 2019-09-12 10:16:29.843107: Resultado: Normais = 22449 - Corrigidas = 0
# 2019-09-12 10:16:29.843107: Verificando registros do arquivo 201611_ParticipantesLicitacao.csv
# 2019-09-12 10:16:44.768270: Resultado: Normais = 1019941 - Corrigidas = 0
# 2019-09-12 10:16:44.768270: Verificando registros do arquivo 201612_ItemLicitacao.csv
# 2019-09-12 10:16:46.836735: Resultado: Normais = 155261 - Corrigidas = 0
# 2019-09-12 10:16:46.836735: Verificando registros do arquivo 201612_Licitacao.csv
# 2019-09-12 10:16:47.191788: Resultado: Normais = 13617 - Corrigidas = 0
# 2019-09-12 10:16:47.191788: Verificando registros do arquivo 201612_ParticipantesLicitacao.csv
# 2019-09-12 10:17:00.191506: Resultado: Normais = 894156 - Corrigidas = 0
# 2019-09-12 10:17:00.192486: Verificando registros do arquivo 201701_ItemLicitacao.csv
# 2019-09-12 10:17:00.940521: Resultado: Normais = 58672 - Corrigidas = 0
# 2019-09-12 10:17:00.940521: Verificando registros do arquivo 201701_Licitacao.csv
# 2019-09-12 10:17:01.085098: Resultado: Normais = 6063 - Corrigidas = 0
# 2019-09-12 10:17:01.085098: Verificando registros do arquivo 201701_ParticipantesLicitacao.csv
# 2019-09-12 10:17:05.547053: Resultado: Normais = 341325 - Corrigidas = 0
# 2019-09-12 10:17:05.547053: Verificando registros do arquivo 201702_ItemLicitacao.csv
# 2019-09-12 10:17:06.427700: Resultado: Normais = 60410 - Corrigidas = 0
# 2019-09-12 10:17:06.427700: Verificando registros do arquivo 201702_Licitacao.csv
# 2019-09-12 10:17:06.578297: Resultado: Normais = 8471 - Corrigidas = 0
# 2019-09-12 10:17:06.578297: Verificando registros do arquivo 201702_ParticipantesLicitacao.csv
# 2019-09-12 10:17:11.430313: Resultado: Normais = 315405 - Corrigidas = 0
# 2019-09-12 10:17:11.431310: Verificando registros do arquivo 201703_ItemLicitacao.csv
# 2019-09-12 10:17:12.895424: Resultado: Normais = 100335 - Corrigidas = 0
# 2019-09-12 10:17:12.895424: Verificando registros do arquivo 201703_Licitacao.csv
# 2019-09-12 10:17:13.108820: Resultado: Normais = 12007 - Corrigidas = 0
# 2019-09-12 10:17:13.109818: Verificando registros do arquivo 201703_ParticipantesLicitacao.csv
# 2019-09-12 10:17:21.805258: Resultado: Normais = 572157 - Corrigidas = 0
# 2019-09-12 10:17:21.805258: Verificando registros do arquivo 201704_ItemLicitacao.csv
# 2019-09-12 10:17:23.374048: Resultado: Normais = 88769 - Corrigidas = 0
# 2019-09-12 10:17:23.374048: Verificando registros do arquivo 201704_Licitacao.csv
# 2019-09-12 10:17:23.626373: Resultado: Normais = 9821 - Corrigidas = 0
# 2019-09-12 10:17:23.626373: Verificando registros do arquivo 201704_ParticipantesLicitacao.csv
# 2019-09-12 10:17:30.789209: Resultado: Normais = 565133 - Corrigidas = 0
# 2019-09-12 10:17:30.789209: Verificando registros do arquivo 201705_ItemLicitacao.csv
# 2019-09-12 10:17:32.210405: Resultado: Normais = 110588 - Corrigidas = 0
# 2019-09-12 10:17:32.211403: Verificando registros do arquivo 201705_Licitacao.csv
# 2019-09-12 10:17:32.543514: Resultado: Normais = 14092 - Corrigidas = 0
# 2019-09-12 10:17:32.543514: Verificando registros do arquivo 201705_ParticipantesLicitacao.csv
# 2019-09-12 10:17:41.721099: Resultado: Normais = 656758 - Corrigidas = 0
# 2019-09-12 10:17:41.721099: Verificando registros do arquivo 201706_ItemLicitacao.csv
# 2019-09-12 10:17:43.167227: Resultado: Normais = 116478 - Corrigidas = 0
# 2019-09-12 10:17:43.168224: Verificando registros do arquivo 201706_Licitacao.csv
# 2019-09-12 10:17:43.409578: Resultado: Normais = 13761 - Corrigidas = 0
# 2019-09-12 10:17:43.409578: Verificando registros do arquivo 201706_ParticipantesLicitacao.csv
# 2019-09-12 10:17:52.540098: Resultado: Normais = 680840 - Corrigidas = 0
# 2019-09-12 10:17:52.540098: Verificando registros do arquivo 201707_ItemLicitacao.csv
# 2019-09-12 10:17:54.159765: Resultado: Normais = 119526 - Corrigidas = 0
# 2019-09-12 10:17:54.159765: Verificando registros do arquivo 201707_Licitacao.csv
# 2019-09-12 10:17:54.466943: Resultado: Normais = 13381 - Corrigidas = 0
# 2019-09-12 10:17:54.467940: Verificando registros do arquivo 201707_ParticipantesLicitacao.csv
# 2019-09-12 10:18:03.608387: Resultado: Normais = 712795 - Corrigidas = 0
# 2019-09-12 10:18:03.609395: Verificando registros do arquivo 201708_ItemLicitacao.csv
# 2019-09-12 10:18:05.440478: Resultado: Normais = 136571 - Corrigidas = 0
# 2019-09-12 10:18:05.441475: Verificando registros do arquivo 201708_Licitacao.csv
# 2019-09-12 10:18:05.793533: Resultado: Normais = 15548 - Corrigidas = 0
# 2019-09-12 10:18:05.793533: Verificando registros do arquivo 201708_ParticipantesLicitacao.csv
# 2019-09-12 10:18:17.166251: Resultado: Normais = 842383 - Corrigidas = 0
# 2019-09-12 10:18:17.166251: Verificando registros do arquivo 201709_ItemLicitacao.csv
# 2019-09-12 10:18:18.388978: Resultado: Normais = 112651 - Corrigidas = 0
# 2019-09-12 10:18:18.388978: Verificando registros do arquivo 201709_Licitacao.csv
# 2019-09-12 10:18:18.606398: Resultado: Normais = 13720 - Corrigidas = 0
# 2019-09-12 10:18:18.607396: Verificando registros do arquivo 201709_ParticipantesLicitacao.csv
# 2019-09-12 10:18:27.291683: Resultado: Normais = 647608 - Corrigidas = 0
# 2019-09-12 10:18:27.291683: Verificando registros do arquivo 201710_ItemLicitacao.csv
# 2019-09-12 10:18:29.342195: Resultado: Normais = 153193 - Corrigidas = 0
# 2019-09-12 10:18:29.342195: Verificando registros do arquivo 201710_Licitacao.csv
# 2019-09-12 10:18:29.647381: Resultado: Normais = 16947 - Corrigidas = 0
# 2019-09-12 10:18:29.647381: Verificando registros do arquivo 201710_ParticipantesLicitacao.csv
# 2019-09-12 10:18:41.731669: Resultado: Normais = 887412 - Corrigidas = 0
# 2019-09-12 10:18:41.731669: Verificando registros do arquivo 201711_ItemLicitacao.csv
# 2019-09-12 10:18:44.052461: Resultado: Normais = 172829 - Corrigidas = 0
# 2019-09-12 10:18:44.052461: Verificando registros do arquivo 201711_Licitacao.csv
# 2019-09-12 10:18:44.454383: Resultado: Normais = 20317 - Corrigidas = 0
# 2019-09-12 10:18:44.454383: Verificando registros do arquivo 201711_ParticipantesLicitacao.csv
# 2019-09-12 10:18:57.974269: Resultado: Normais = 933251 - Corrigidas = 0
# 2019-09-12 10:18:57.974269: Verificando registros do arquivo 201712_ItemLicitacao.csv
# 2019-09-12 10:18:59.734584: Resultado: Normais = 133723 - Corrigidas = 0
# 2019-09-12 10:18:59.735551: Verificando registros do arquivo 201712_Licitacao.csv
# 2019-09-12 10:18:59.979926: Resultado: Normais = 14874 - Corrigidas = 0
# 2019-09-12 10:18:59.980924: Verificando registros do arquivo 201712_ParticipantesLicitacao.csv
# 2019-09-12 10:19:10.908965: Resultado: Normais = 747433 - Corrigidas = 0
# 2019-09-12 10:19:10.909965: Verificando registros do arquivo 201801_ItemLicitacao.csv
# 2019-09-12 10:19:11.759723: Resultado: Normais = 60331 - Corrigidas = 0
# 2019-09-12 10:19:11.759723: Verificando registros do arquivo 201801_Licitacao.csv
# 2019-09-12 10:19:11.857467: Resultado: Normais = 5732 - Corrigidas = 0
# 2019-09-12 10:19:11.857467: Verificando registros do arquivo 201801_ParticipantesLicitacao.csv
# 2019-09-12 10:19:16.419223: Resultado: Normais = 330768 - Corrigidas = 0
# 2019-09-12 10:19:16.419223: Verificando registros do arquivo 201802_ItemLicitacao.csv
# 2019-09-12 10:19:17.188176: Resultado: Normais = 65837 - Corrigidas = 0
# 2019-09-12 10:19:17.188176: Verificando registros do arquivo 201802_Licitacao.csv
# 2019-09-12 10:19:17.357714: Resultado: Normais = 7535 - Corrigidas = 0
# 2019-09-12 10:19:17.357714: Verificando registros do arquivo 201802_ParticipantesLicitacao.csv
# 2019-09-12 10:19:22.896914: Resultado: Normais = 366024 - Corrigidas = 0
# 2019-09-12 10:19:22.897888: Verificando registros do arquivo 201803_ItemLicitacao.csv
# 2019-09-12 10:19:23.900204: Resultado: Normais = 86618 - Corrigidas = 0
# 2019-09-12 10:19:23.900204: Verificando registros do arquivo 201803_Licitacao.csv
# 2019-09-12 10:19:24.107650: Resultado: Normais = 10099 - Corrigidas = 0
# 2019-09-12 10:19:24.107650: Verificando registros do arquivo 201803_ParticipantesLicitacao.csv
# 2019-09-12 10:19:31.195801: Resultado: Normais = 514620 - Corrigidas = 0
# 2019-09-12 10:19:31.195801: Verificando registros do arquivo 201804_ItemLicitacao.csv
# 2019-09-12 10:19:32.356696: Resultado: Normais = 93096 - Corrigidas = 0
# 2019-09-12 10:19:32.356696: Verificando registros do arquivo 201804_Licitacao.csv
# 2019-09-12 10:19:32.628969: Resultado: Normais = 13573 - Corrigidas = 0
# 2019-09-12 10:19:32.628969: Verificando registros do arquivo 201804_ParticipantesLicitacao.csv
# 2019-09-12 10:19:39.674116: Resultado: Normais = 529302 - Corrigidas = 0
# 2019-09-12 10:19:39.674116: Verificando registros do arquivo 201805_ItemLicitacao.csv
# 2019-09-12 10:19:41.001567: Resultado: Normais = 106766 - Corrigidas = 0
# 2019-09-12 10:19:41.001567: Verificando registros do arquivo 201805_Licitacao.csv
# 2019-09-12 10:19:41.292887: Resultado: Normais = 14089 - Corrigidas = 0
# 2019-09-12 10:19:41.292887: Verificando registros do arquivo 201805_ParticipantesLicitacao.csv
# 2019-09-12 10:19:49.721939: Resultado: Normais = 620189 - Corrigidas = 0
# 2019-09-12 10:19:49.722937: Verificando registros do arquivo 201806_ItemLicitacao.csv
# 2019-09-12 10:19:51.475250: Resultado: Normais = 109709 - Corrigidas = 0
# 2019-09-12 10:19:51.476247: Verificando registros do arquivo 201806_Licitacao.csv
# 2019-09-12 10:19:51.758489: Resultado: Normais = 13244 - Corrigidas = 0
# 2019-09-12 10:19:51.758489: Verificando registros do arquivo 201806_ParticipantesLicitacao.csv
# 2019-09-12 10:20:01.925558: Resultado: Normais = 649006 - Corrigidas = 0
# 2019-09-12 10:20:01.925558: Verificando registros do arquivo 201807_ItemLicitacao.csv
# 2019-09-12 10:20:03.681860: Resultado: Normais = 125459 - Corrigidas = 0
# 2019-09-12 10:20:03.681860: Verificando registros do arquivo 201807_Licitacao.csv
# 2019-09-12 10:20:03.971109: Resultado: Normais = 15617 - Corrigidas = 0
# 2019-09-12 10:20:03.972083: Verificando registros do arquivo 201807_ParticipantesLicitacao.csv
# 2019-09-12 10:20:15.204031: Resultado: Normais = 720988 - Corrigidas = 0
# 2019-09-12 10:20:15.204031: Verificando registros do arquivo 201808_ItemLicitacao.csv
# 2019-09-12 10:20:17.529805: Resultado: Normais = 141831 - Corrigidas = 0
# 2019-09-12 10:20:17.529805: Verificando registros do arquivo 201808_Licitacao.csv
# 2019-09-12 10:20:18.016504: Resultado: Normais = 18808 - Corrigidas = 0
# 2019-09-12 10:20:18.016504: Verificando registros do arquivo 201808_ParticipantesLicitacao.csv
# 2019-09-12 10:20:30.546754: Resultado: Normais = 761130 - Corrigidas = 0
# 2019-09-12 10:20:30.546754: Verificando registros do arquivo 201809_ItemLicitacao.csv
# 2019-09-12 10:20:32.051727: Resultado: Normais = 125796 - Corrigidas = 0
# 2019-09-12 10:20:32.051727: Verificando registros do arquivo 201809_Licitacao.csv
# 2019-09-12 10:20:32.352918: Resultado: Normais = 16758 - Corrigidas = 0
# 2019-09-12 10:20:32.352918: Verificando registros do arquivo 201809_ParticipantesLicitacao.csv
# 2019-09-12 10:20:41.722848: Resultado: Normais = 656463 - Corrigidas = 0
# 2019-09-12 10:20:41.722848: Verificando registros do arquivo 201810_ItemLicitacao.csv
# 2019-09-12 10:20:43.967841: Resultado: Normais = 165531 - Corrigidas = 0
# 2019-09-12 10:20:43.967841: Verificando registros do arquivo 201810_Licitacao.csv
# 2019-09-12 10:20:44.401042: Resultado: Normais = 22057 - Corrigidas = 0
# 2019-09-12 10:20:44.401042: Verificando registros do arquivo 201810_ParticipantesLicitacao.csv
# 2019-09-12 10:20:57.105446: Resultado: Normais = 879960 - Corrigidas = 0
# 2019-09-12 10:20:57.105446: Verificando registros do arquivo 201811_ItemLicitacao.csv
# 2019-09-12 10:20:59.541928: Resultado: Normais = 177930 - Corrigidas = 0
# 2019-09-12 10:20:59.541928: Verificando registros do arquivo 201811_Licitacao.csv
# 2019-09-12 10:21:00.083483: Resultado: Normais = 23670 - Corrigidas = 0
# 2019-09-12 10:21:00.083483: Verificando registros do arquivo 201811_ParticipantesLicitacao.csv
# 2019-09-12 10:21:12.782923: Resultado: Normais = 901553 - Corrigidas = 0
# 2019-09-12 10:21:12.782923: Verificando registros do arquivo 201812_ItemLicitacao.csv
# 2019-09-12 10:21:14.840383: Resultado: Normais = 156213 - Corrigidas = 0
# 2019-09-12 10:21:14.841381: Verificando registros do arquivo 201812_Licitacao.csv
# 2019-09-12 10:21:15.247294: Resultado: Normais = 16074 - Corrigidas = 0
# 2019-09-12 10:21:15.247294: Verificando registros do arquivo 201812_ParticipantesLicitacao.csv
# 2019-09-12 10:21:26.364015: Resultado: Normais = 818393 - Corrigidas = 0
# 2019-09-12 10:21:26.364015: Verificando registros do arquivo 201901_ItemLicitacao.csv
# 2019-09-12 10:21:27.147950: Resultado: Normais = 64905 - Corrigidas = 0
# 2019-09-12 10:21:27.147950: Verificando registros do arquivo 201901_Licitacao.csv
# 2019-09-12 10:21:27.253633: Resultado: Normais = 5799 - Corrigidas = 0
# 2019-09-12 10:21:27.253633: Verificando registros do arquivo 201901_ParticipantesLicitacao.csv
# 2019-09-12 10:21:31.949072: Resultado: Normais = 388578 - Corrigidas = 0
# 2019-09-12 10:21:31.950069: Verificando registros do arquivo 201902_ItemLicitacao.csv
# 2019-09-12 10:21:32.873596: Resultado: Normais = 79864 - Corrigidas = 0
# 2019-09-12 10:21:32.874598: Verificando registros do arquivo 201902_Licitacao.csv
# 2019-09-12 10:21:33.108966: Resultado: Normais = 9996 - Corrigidas = 0
# 2019-09-12 10:21:33.109967: Verificando registros do arquivo 201902_ParticipantesLicitacao.csv
# 2019-09-12 10:21:38.796748: Resultado: Normais = 444393 - Corrigidas = 0
# 2019-09-12 10:21:38.796748: Verificando registros do arquivo 201903_ItemLicitacao.csv
# 2019-09-12 10:21:39.744211: Resultado: Normais = 79408 - Corrigidas = 0
# 2019-09-12 10:21:39.744211: Verificando registros do arquivo 201903_Licitacao.csv
# 2019-09-12 10:21:39.949661: Resultado: Normais = 10064 - Corrigidas = 0
# 2019-09-12 10:21:39.949661: Verificando registros do arquivo 201903_ParticipantesLicitacao.csv
# 2019-09-12 10:21:45.704266: Resultado: Normais = 456608 - Corrigidas = 0
# 2019-09-12 10:21:45.704266: Verificando registros do arquivo 201904_ItemLicitacao.csv
# 2019-09-12 10:21:47.223201: Resultado: Normais = 110801 - Corrigidas = 0
# 2019-09-12 10:21:47.223201: Verificando registros do arquivo 201904_Licitacao.csv
# 2019-09-12 10:21:47.591217: Resultado: Normais = 12749 - Corrigidas = 0
# 2019-09-12 10:21:47.591217: Verificando registros do arquivo 201904_ParticipantesLicitacao.csv
# 2019-09-12 10:21:56.371727: Resultado: Normais = 630394 - Corrigidas = 0
# 2019-09-12 10:21:56.371727: Verificando registros do arquivo 201905_ItemLicitacao.csv
# 2019-09-12 10:21:56.618069: Resultado: Normais = 14171 - Corrigidas = 0
# 2019-09-12 10:21:56.618069: Verificando registros do arquivo 201905_Licitacao.csv
# 2019-09-12 10:21:56.652969: Resultado: Normais = 1384 - Corrigidas = 0
# 2019-09-12 10:21:56.653966: Verificando registros do arquivo 201905_ParticipantesLicitacao.csv
# 2019-09-12 10:21:57.703157: Resultado: Normais = 83575 - Corrigidas = 0
# 2019-09-12 10:21:57.704156: Organizacao dos arquivos finalizada.
