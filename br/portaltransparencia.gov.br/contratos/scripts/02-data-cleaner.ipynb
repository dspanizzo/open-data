# %%
import os
import codecs
from datetime import datetime

# %%
def encode_to_utf8(**kwargs):
    """
    Funcao para padronizar a codificacao dos arquivos originais em UTF-8.
    Facilita a futura leitura dos arquivos e elimina caracteres desconhecidos.
    
    Args:
        original_encode(str): Codificacao original do arquivo.
                              Ex.: 'cp1252'
        in_data_path(str): Caminho completo para acesso ao arquivo original.
                           Ex.: '..\data\01-collected\2012_Funcoes.csv'
        out_data_path(str): Caminho completo para escrita do arquivo codificado
                            em UTF-8.
                            Ex.: '..\data\02-cleaned\2012_Funcoes.csv'
    """
    
    # Log: Mensagem de inicio da codificacao
    print(str(datetime.now()) + ': Inicio da codificacao do arquivo ' + kwargs['in_data_path'])
    
    # Le arquivo na codificacao original
    with codecs.open(kwargs['in_data_path'], 'rb', encoding = kwargs['original_encode'], errors = 'replace') as file:
        
        # Substitui os caracteres desconhecidos por interrogacao
        lines = file.read().replace('\x1a', '?').replace('\u0085', '?')

    # Escreve o arquivo codificado em UTF-8
    with codecs.open(kwargs['out_data_path'], 'w', encoding = 'utf-8') as file:
        file.write(lines)
    
    # Log: Mensagem de termino da codificacao
    print(str(datetime.now()) + ': Fim da codificacao do arquivo '+ kwargs['out_data_path'])

# %%
def clean_files():
    """
    Funcao para limpar os arquivos coletados, codificando em UTF-8 e elimando caracteres desconhecidos.
    """
    
    # Prepara o dicionario de variaveis (kwargs = keyworded arguments)
    kwargs = {}
    
    # Diretorio de armazenamento dos arquivos originais
    kwargs['in_data_dir'] = '..\\data\\01-collected'
    
    # Diretorio de armazenamento dos arquivos tratados
    kwargs['out_data_dir'] = '..\\data\\02-cleaned'
    
    # Codificacao dos arquivos originais
    kwargs['original_encode'] = 'latin-1'

    # Lista dos arquivos originais 
    kwargs['data_files'] = os.listdir(kwargs['in_data_dir'])
    
    # Log: Mensagem de inicio do processo 
    print(str(datetime.now()) + ': Limpeza dos arquivos iniciada.')

    # Para cada arquivo na lista de arquivos originais
    for file in kwargs['data_files']:

        # Define o caminho completo de acesso e escrita dos arquivos
        kwargs['data_file'] = file
        kwargs['in_data_path'] = os.path.join(kwargs['in_data_dir'], kwargs['data_file'])
        kwargs['out_data_path'] = os.path.join(kwargs['out_data_dir'], kwargs['data_file'])
        
        # Codifica o arquivo original em UTF-8
        encode_to_utf8(**kwargs)
      
    # Log: Mensagem de finalizacao do processo
    print(str(datetime.now()) + ': Limpeza dos arquivos finalizada.')

# %%
def main():
    """
    Limpa os dados de Contratos do Governo Federal (Contratos).
    Origem: Portal da Transparencia 
    """
        
    ### Limpa os arquivos
    clean_files()

if __name__ == '__main__':
    main()
# Out:
# 2020-01-03 11:30:28.982813: Limpeza dos arquivos iniciada.
# 2020-01-03 11:30:28.982813: Inicio da codificacao do arquivo ..\data\01-collected\201901_Apostilamento.csv
# 2020-01-03 11:30:28.987801: Fim da codificacao do arquivo ..\data\02-cleaned\201901_Apostilamento.csv
# 2020-01-03 11:30:28.988800: Inicio da codificacao do arquivo ..\data\01-collected\201901_Compras.csv
# 2020-01-03 11:30:29.001764: Fim da codificacao do arquivo ..\data\02-cleaned\201901_Compras.csv
# 2020-01-03 11:30:29.002772: Inicio da codificacao do arquivo ..\data\01-collected\201901_ItemCompra.csv
# 2020-01-03 11:30:29.007753: Fim da codificacao do arquivo ..\data\02-cleaned\201901_ItemCompra.csv
# 2020-01-03 11:30:29.007753: Inicio da codificacao do arquivo ..\data\01-collected\201901_TermoAditivo.csv
# 2020-01-03 11:30:29.010738: Fim da codificacao do arquivo ..\data\02-cleaned\201901_TermoAditivo.csv
# 2020-01-03 11:30:29.010738: Inicio da codificacao do arquivo ..\data\01-collected\201902_Apostilamento.csv
# 2020-01-03 11:30:29.013732: Fim da codificacao do arquivo ..\data\02-cleaned\201902_Apostilamento.csv
# 2020-01-03 11:30:29.014731: Inicio da codificacao do arquivo ..\data\01-collected\201902_Compras.csv
# 2020-01-03 11:30:29.021708: Fim da codificacao do arquivo ..\data\02-cleaned\201902_Compras.csv
# 2020-01-03 11:30:29.022706: Inicio da codificacao do arquivo ..\data\01-collected\201902_ItemCompra.csv
# 2020-01-03 11:30:29.029724: Fim da codificacao do arquivo ..\data\02-cleaned\201902_ItemCompra.csv
# 2020-01-03 11:30:29.029724: Inicio da codificacao do arquivo ..\data\01-collected\201902_TermoAditivo.csv
# 2020-01-03 11:30:29.032680: Fim da codificacao do arquivo ..\data\02-cleaned\201902_TermoAditivo.csv
# 2020-01-03 11:30:29.032680: Inicio da codificacao do arquivo ..\data\01-collected\201903_Apostilamento.csv
# 2020-01-03 11:30:29.059609: Fim da codificacao do arquivo ..\data\02-cleaned\201903_Apostilamento.csv
# 2020-01-03 11:30:29.059609: Inicio da codificacao do arquivo ..\data\01-collected\201903_Compras.csv
# 2020-01-03 11:30:29.066592: Fim da codificacao do arquivo ..\data\02-cleaned\201903_Compras.csv
# 2020-01-03 11:30:29.066592: Inicio da codificacao do arquivo ..\data\01-collected\201903_ItemCompra.csv
# 2020-01-03 11:30:29.080553: Fim da codificacao do arquivo ..\data\02-cleaned\201903_ItemCompra.csv
# 2020-01-03 11:30:29.080553: Inicio da codificacao do arquivo ..\data\01-collected\201903_TermoAditivo.csv
# 2020-01-03 11:30:29.093516: Fim da codificacao do arquivo ..\data\02-cleaned\201903_TermoAditivo.csv
# 2020-01-03 11:30:29.093516: Inicio da codificacao do arquivo ..\data\01-collected\201904_Apostilamento.csv
# 2020-01-03 11:30:29.100499: Fim da codificacao do arquivo ..\data\02-cleaned\201904_Apostilamento.csv
# 2020-01-03 11:30:29.100499: Inicio da codificacao do arquivo ..\data\01-collected\201904_Compras.csv
# 2020-01-03 11:30:29.107482: Fim da codificacao do arquivo ..\data\02-cleaned\201904_Compras.csv
# 2020-01-03 11:30:29.108478: Inicio da codificacao do arquivo ..\data\01-collected\201904_ItemCompra.csv
# 2020-01-03 11:30:29.119448: Fim da codificacao do arquivo ..\data\02-cleaned\201904_ItemCompra.csv
# 2020-01-03 11:30:29.119448: Inicio da codificacao do arquivo ..\data\01-collected\201904_TermoAditivo.csv
# 2020-01-03 11:30:29.127427: Fim da codificacao do arquivo ..\data\02-cleaned\201904_TermoAditivo.csv
# 2020-01-03 11:30:29.127427: Inicio da codificacao do arquivo ..\data\01-collected\201905_Apostilamento.csv
# 2020-01-03 11:30:29.130419: Fim da codificacao do arquivo ..\data\02-cleaned\201905_Apostilamento.csv
# 2020-01-03 11:30:29.130419: Inicio da codificacao do arquivo ..\data\01-collected\201905_Compras.csv
# 2020-01-03 11:30:29.138397: Fim da codificacao do arquivo ..\data\02-cleaned\201905_Compras.csv
# 2020-01-03 11:30:29.139395: Inicio da codificacao do arquivo ..\data\01-collected\201905_ItemCompra.csv
# 2020-01-03 11:30:29.143383: Fim da codificacao do arquivo ..\data\02-cleaned\201905_ItemCompra.csv
# 2020-01-03 11:30:29.143383: Inicio da codificacao do arquivo ..\data\01-collected\201905_TermoAditivo.csv
# 2020-01-03 11:30:29.146375: Fim da codificacao do arquivo ..\data\02-cleaned\201905_TermoAditivo.csv
# 2020-01-03 11:30:29.146375: Inicio da codificacao do arquivo ..\data\01-collected\201906_Apostilamento.csv
# 2020-01-03 11:30:29.149402: Fim da codificacao do arquivo ..\data\02-cleaned\201906_Apostilamento.csv
# 2020-01-03 11:30:29.149402: Inicio da codificacao do arquivo ..\data\01-collected\201906_Compras.csv
# 2020-01-03 11:30:29.158345: Fim da codificacao do arquivo ..\data\02-cleaned\201906_Compras.csv
# 2020-01-03 11:30:29.158345: Inicio da codificacao do arquivo ..\data\01-collected\201906_ItemCompra.csv
# 2020-01-03 11:30:29.172307: Fim da codificacao do arquivo ..\data\02-cleaned\201906_ItemCompra.csv
# 2020-01-03 11:30:29.172307: Inicio da codificacao do arquivo ..\data\01-collected\201906_TermoAditivo.csv
# 2020-01-03 11:30:29.177296: Fim da codificacao do arquivo ..\data\02-cleaned\201906_TermoAditivo.csv
# 2020-01-03 11:30:29.178291: Inicio da codificacao do arquivo ..\data\01-collected\201907_Apostilamento.csv
# 2020-01-03 11:30:29.183277: Fim da codificacao do arquivo ..\data\02-cleaned\201907_Apostilamento.csv
# 2020-01-03 11:30:29.183277: Inicio da codificacao do arquivo ..\data\01-collected\201907_Compras.csv
# 2020-01-03 11:30:29.194276: Fim da codificacao do arquivo ..\data\02-cleaned\201907_Compras.csv
# 2020-01-03 11:30:29.194276: Inicio da codificacao do arquivo ..\data\01-collected\201907_ItemCompra.csv
# 2020-01-03 11:30:29.198237: Fim da codificacao do arquivo ..\data\02-cleaned\201907_ItemCompra.csv
# 2020-01-03 11:30:29.198237: Inicio da codificacao do arquivo ..\data\01-collected\201907_TermoAditivo.csv
# 2020-01-03 11:30:29.201256: Fim da codificacao do arquivo ..\data\02-cleaned\201907_TermoAditivo.csv
# 2020-01-03 11:30:29.201256: Inicio da codificacao do arquivo ..\data\01-collected\201908_Apostilamento.csv
# 2020-01-03 11:30:29.205252: Fim da codificacao do arquivo ..\data\02-cleaned\201908_Apostilamento.csv
# 2020-01-03 11:30:29.205252: Inicio da codificacao do arquivo ..\data\01-collected\201908_Compras.csv
# 2020-01-03 11:30:29.213196: Fim da codificacao do arquivo ..\data\02-cleaned\201908_Compras.csv
# 2020-01-03 11:30:29.213196: Inicio da codificacao do arquivo ..\data\01-collected\201908_ItemCompra.csv
# 2020-01-03 11:30:29.216226: Fim da codificacao do arquivo ..\data\02-cleaned\201908_ItemCompra.csv
# 2020-01-03 11:30:29.216226: Inicio da codificacao do arquivo ..\data\01-collected\201908_TermoAditivo.csv
# 2020-01-03 11:30:29.221177: Fim da codificacao do arquivo ..\data\02-cleaned\201908_TermoAditivo.csv
# 2020-01-03 11:30:29.221177: Inicio da codificacao do arquivo ..\data\01-collected\201909_Apostilamento.csv
# 2020-01-03 11:30:29.225165: Fim da codificacao do arquivo ..\data\02-cleaned\201909_Apostilamento.csv
# 2020-01-03 11:30:29.225165: Inicio da codificacao do arquivo ..\data\01-collected\201909_Compras.csv
# 2020-01-03 11:30:29.233144: Fim da codificacao do arquivo ..\data\02-cleaned\201909_Compras.csv
# 2020-01-03 11:30:29.233144: Inicio da codificacao do arquivo ..\data\01-collected\201909_ItemCompra.csv
# 2020-01-03 11:30:29.238130: Fim da codificacao do arquivo ..\data\02-cleaned\201909_ItemCompra.csv
# 2020-01-03 11:30:29.238130: Inicio da codificacao do arquivo ..\data\01-collected\201909_TermoAditivo.csv
# 2020-01-03 11:30:29.242121: Fim da codificacao do arquivo ..\data\02-cleaned\201909_TermoAditivo.csv
# 2020-01-03 11:30:29.242121: Inicio da codificacao do arquivo ..\data\01-collected\201910_Apostilamento.csv
# 2020-01-03 11:30:29.245111: Fim da codificacao do arquivo ..\data\02-cleaned\201910_Apostilamento.csv
# 2020-01-03 11:30:29.245111: Inicio da codificacao do arquivo ..\data\01-collected\201910_Compras.csv
# 2020-01-03 11:30:29.258114: Fim da codificacao do arquivo ..\data\02-cleaned\201910_Compras.csv
# 2020-01-03 11:30:29.259078: Inicio da codificacao do arquivo ..\data\01-collected\201910_ItemCompra.csv
# 2020-01-03 11:30:29.264062: Fim da codificacao do arquivo ..\data\02-cleaned\201910_ItemCompra.csv
# 2020-01-03 11:30:29.264062: Inicio da codificacao do arquivo ..\data\01-collected\201910_TermoAditivo.csv
# 2020-01-03 11:30:29.268050: Fim da codificacao do arquivo ..\data\02-cleaned\201910_TermoAditivo.csv
# 2020-01-03 11:30:29.268050: Inicio da codificacao do arquivo ..\data\01-collected\201911_Apostilamento.csv
# 2020-01-03 11:30:29.273081: Fim da codificacao do arquivo ..\data\02-cleaned\201911_Apostilamento.csv
# 2020-01-03 11:30:29.273081: Inicio da codificacao do arquivo ..\data\01-collected\201911_Compras.csv
# 2020-01-03 11:30:29.293980: Fim da codificacao do arquivo ..\data\02-cleaned\201911_Compras.csv
# 2020-01-03 11:30:29.294978: Inicio da codificacao do arquivo ..\data\01-collected\201911_ItemCompra.csv
# 2020-01-03 11:30:29.306946: Fim da codificacao do arquivo ..\data\02-cleaned\201911_ItemCompra.csv
# 2020-01-03 11:30:29.307943: Inicio da codificacao do arquivo ..\data\01-collected\201911_TermoAditivo.csv
# 2020-01-03 11:30:29.310970: Fim da codificacao do arquivo ..\data\02-cleaned\201911_TermoAditivo.csv
# 2020-01-03 11:30:29.311934: Inicio da codificacao do arquivo ..\data\01-collected\201912_Apostilamento.csv
# 2020-01-03 11:30:29.313928: Fim da codificacao do arquivo ..\data\02-cleaned\201912_Apostilamento.csv
# 2020-01-03 11:30:29.313928: Inicio da codificacao do arquivo ..\data\01-collected\201912_Compras.csv
# 2020-01-03 11:30:29.319913: Fim da codificacao do arquivo ..\data\02-cleaned\201912_Compras.csv
# 2020-01-03 11:30:29.319913: Inicio da codificacao do arquivo ..\data\01-collected\201912_ItemCompra.csv
# 2020-01-03 11:30:29.323900: Fim da codificacao do arquivo ..\data\02-cleaned\201912_ItemCompra.csv
# 2020-01-03 11:30:29.323900: Inicio da codificacao do arquivo ..\data\01-collected\201912_TermoAditivo.csv
# 2020-01-03 11:30:29.326894: Fim da codificacao do arquivo ..\data\02-cleaned\201912_TermoAditivo.csv
# 2020-01-03 11:30:29.326894: Limpeza dos arquivos finalizada.
