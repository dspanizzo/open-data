# %%
import os
import codecs
from datetime import datetime

# %%
def encode_to_utf8(**kwargs):
    """
    Funcao para padronizar a codificacao dos arquivos originais em UTF-8.
    Facilita a futura leitura dos arquivos e elimina caracteres desconhecidos.
    
    Args:
        original_encode(str): Codificacao original do arquivo.
                              Ex.: 'cp1252'
        in_data_path(str): Caminho completo para acesso ao arquivo original.
                           Ex.: '..\data\01-collected\2012_Funcoes.csv'
        out_data_path(str): Caminho completo para escrita do arquivo codificado
                            em UTF-8.
                            Ex.: '..\data\02-cleaned\2012_Funcoes.csv'
    """
    
    # Log: Mensagem de inicio da codificacao
    print(str(datetime.now()) + ': Inicio da codificacao do arquivo ' + kwargs['in_data_path'])
    
    # Le arquivo na codificacao original
    with codecs.open(kwargs['in_data_path'], 'rb', encoding = kwargs['original_encode'], errors = 'replace') as file:
        
        # Substitui os caracteres desconhecidos por interrogacao
        lines = file.read().replace('\x1a', '?').replace('\u0085', '?')

    # Escreve o arquivo codificado em UTF-8
    with codecs.open(kwargs['out_data_path'], 'w', encoding = 'utf-8') as file:
        file.write(lines)
    
    # Log: Mensagem de termino da codificacao
    print(str(datetime.now()) + ': Fim da codificacao do arquivo '+ kwargs['out_data_path'])

# %%
def clean_files():
    """
    Funcao para limpar os arquivos coletados, codificando em UTF-8 e elimando caracteres desconhecidos.
    """
    
    # Prepara o dicionario de variaveis (kwargs = keyworded arguments)
    kwargs = {}
    
    # Diretorio de armazenamento dos arquivos originais
    kwargs['in_data_dir'] = '..\\data\\01-collected'
    
    # Diretorio de armazenamento dos arquivos tratados
    kwargs['out_data_dir'] = '..\\data\\02-cleaned'
    
    # Codificacao dos arquivos originais
    kwargs['original_encode'] = 'latin-1'

    # Lista dos arquivos originais 
    kwargs['data_files'] = os.listdir(kwargs['in_data_dir'])
    
    # Log: Mensagem de inicio do processo 
    print(str(datetime.now()) + ': Limpeza dos arquivos iniciada.')

    # Para cada arquivo na lista de arquivos originais
    for file in kwargs['data_files']:

        # Define o caminho completo de acesso e escrita dos arquivos
        kwargs['data_file'] = file
        kwargs['in_data_path'] = os.path.join(kwargs['in_data_dir'], kwargs['data_file'])
        kwargs['out_data_path'] = os.path.join(kwargs['out_data_dir'], kwargs['data_file'])
        
        # Codifica o arquivo original em UTF-8
        encode_to_utf8(**kwargs)
      
    # Log: Mensagem de finalizacao do processo
    print(str(datetime.now()) + ': Limpeza dos arquivos finalizada.')

# %%
def main():
    """
    Limpa os dados de resultados das eleicoes por candidato, municipio e zona. 
    Origem: Tribunal Superior Eleitoral (TSE) 
    """
        
    ### Limpa os arquivos
    clean_files()

if __name__ == '__main__':
    main()
# Out:
# 2020-08-06 16:45:41.478416: Limpeza dos arquivos iniciada.
# 2020-08-06 16:45:41.478416: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_AC.csv
# 2020-08-06 16:45:41.492868: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_AC.csv
# 2020-08-06 16:45:41.493020: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_AL.csv
# 2020-08-06 16:45:41.515914: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_AL.csv
# 2020-08-06 16:45:41.516167: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_AM.csv
# 2020-08-06 16:45:41.558879: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_AM.csv
# 2020-08-06 16:45:41.559933: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_AP.csv
# 2020-08-06 16:45:41.566880: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_AP.csv
# 2020-08-06 16:45:41.567253: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_BA.csv
# 2020-08-06 16:45:41.675365: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_BA.csv
# 2020-08-06 16:45:41.678097: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_BRASIL.csv
# 2020-08-06 16:45:43.780738: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_BRASIL.csv
# 2020-08-06 16:45:43.820519: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_CE.csv
# 2020-08-06 16:45:43.870632: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_CE.csv
# 2020-08-06 16:45:43.872629: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_ES.csv
# 2020-08-06 16:45:43.898871: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_ES.csv
# 2020-08-06 16:45:43.899555: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_GO.csv
# 2020-08-06 16:45:43.954112: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_GO.csv
# 2020-08-06 16:45:43.956130: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_MA.csv
# 2020-08-06 16:45:43.999616: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_MA.csv
# 2020-08-06 16:45:44.002151: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_MG.csv
# 2020-08-06 16:45:44.232619: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_MG.csv
# 2020-08-06 16:45:44.237619: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_MS.csv
# 2020-08-06 16:45:44.259627: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_MS.csv
# 2020-08-06 16:45:44.260938: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_MT.csv
# 2020-08-06 16:45:44.285591: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_MT.csv
# 2020-08-06 16:45:44.285591: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_PA.csv
# 2020-08-06 16:45:44.342097: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_PA.csv
# 2020-08-06 16:45:44.344092: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_PB.csv
# 2020-08-06 16:45:44.371664: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_PB.csv
# 2020-08-06 16:45:44.371925: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_PE.csv
# 2020-08-06 16:45:44.431829: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_PE.csv
# 2020-08-06 16:45:44.433780: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_PI.csv
# 2020-08-06 16:45:44.461750: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_PI.csv
# 2020-08-06 16:45:44.462702: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_PR.csv
# 2020-08-06 16:45:44.547640: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_PR.csv
# 2020-08-06 16:45:44.550641: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_RJ.csv
# 2020-08-06 16:45:45.033619: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_RJ.csv
# 2020-08-06 16:45:45.043664: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_RN.csv
# 2020-08-06 16:45:45.070596: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_RN.csv
# 2020-08-06 16:45:45.071589: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_RO.csv
# 2020-08-06 16:45:45.087092: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_RO.csv
# 2020-08-06 16:45:45.087092: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_RR.csv
# 2020-08-06 16:45:45.093357: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_RR.csv
# 2020-08-06 16:45:45.093357: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_RS.csv
# 2020-08-06 16:45:45.179605: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_RS.csv
# 2020-08-06 16:45:45.182597: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_SC.csv
# 2020-08-06 16:45:45.225915: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_SC.csv
# 2020-08-06 16:45:45.226914: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_SE.csv
# 2020-08-06 16:45:45.246620: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_SE.csv
# 2020-08-06 16:45:45.247267: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_SP.csv
# 2020-08-06 16:45:45.683226: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_SP.csv
# 2020-08-06 16:45:45.689197: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2016_TO.csv
# 2020-08-06 16:45:45.704228: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2016_TO.csv
# 2020-08-06 16:45:45.705182: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_AC.csv
# 2020-08-06 16:45:45.723331: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_AC.csv
# 2020-08-06 16:45:45.724285: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_AL.csv
# 2020-08-06 16:45:45.788331: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_AL.csv
# 2020-08-06 16:45:45.789840: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_AM.csv
# 2020-08-06 16:45:45.877724: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_AM.csv
# 2020-08-06 16:45:45.880750: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_AP.csv
# 2020-08-06 16:45:45.898776: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_AP.csv
# 2020-08-06 16:45:45.899752: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_BA.csv
# 2020-08-06 16:45:46.829718: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_BA.csv
# 2020-08-06 16:45:46.848667: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_BR.csv
# 2020-08-06 16:45:47.025045: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_BR.csv
# 2020-08-06 16:45:47.028832: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_BRASIL.csv
# 2020-08-06 16:46:09.223873: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_BRASIL.csv
# 2020-08-06 16:46:09.583626: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_CE.csv
# 2020-08-06 16:46:10.367139: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_CE.csv
# 2020-08-06 16:46:10.375877: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_DF.csv
# 2020-08-06 16:46:10.421850: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_DF.csv
# 2020-08-06 16:46:10.423359: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_ES.csv
# 2020-08-06 16:46:10.642636: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_ES.csv
# 2020-08-06 16:46:10.645624: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_GO.csv
# 2020-08-06 16:46:11.925317: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_GO.csv
# 2020-08-06 16:46:11.941747: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_MA.csv
# 2020-08-06 16:46:12.652799: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_MA.csv
# 2020-08-06 16:46:12.663774: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_MG.csv
# 2020-08-06 16:46:17.506504: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_MG.csv
# 2020-08-06 16:46:17.583683: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_MS.csv
# 2020-08-06 16:46:17.667721: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_MS.csv
# 2020-08-06 16:46:17.669577: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_MT.csv
# 2020-08-06 16:46:17.886162: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_MT.csv
# 2020-08-06 16:46:17.888512: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_PA.csv
# 2020-08-06 16:46:18.475155: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_PA.csv
# 2020-08-06 16:46:18.481139: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_PB.csv
# 2020-08-06 16:46:19.007673: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_PB.csv
# 2020-08-06 16:46:19.014289: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_PE.csv
# 2020-08-06 16:46:20.058692: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_PE.csv
# 2020-08-06 16:46:20.069883: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_PI.csv
# 2020-08-06 16:46:20.385301: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_PI.csv
# 2020-08-06 16:46:20.389355: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_PR.csv
# 2020-08-06 16:46:22.913008: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_PR.csv
# 2020-08-06 16:46:22.934247: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_RJ.csv
# 2020-08-06 16:46:24.722645: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_RJ.csv
# 2020-08-06 16:46:24.747579: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_RN.csv
# 2020-08-06 16:46:24.935458: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_RN.csv
# 2020-08-06 16:46:24.941740: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_RO.csv
# 2020-08-06 16:46:24.995335: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_RO.csv
# 2020-08-06 16:46:24.996657: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_RR.csv
# 2020-08-06 16:46:25.008628: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_RR.csv
# 2020-08-06 16:46:25.008997: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_RS.csv
# 2020-08-06 16:46:26.806488: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_RS.csv
# 2020-08-06 16:46:26.839980: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_SC.csv
# 2020-08-06 16:46:27.356848: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_SC.csv
# 2020-08-06 16:46:27.372707: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_SE.csv
# 2020-08-06 16:46:27.435960: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_SE.csv
# 2020-08-06 16:46:27.436958: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_SP.csv
# 2020-08-06 16:46:35.707229: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_SP.csv
# 2020-08-06 16:46:35.822006: Inicio da codificacao do arquivo ..\data\01-collected\votacao_candidato_munzona_2018_TO.csv
# 2020-08-06 16:46:35.932951: Fim da codificacao do arquivo ..\data\02-cleaned\votacao_candidato_munzona_2018_TO.csv
# 2020-08-06 16:46:35.935552: Limpeza dos arquivos finalizada.
