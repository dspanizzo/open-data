# %%
import os
import codecs
from datetime import datetime

# %%
def join_lines(**kwargs):
    """
    Le o arquivo de entrada, caso algum dos registros tenha quantidade de colunas diferente
    do cabecalho, a linha seguinte e concatenada com a atual e escrita no arquivo de saida.
    """
    
    # Log: Mensagem de inicio da verificacao dos registros
    print(str(datetime.now()) + ': Verificando registros do arquivo ' + kwargs['data_file'])
    
    # Le o arquivo de entrada
    with codecs.open(kwargs['in_data_path'], 'r', encoding = 'utf-8') as reader:
        
        # Prepara o arquivo de saida
        with codecs.open(kwargs['out_data_path'], 'w', encoding = 'utf-8') as writer:
            
            # Armazena o header do arquivo de entrada
            header = reader.readline()
            
            # Conta a quantidade de colunas no header
            qt_columns = header.count('\";\"')
            
            # Define os contadores
            qt_lines = 0
            qt_joins = 0
            
            # Escreve o cabecalho no arquivo de saida
            writer.write(header)
            
            # Para cada linha no arquivo de entrada
            for line in reader:
                
                # Escreve o registro do arquivo de entrada no arquivo de saida 
                # Caso o registro tenha quantidade de colunas diferente do cabecalho
                # a linha seguinte e concatenada com a atual
                if line.count('\";\"') != qt_columns:
                    qt_joins += 1
                    writer.write(line.replace("\r\n", "") + reader.readline())
                else:
                    qt_lines += 1
                    writer.write(line)
                    
    # Log: Resultado da verificacao dos registros
    print(str(datetime.now()) + ': Resultado: Normais = ' + str(qt_lines) + ' - Corrigidas = ' + str(qt_joins))

# %%
def organize_files():
    """
    Para cada arquivo de origem, e verificado se a quantidade de colunas de cada registro corresponde
    com a quantidade de colunas do cabecalho do arquivo.        
    """
    
    # Prepara o dicionario de variaveis (kwargs = keyworded arguments)
    kwargs = {}
    
    # Diretorio de armazenamento dos arquivos originais
    kwargs['in_data_dir'] = '..\\data\\02-cleaned'
    
    # Diretorio de armazenamento dos arquivos tratados
    kwargs['out_data_dir'] = '..\\data\\03-organized'
    
    # Lista dos arquivos originais 
    kwargs['data_files'] = os.listdir(kwargs['in_data_dir'])
    
    # Log: Mensagem de inicio do processo 
    print(str(datetime.now()) + ': Organizacao dos arquivos iniciada.')
    
    # Para cada arquivo na lista de arquivos originais
    for file in kwargs['data_files']:
        
        # Define o caminho completo de acesso e escrita dos arquivos
        kwargs['data_file'] = file
        kwargs['in_data_path'] = os.path.join(kwargs['in_data_dir'], kwargs['data_file'])
        kwargs['out_data_path'] = os.path.join(kwargs['out_data_dir'], kwargs['data_file'])
        
        # Corrige registros com menos colunas que o esperado
        join_lines(**kwargs)
      
    # Log: Mensagem de finalizacao do processo de limpeza
    print(str(datetime.now()) + ': Organizacao dos arquivos finalizada.')

# %%
def main():
    """
    Organiza os dados de resultados das eleicoes por candidato, municipio e zona. 
    Origem: Tribunal Superior Eleitoral (TSE)
    """
    
    ### Organiza os arquivos
    organize_files()

if __name__ == '__main__':
    main()
# Out:
# 2020-08-06 16:50:31.723191: Organizacao dos arquivos iniciada.
# 2020-08-06 16:50:31.723873: Verificando registros do arquivo votacao_candidato_munzona_2018_AC.csv
# 2020-08-06 16:50:31.934611: Resultado: Normais = 12397 - Corrigidas = 0
# 2020-08-06 16:50:31.934611: Verificando registros do arquivo votacao_candidato_munzona_2018_AL.csv
# 2020-08-06 16:50:32.699895: Resultado: Normais = 44084 - Corrigidas = 0
# 2020-08-06 16:50:32.700210: Verificando registros do arquivo votacao_candidato_munzona_2018_AM.csv
# 2020-08-06 16:50:33.812136: Resultado: Normais = 56896 - Corrigidas = 0
# 2020-08-06 16:50:33.812408: Verificando registros do arquivo votacao_candidato_munzona_2018_AP.csv
# 2020-08-06 16:50:33.978298: Resultado: Normais = 9978 - Corrigidas = 0
# 2020-08-06 16:50:33.978886: Verificando registros do arquivo votacao_candidato_munzona_2018_BA.csv
# 2020-08-06 16:50:43.808005: Resultado: Normais = 493963 - Corrigidas = 0
# 2020-08-06 16:50:43.808520: Verificando registros do arquivo votacao_candidato_munzona_2018_BR.csv
# 2020-08-06 16:50:45.587662: Resultado: Normais = 94095 - Corrigidas = 0
# 2020-08-06 16:50:45.588945: Verificando registros do arquivo votacao_candidato_munzona_2018_BRASIL.csv
# 2020-08-06 16:54:04.901888: Resultado: Normais = 9061048 - Corrigidas = 0
# 2020-08-06 16:54:04.902239: Verificando registros do arquivo votacao_candidato_munzona_2018_CE.csv
# 2020-08-06 16:54:08.447792: Resultado: Normais = 172815 - Corrigidas = 0
# 2020-08-06 16:54:08.447792: Verificando registros do arquivo votacao_candidato_munzona_2018_DF.csv
# 2020-08-06 16:54:08.958271: Resultado: Normais = 21964 - Corrigidas = 0
# 2020-08-06 16:54:08.958796: Verificando registros do arquivo votacao_candidato_munzona_2018_ES.csv
# 2020-08-06 16:54:10.266171: Resultado: Normais = 65365 - Corrigidas = 0
# 2020-08-06 16:54:10.266343: Verificando registros do arquivo votacao_candidato_munzona_2018_GO.csv
# 2020-08-06 16:54:15.971213: Resultado: Normais = 271432 - Corrigidas = 0
# 2020-08-06 16:54:15.971641: Verificando registros do arquivo votacao_candidato_munzona_2018_MA.csv
# 2020-08-06 16:54:19.788656: Resultado: Normais = 157868 - Corrigidas = 0
# 2020-08-06 16:54:19.788656: Verificando registros do arquivo votacao_candidato_munzona_2018_MG.csv
# 2020-08-06 16:55:02.812479: Resultado: Normais = 1962549 - Corrigidas = 0
# 2020-08-06 16:55:02.812701: Verificando registros do arquivo votacao_candidato_munzona_2018_MS.csv
# 2020-08-06 16:55:03.622181: Resultado: Normais = 42240 - Corrigidas = 0
# 2020-08-06 16:55:03.623162: Verificando registros do arquivo votacao_candidato_munzona_2018_MT.csv
# 2020-08-06 16:55:04.969933: Resultado: Normais = 68912 - Corrigidas = 0
# 2020-08-06 16:55:04.970416: Verificando registros do arquivo votacao_candidato_munzona_2018_PA.csv
# 2020-08-06 16:55:07.685738: Resultado: Normais = 127991 - Corrigidas = 0
# 2020-08-06 16:55:07.686105: Verificando registros do arquivo votacao_candidato_munzona_2018_PB.csv
# 2020-08-06 16:55:10.334104: Resultado: Normais = 128529 - Corrigidas = 0
# 2020-08-06 16:55:10.334367: Verificando registros do arquivo votacao_candidato_munzona_2018_PE.csv
# 2020-08-06 16:55:15.307756: Resultado: Normais = 209627 - Corrigidas = 0
# 2020-08-06 16:55:15.308365: Verificando registros do arquivo votacao_candidato_munzona_2018_PI.csv
# 2020-08-06 16:55:17.447703: Resultado: Normais = 84410 - Corrigidas = 0
# 2020-08-06 16:55:17.448088: Verificando registros do arquivo votacao_candidato_munzona_2018_PR.csv
# 2020-08-06 16:55:29.317247: Resultado: Normais = 506940 - Corrigidas = 0
# 2020-08-06 16:55:29.317247: Verificando registros do arquivo votacao_candidato_munzona_2018_RJ.csv
# 2020-08-06 16:55:42.519334: Resultado: Normais = 640500 - Corrigidas = 0
# 2020-08-06 16:55:42.519334: Verificando registros do arquivo votacao_candidato_munzona_2018_RN.csv
# 2020-08-06 16:55:44.055317: Resultado: Normais = 78506 - Corrigidas = 0
# 2020-08-06 16:55:44.055602: Verificando registros do arquivo votacao_candidato_munzona_2018_RO.csv
# 2020-08-06 16:55:44.631907: Resultado: Normais = 28672 - Corrigidas = 0
# 2020-08-06 16:55:44.632322: Verificando registros do arquivo votacao_candidato_munzona_2018_RR.csv
# 2020-08-06 16:55:44.750477: Resultado: Normais = 5639 - Corrigidas = 0
# 2020-08-06 16:55:44.750477: Verificando registros do arquivo votacao_candidato_munzona_2018_RS.csv
# 2020-08-06 16:55:59.427127: Resultado: Normais = 658242 - Corrigidas = 0
# 2020-08-06 16:55:59.427459: Verificando registros do arquivo votacao_candidato_munzona_2018_SC.csv
# 2020-08-06 16:56:04.228539: Resultado: Normais = 221056 - Corrigidas = 0
# 2020-08-06 16:56:04.229524: Verificando registros do arquivo votacao_candidato_munzona_2018_SE.csv
# 2020-08-06 16:56:04.871310: Resultado: Normais = 33717 - Corrigidas = 0
# 2020-08-06 16:56:04.871310: Verificando registros do arquivo votacao_candidato_munzona_2018_SP.csv
# 2020-08-06 16:57:11.117251: Resultado: Normais = 2855918 - Corrigidas = 0
# 2020-08-06 16:57:11.117357: Verificando registros do arquivo votacao_candidato_munzona_2018_TO.csv
# 2020-08-06 16:57:12.027356: Resultado: Normais = 43820 - Corrigidas = 0
# 2020-08-06 16:57:12.027564: Organizacao dos arquivos finalizada.
