# %%
import os as os
import requests as req
import zipfile as zipfile
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
def data_directories():
    """
    Funcao de criacao das pastas para armazenamento dos dados, caso nao existam.
    
    """

    # Diretorios para armazenamento dos dados coletados
    directories = ['..\\data\\01-collected'
                  ,'..\\data\\02-cleaned'
                  ,'..\\data\\03-organized'
                  ,'..\\data\\04-standardized']
    
    # Log: Mensagem de inicio da criacao dos diretorios
    print(str(datetime.now()) + ': Criacao dos diretorios para armazenamento dos dados iniciada.')
    
    # Para cada diretorio na lista de diretorios
    for directory in directories:
        
        # Verifica se o diretorio existe
        if not os.path.exists(directory):
            
            # Cria o diretorio
            os.makedirs(directory)
            
            # Log: Mensagem de criacao do diretorio
            print(str(datetime.now()) + ': Diretorio ' + directory + ' criado.')
        
        else:
            
            # Log: Mensagem de diretorio existente
            print(str(datetime.now()) + ': Diretorio ' + directory + ' ja existe.')
    
    # Log: Mensagem de fim da criacao dos diretorios
    print(str(datetime.now()) + ': Criacao dos diretorios para armazenamento dos dados finalizada.')

# %%
def download_file(**kwargs):
    """
    Funcao que realiza o download do arquivo. Ao final do download, e verificado
    se o arquivo solicitado esta vazio. Caso esteja vazio, o arquivo e apagado. Caso contrario,
    o arquivo e descompactado.
    
    Args:
        url_query (str): URL parametrizada para download do arquivo.
        download_path (str): Caminho do diretorio onde sera salvo o arquivo.
        download_directory (str): Caminho do diretorio para decompactacao do arquivo
    """
    
    # Log: Mensagem de inicio do download do arquivo
    print(str(datetime.now()) + ': Inicio do download do arquivo ' + kwargs['download_path'])
    
    # Prepara a requisicao de download do arquivo
    res = req.get(kwargs['url_query'], stream = True)
    
    # Se for encontrada a URL para download
    if res.status_code == 200:
        
        # Faz o download do arquivo
        with open(kwargs['download_path'], 'wb') as f:
            
            # Log: Mensagem de URL encontrada e de inicio do download
            print(str(datetime.now()) + ': URL encontrada, fazendo o download do arquivo: ' + kwargs['download_path'])
            
            # Download do arquivo em pedacos
            for chunk in res.iter_content(chunk_size = 1024):
                f.write(chunk)
        
        # Verifica o tamanho do arquivo recebido
        file_size = os.stat(kwargs['download_path']).st_size
        
        # Se o tamanho do arquivo for muito 
        # pequeno remove o arquivo da pasta 
        if file_size <= 100:
            
            # Log: Mensagem de remocao por arquivo por nao conter dados
            print(str(datetime.now()) + ': Arquivo ' + kwargs['download_path'] + ' removido por conter poucos dados.')
            
            # Remove o arquivo sem dados
            os.remove(kwargs['download_path'])
            
        # Caso contrario, descompacta o arquivo csv 
        # na pasta e remove o arquivo compactado
        else:
            
            # Log: Mensagem de inicio da descompactacao do arquivo zip
            print(str(datetime.now()) + ': Descompactando o arquivo ' + kwargs['download_path'])
            
            # Descompacta o arquivo zip mantem apenas o csv
            zip_ref = zipfile.ZipFile(kwargs['download_path'], 'r')
            zip_ref.extractall(path=kwargs['download_directory'])
            zip_ref.close()
            os.remove(kwargs['download_path'])
            
            # log: Mensagem de finalizacao do download do arquivo
            print(str(datetime.now()) + ': Fim do download do arquivo ' + kwargs['download_path'])
            
    else:
        print(str(datetime.now()) + ': Nao foram encontrados arquivos referentes ao ano de ' + kwargs['file_date_ref'])

# %%
def collect_data(**kwargs):
    """
    Coleta os dados para cada ano de referencia dentro das datas de inicio e fim informadas.
    
    Args:
        dt_ini_ref (date): Data inicial para coleta dos dados
        dt_fim_ref (date): Data final para coleta dos dados
    """
    
    # Cria os diretorios para armazenamento dos dados
    data_directories()
    
    # Define a data de referencia inicial
    kwargs['dt_ref'] = kwargs['dt_ini_ref']
    
    # Define o diretorio para download dos arquivos
    kwargs['download_directory'] = '..\\data\\01-collected\\'
    
    # Define a URL base de busca dos arquivos para download
    kwargs['download_url'] = 'http://agencia.tse.jus.br/estatistica/sead/odsele/perfil_eleitorado/'
    
    # Define o nome e extensao do arquivo para download
    kwargs['file_name'] = 'perfil_eleitorado_'
    kwargs['file_ext'] = '.zip'
    
    # Log: Mensagem de inicio do processo 
    print(str(datetime.now()) + ': Coleta dos arquivos iniciada.')
       
    # Para cada mes de referencia dentro das datas de inicio e fim
    while kwargs['dt_ref'] <= kwargs['dt_fim_ref']:
        
        # Prepara as variaveis do mes de referencia
        kwargs['file_date_ref'] = kwargs['dt_ref'].strftime('%Y')
        kwargs['download_file'] = kwargs['file_name'] + kwargs['file_date_ref'] +  kwargs['file_ext']
        
        # Define a URL completa para download do arquivo
        kwargs['url_query'] = kwargs['download_url'] + kwargs['download_file']
        
        # Define o caminho completo para armazenamento do arquivo de download
        kwargs['download_path'] = kwargs['download_directory'] + kwargs['download_file']
        
        # Inicia o download do arquivo
        download_file(**kwargs)
        
        # Atualiza o ano de refencia
        kwargs['dt_ref'] += relativedelta(years=1)
    
    # Log: Mensagem de inicio da remocao de arquivos nao relacionados com os dados
    print(str(datetime.now()) + ': Verificando a existencia de arquivos nao relacionados com os dados.')
    
    # Remove arquivos nao relacionados com os dados (Ex.: leiame.pdf)
    downloaded_files = os.listdir(kwargs['download_directory'])
    unrelated_files = [file for file in downloaded_files if file.endswith('.pdf')]
    for file in unrelated_files:
        file_to_remove = os.path.join(kwargs['download_directory'], file)
        os.remove(file_to_remove)
        
        # Log: Mensagem de remocao de arquivo nao relacionado com os dados
        print(str(datetime.now()) + ': Arquivo ' + file_to_remove + ' removido.')
        
    # Log: Mensagem de fim da remocao de arquivos nao relacionados com os dados
    print(str(datetime.now()) + ': Remocao dos arquivos nao relacionados com os dados concluida.')

    # Log: Mensagem de finalizacao do processo 
    print(str(datetime.now()) + ': Coleta dos arquivos finalizada.')

# %%
def main():
    """
    Coleta os dados do perfil do eleitorado nas eleicoes. 
    Origem: Tribunal Superior Eleitoral (TSE)
    """
    
    # Prepara o dicionario de variaveis (kwargs = keyworded arguments)
    kwargs = {}
    
    # Datas de Inicio e Fim (YYYY-MM-DD) 
    # Obs.: Dados disponiveis a partir de 1994-01-01
    kwargs['dt_ini_ref'] = datetime.strptime('1994-01-01', "%Y-%m-%d")
    kwargs['dt_fim_ref'] = datetime.strptime('2020-01-01', "%Y-%m-%d")
    
    # Coleta os arquivos
    collect_data(**kwargs)

if __name__ == '__main__':
    main()
# Out:
# 2020-08-11 11:04:58.294474: Criacao dos diretorios para armazenamento dos dados iniciada.
# 2020-08-11 11:04:58.294474: Diretorio ..\data\01-collected ja existe.
# 2020-08-11 11:04:58.295482: Diretorio ..\data\02-cleaned ja existe.
# 2020-08-11 11:04:58.296465: Diretorio ..\data\03-organized ja existe.
# 2020-08-11 11:04:58.296465: Diretorio ..\data\04-standardized ja existe.
# 2020-08-11 11:04:58.297470: Criacao dos diretorios para armazenamento dos dados finalizada.
# 2020-08-11 11:04:58.297470: Coleta dos arquivos iniciada.
# 2020-08-11 11:04:58.298461: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_1994.zip
# 2020-08-11 11:04:58.560801: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_1994.zip
# 2020-08-11 11:04:58.978867: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_1994.zip
# 2020-08-11 11:04:59.047279: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_1994.zip
# 2020-08-11 11:04:59.048275: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_1995.zip
# 2020-08-11 11:04:59.135759: Nao foram encontrados arquivos referentes ao ano de 1995
# 2020-08-11 11:04:59.136758: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_1996.zip
# 2020-08-11 11:04:59.227140: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_1996.zip
# 2020-08-11 11:04:59.652230: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_1996.zip
# 2020-08-11 11:04:59.707117: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_1996.zip
# 2020-08-11 11:04:59.708080: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_1997.zip
# 2020-08-11 11:04:59.795867: Nao foram encontrados arquivos referentes ao ano de 1997
# 2020-08-11 11:04:59.796865: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_1998.zip
# 2020-08-11 11:04:59.895334: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_1998.zip
# 2020-08-11 11:05:00.320609: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_1998.zip
# 2020-08-11 11:05:00.385434: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_1998.zip
# 2020-08-11 11:05:00.385434: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_1999.zip
# 2020-08-11 11:05:00.489159: Nao foram encontrados arquivos referentes ao ano de 1999
# 2020-08-11 11:05:00.490154: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2000.zip
# 2020-08-11 11:05:00.591396: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2000.zip
# 2020-08-11 11:05:02.452562: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2000.zip
# 2020-08-11 11:05:02.835996: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2000.zip
# 2020-08-11 11:05:02.835996: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2001.zip
# 2020-08-11 11:05:02.927266: Nao foram encontrados arquivos referentes ao ano de 2001
# 2020-08-11 11:05:02.928261: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2002.zip
# 2020-08-11 11:05:03.022523: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2002.zip
# 2020-08-11 11:05:04.786668: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2002.zip
# 2020-08-11 11:05:05.136299: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2002.zip
# 2020-08-11 11:05:05.137331: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2003.zip
# 2020-08-11 11:05:05.244607: Nao foram encontrados arquivos referentes ao ano de 2003
# 2020-08-11 11:05:05.245568: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2004.zip
# 2020-08-11 11:05:05.347808: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2004.zip
# 2020-08-11 11:05:07.021882: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2004.zip
# 2020-08-11 11:05:07.388367: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2004.zip
# 2020-08-11 11:05:07.389366: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2005.zip
# 2020-08-11 11:05:07.490101: Nao foram encontrados arquivos referentes ao ano de 2005
# 2020-08-11 11:05:07.490101: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2006.zip
# 2020-08-11 11:05:07.578343: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2006.zip
# 2020-08-11 11:05:09.303149: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2006.zip
# 2020-08-11 11:05:09.742532: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2006.zip
# 2020-08-11 11:05:09.742532: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2007.zip
# 2020-08-11 11:05:09.849791: Nao foram encontrados arquivos referentes ao ano de 2007
# 2020-08-11 11:05:09.850786: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2008.zip
# 2020-08-11 11:05:09.940515: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2008.zip
# 2020-08-11 11:05:11.756953: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2008.zip
# 2020-08-11 11:05:12.232601: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2008.zip
# 2020-08-11 11:05:12.233600: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2009.zip
# 2020-08-11 11:05:12.337319: Nao foram encontrados arquivos referentes ao ano de 2009
# 2020-08-11 11:05:12.337319: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2010.zip
# 2020-08-11 11:05:12.436055: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2010.zip
# 2020-08-11 11:05:14.833028: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2010.zip
# 2020-08-11 11:05:15.494800: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2010.zip
# 2020-08-11 11:05:15.495797: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2011.zip
# 2020-08-11 11:05:15.585563: Nao foram encontrados arquivos referentes ao ano de 2011
# 2020-08-11 11:05:15.585563: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2012.zip
# 2020-08-11 11:05:15.677819: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2012.zip
# 2020-08-11 11:05:24.198911: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2012.zip
# 2020-08-11 11:05:27.800956: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2012.zip
# 2020-08-11 11:05:27.801955: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2013.zip
# 2020-08-11 11:05:27.920664: Nao foram encontrados arquivos referentes ao ano de 2013
# 2020-08-11 11:05:27.920664: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2014.zip
# 2020-08-11 11:05:28.008402: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2014.zip
# 2020-08-11 11:05:29.764171: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2014.zip
# 2020-08-11 11:05:30.097452: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2014.zip
# 2020-08-11 11:05:30.097452: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2015.zip
# 2020-08-11 11:05:30.188813: Nao foram encontrados arquivos referentes ao ano de 2015
# 2020-08-11 11:05:30.188813: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2016.zip
# 2020-08-11 11:05:30.288544: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2016.zip
# 2020-08-11 11:05:32.185483: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2016.zip
# 2020-08-11 11:05:32.546183: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2016.zip
# 2020-08-11 11:05:32.547168: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2017.zip
# 2020-08-11 11:05:32.639942: Nao foram encontrados arquivos referentes ao ano de 2017
# 2020-08-11 11:05:32.640917: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2018.zip
# 2020-08-11 11:05:32.741168: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2018.zip
# 2020-08-11 11:05:45.682755: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2018.zip
# 2020-08-11 11:05:49.817299: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2018.zip
# 2020-08-11 11:05:49.817299: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2019.zip
# 2020-08-11 11:05:49.931948: Nao foram encontrados arquivos referentes ao ano de 2019
# 2020-08-11 11:05:49.931948: Inicio do download do arquivo ..\data\01-collected\perfil_eleitorado_2020.zip
# 2020-08-11 11:05:50.023671: URL encontrada, fazendo o download do arquivo: ..\data\01-collected\perfil_eleitorado_2020.zip
# 2020-08-11 11:06:01.415910: Descompactando o arquivo ..\data\01-collected\perfil_eleitorado_2020.zip
# 2020-08-11 11:06:06.148704: Fim do download do arquivo ..\data\01-collected\perfil_eleitorado_2020.zip
# 2020-08-11 11:06:06.149700: Verificando a existencia de arquivos nao relacionados com os dados.
# 2020-08-11 11:06:06.151698: Arquivo ..\data\01-collected\LEIAME.pdf removido.
# 2020-08-11 11:06:06.152700: Remocao dos arquivos nao relacionados com os dados concluida.
# 2020-08-11 11:06:06.152700: Coleta dos arquivos finalizada.
