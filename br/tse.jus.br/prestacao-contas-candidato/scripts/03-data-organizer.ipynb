# %%
import os
import codecs
from datetime import datetime

# %%
def join_lines(**kwargs):
    """
    Le o arquivo de entrada, caso algum dos registros tenha quantidade de colunas diferente
    do cabecalho, a linha seguinte e concatenada com a atual e escrita no arquivo de saida.
    """
    
    # Log: Mensagem de inicio da verificacao dos registros
    print(str(datetime.now()) + ': Verificando registros do arquivo ' + kwargs['data_file'])
    
    # Le o arquivo de entrada
    with codecs.open(kwargs['in_data_path'], 'r', encoding = 'utf-8') as reader:
        
        # Prepara o arquivo de saida
        with codecs.open(kwargs['out_data_path'], 'w', encoding = 'utf-8') as writer:
            
            # Armazena o header do arquivo de entrada
            header = reader.readline()
            
            # Conta a quantidade de colunas no header
            qt_columns = header.count('\";\"')
            
            # Define os contadores
            qt_lines = 0
            qt_joins = 0
            
            # Escreve o cabecalho no arquivo de saida
            writer.write(header)
            
            # Para cada linha no arquivo de entrada
            for line in reader:
                
                # Escreve o registro do arquivo de entrada no arquivo de saida 
                # Caso o registro tenha quantidade de colunas diferente do cabecalho
                # a linha seguinte e concatenada com a atual
                if line.count('\";\"') != qt_columns:
                    qt_joins += 1
                    writer.write(line.replace("\r\n", "") + reader.readline())
                else:
                    qt_lines += 1
                    writer.write(line)
                    
    # Log: Resultado da verificacao dos registros
    print(str(datetime.now()) + ': Resultado: Normais = ' + str(qt_lines) + ' - Corrigidas = ' + str(qt_joins))

# %%
def organize_files():
    """
    Para cada arquivo de origem, e verificado se a quantidade de colunas de cada registro corresponde
    com a quantidade de colunas do cabecalho do arquivo.        
    """
    
    # Prepara o dicionario de variaveis (kwargs = keyworded arguments)
    kwargs = {}
    
    # Diretorio de armazenamento dos arquivos originais
    kwargs['in_data_dir'] = '..\\data\\02-cleaned'
    
    # Diretorio de armazenamento dos arquivos tratados
    kwargs['out_data_dir'] = '..\\data\\03-organized'
    
    # Lista dos arquivos originais 
    kwargs['data_files'] = os.listdir(kwargs['in_data_dir'])
    
    # Log: Mensagem de inicio do processo 
    print(str(datetime.now()) + ': Organizacao dos arquivos iniciada.')
    
    # Para cada arquivo na lista de arquivos originais
    for file in kwargs['data_files']:
        
        # Define o caminho completo de acesso e escrita dos arquivos
        kwargs['data_file'] = file
        kwargs['in_data_path'] = os.path.join(kwargs['in_data_dir'], kwargs['data_file'])
        kwargs['out_data_path'] = os.path.join(kwargs['out_data_dir'], kwargs['data_file'])
        
        # Corrige registros com menos colunas que o esperado
        join_lines(**kwargs)
      
    # Log: Mensagem de finalizacao do processo de limpeza
    print(str(datetime.now()) + ': Organizacao dos arquivos finalizada.')

# %%
def main():
    """
    Organiza os dados de prestacao de contas por candidato. 
    Origem: Tribunal Superior Eleitoral (TSE)
    """
    
    ### Organiza os arquivos
    organize_files()

if __name__ == '__main__':
    main()
# Out:
# 2021-11-15 18:35:27.666510: Organizacao dos arquivos iniciada.
# 2021-11-15 18:35:27.666510: Verificando registros do arquivo despesas_contratadas_candidatos_2020_AC.csv
# 2021-11-15 18:35:27.926884: Resultado: Normais = 13394 - Corrigidas = 0
# 2021-11-15 18:35:27.926884: Verificando registros do arquivo despesas_contratadas_candidatos_2020_AL.csv
# 2021-11-15 18:35:29.095489: Resultado: Normais = 66375 - Corrigidas = 0
# 2021-11-15 18:35:29.095489: Verificando registros do arquivo despesas_contratadas_candidatos_2020_AM.csv
# 2021-11-15 18:35:30.242479: Resultado: Normais = 67660 - Corrigidas = 0
# 2021-11-15 18:35:30.242479: Verificando registros do arquivo despesas_contratadas_candidatos_2020_AP.csv
# 2021-11-15 18:35:30.554579: Resultado: Normais = 16322 - Corrigidas = 0
# 2021-11-15 18:35:30.554579: Verificando registros do arquivo despesas_contratadas_candidatos_2020_BA.csv
# 2021-11-15 18:35:34.226976: Resultado: Normais = 213707 - Corrigidas = 0
# 2021-11-15 18:35:34.227973: Verificando registros do arquivo despesas_contratadas_candidatos_2020_BRASIL.csv
# 2021-11-15 18:36:41.339558: Resultado: Normais = 3860105 - Corrigidas = 0
# 2021-11-15 18:36:41.339558: Verificando registros do arquivo despesas_contratadas_candidatos_2020_CE.csv
# 2021-11-15 18:36:43.601375: Resultado: Normais = 129414 - Corrigidas = 0
# 2021-11-15 18:36:43.601375: Verificando registros do arquivo despesas_contratadas_candidatos_2020_ES.csv
# 2021-11-15 18:36:44.930709: Resultado: Normais = 76859 - Corrigidas = 0
# 2021-11-15 18:36:44.931656: Verificando registros do arquivo despesas_contratadas_candidatos_2020_GO.csv
# 2021-11-15 18:36:48.623614: Resultado: Normais = 222424 - Corrigidas = 0
# 2021-11-15 18:36:48.623614: Verificando registros do arquivo despesas_contratadas_candidatos_2020_MA.csv
# 2021-11-15 18:36:50.450423: Resultado: Normais = 106282 - Corrigidas = 0
# 2021-11-15 18:36:50.450423: Verificando registros do arquivo despesas_contratadas_candidatos_2020_MG.csv
# 2021-11-15 18:36:59.365918: Resultado: Normais = 526994 - Corrigidas = 0
# 2021-11-15 18:36:59.366892: Verificando registros do arquivo despesas_contratadas_candidatos_2020_MS.csv
# 2021-11-15 18:37:00.973467: Resultado: Normais = 89110 - Corrigidas = 0
# 2021-11-15 18:37:00.973467: Verificando registros do arquivo despesas_contratadas_candidatos_2020_MT.csv
# 2021-11-15 18:37:03.293695: Resultado: Normais = 138270 - Corrigidas = 0
# 2021-11-15 18:37:03.293695: Verificando registros do arquivo despesas_contratadas_candidatos_2020_PA.csv
# 2021-11-15 18:37:05.509564: Resultado: Normais = 125360 - Corrigidas = 0
# 2021-11-15 18:37:05.509564: Verificando registros do arquivo despesas_contratadas_candidatos_2020_PB.csv
# 2021-11-15 18:37:06.823983: Resultado: Normais = 75909 - Corrigidas = 0
# 2021-11-15 18:37:06.823983: Verificando registros do arquivo despesas_contratadas_candidatos_2020_PE.csv
# 2021-11-15 18:37:09.141527: Resultado: Normais = 131802 - Corrigidas = 0
# 2021-11-15 18:37:09.141527: Verificando registros do arquivo despesas_contratadas_candidatos_2020_PI.csv
# 2021-11-15 18:37:10.644715: Resultado: Normais = 88069 - Corrigidas = 0
# 2021-11-15 18:37:10.644715: Verificando registros do arquivo despesas_contratadas_candidatos_2020_PR.csv
# 2021-11-15 18:37:14.898090: Resultado: Normais = 250915 - Corrigidas = 0
# 2021-11-15 18:37:14.898090: Verificando registros do arquivo despesas_contratadas_candidatos_2020_RJ.csv
# 2021-11-15 18:37:18.877662: Resultado: Normais = 230051 - Corrigidas = 0
# 2021-11-15 18:37:18.877662: Verificando registros do arquivo despesas_contratadas_candidatos_2020_RN.csv
# 2021-11-15 18:37:20.315459: Resultado: Normais = 83594 - Corrigidas = 0
# 2021-11-15 18:37:20.315459: Verificando registros do arquivo despesas_contratadas_candidatos_2020_RO.csv
# 2021-11-15 18:37:21.070043: Resultado: Normais = 45707 - Corrigidas = 0
# 2021-11-15 18:37:21.071028: Verificando registros do arquivo despesas_contratadas_candidatos_2020_RR.csv
# 2021-11-15 18:37:21.519802: Resultado: Normais = 23451 - Corrigidas = 0
# 2021-11-15 18:37:21.519802: Verificando registros do arquivo despesas_contratadas_candidatos_2020_RS.csv
# 2021-11-15 18:37:28.950034: Resultado: Normais = 272904 - Corrigidas = 0
# 2021-11-15 18:37:28.950034: Verificando registros do arquivo despesas_contratadas_candidatos_2020_SC.csv
# 2021-11-15 18:37:32.161518: Resultado: Normais = 160197 - Corrigidas = 0
# 2021-11-15 18:37:32.161518: Verificando registros do arquivo despesas_contratadas_candidatos_2020_SE.csv
# 2021-11-15 18:37:33.099830: Resultado: Normais = 42465 - Corrigidas = 0
# 2021-11-15 18:37:33.099830: Verificando registros do arquivo despesas_contratadas_candidatos_2020_SP.csv
# 2021-11-15 18:37:46.285468: Resultado: Normais = 579870 - Corrigidas = 0
# 2021-11-15 18:37:46.286475: Verificando registros do arquivo despesas_contratadas_candidatos_2020_TO.csv
# 2021-11-15 18:37:47.687576: Resultado: Normais = 83000 - Corrigidas = 0
# 2021-11-15 18:37:47.687576: Verificando registros do arquivo despesas_pagas_candidatos_2020_AC.csv
# 2021-11-15 18:37:47.835446: Resultado: Normais = 11701 - Corrigidas = 0
# 2021-11-15 18:37:47.835446: Verificando registros do arquivo despesas_pagas_candidatos_2020_AL.csv
# 2021-11-15 18:37:48.454596: Resultado: Normais = 54085 - Corrigidas = 0
# 2021-11-15 18:37:48.454596: Verificando registros do arquivo despesas_pagas_candidatos_2020_AM.csv
# 2021-11-15 18:37:49.870848: Resultado: Normais = 55923 - Corrigidas = 0
# 2021-11-15 18:37:49.870848: Verificando registros do arquivo despesas_pagas_candidatos_2020_AP.csv
# 2021-11-15 18:37:50.448224: Resultado: Normais = 12858 - Corrigidas = 0
# 2021-11-15 18:37:50.448224: Verificando registros do arquivo despesas_pagas_candidatos_2020_BA.csv
# 2021-11-15 18:37:53.256218: Resultado: Normais = 145978 - Corrigidas = 0
# 2021-11-15 18:37:53.256218: Verificando registros do arquivo despesas_pagas_candidatos_2020_BRASIL.csv
# 2021-11-15 18:38:36.345127: Resultado: Normais = 3046059 - Corrigidas = 0
# 2021-11-15 18:38:36.345127: Verificando registros do arquivo despesas_pagas_candidatos_2020_CE.csv
# 2021-11-15 18:38:37.493761: Resultado: Normais = 103614 - Corrigidas = 0
# 2021-11-15 18:38:37.493761: Verificando registros do arquivo despesas_pagas_candidatos_2020_ES.csv
# 2021-11-15 18:38:38.150779: Resultado: Normais = 53281 - Corrigidas = 0
# 2021-11-15 18:38:38.150779: Verificando registros do arquivo despesas_pagas_candidatos_2020_GO.csv
# 2021-11-15 18:38:40.007425: Resultado: Normais = 163110 - Corrigidas = 0
# 2021-11-15 18:38:40.007425: Verificando registros do arquivo despesas_pagas_candidatos_2020_MA.csv
# 2021-11-15 18:38:40.976195: Resultado: Normais = 79280 - Corrigidas = 0
# 2021-11-15 18:38:40.976195: Verificando registros do arquivo despesas_pagas_candidatos_2020_MG.csv
# 2021-11-15 18:38:48.388120: Resultado: Normais = 422028 - Corrigidas = 0
# 2021-11-15 18:38:48.388120: Verificando registros do arquivo despesas_pagas_candidatos_2020_MS.csv
# 2021-11-15 18:38:49.536318: Resultado: Normais = 87906 - Corrigidas = 0
# 2021-11-15 18:38:49.537348: Verificando registros do arquivo despesas_pagas_candidatos_2020_MT.csv
# 2021-11-15 18:38:51.084365: Resultado: Normais = 114248 - Corrigidas = 0
# 2021-11-15 18:38:51.085366: Verificando registros do arquivo despesas_pagas_candidatos_2020_PA.csv
# 2021-11-15 18:38:52.273401: Resultado: Normais = 89405 - Corrigidas = 0
# 2021-11-15 18:38:52.274381: Verificando registros do arquivo despesas_pagas_candidatos_2020_PB.csv
# 2021-11-15 18:38:53.081814: Resultado: Normais = 49495 - Corrigidas = 0
# 2021-11-15 18:38:53.081814: Verificando registros do arquivo despesas_pagas_candidatos_2020_PE.csv
# 2021-11-15 18:38:54.300299: Resultado: Normais = 99453 - Corrigidas = 0
# 2021-11-15 18:38:54.300299: Verificando registros do arquivo despesas_pagas_candidatos_2020_PI.csv
# 2021-11-15 18:38:55.006029: Resultado: Normais = 63491 - Corrigidas = 0
# 2021-11-15 18:38:55.006029: Verificando registros do arquivo despesas_pagas_candidatos_2020_PR.csv
# 2021-11-15 18:38:59.905066: Resultado: Normais = 206402 - Corrigidas = 0
# 2021-11-15 18:38:59.905066: Verificando registros do arquivo despesas_pagas_candidatos_2020_RJ.csv
# 2021-11-15 18:39:02.398435: Resultado: Normais = 187565 - Corrigidas = 0
# 2021-11-15 18:39:02.399399: Verificando registros do arquivo despesas_pagas_candidatos_2020_RN.csv
# 2021-11-15 18:39:03.041823: Resultado: Normais = 56962 - Corrigidas = 0
# 2021-11-15 18:39:03.041823: Verificando registros do arquivo despesas_pagas_candidatos_2020_RO.csv
# 2021-11-15 18:39:03.647824: Resultado: Normais = 35646 - Corrigidas = 0
# 2021-11-15 18:39:03.647824: Verificando registros do arquivo despesas_pagas_candidatos_2020_RR.csv
# 2021-11-15 18:39:03.933019: Resultado: Normais = 23135 - Corrigidas = 0
# 2021-11-15 18:39:03.933019: Verificando registros do arquivo despesas_pagas_candidatos_2020_RS.csv
# 2021-11-15 18:39:06.914148: Resultado: Normais = 223655 - Corrigidas = 0
# 2021-11-15 18:39:06.914148: Verificando registros do arquivo despesas_pagas_candidatos_2020_SC.csv
# 2021-11-15 18:39:08.372428: Resultado: Normais = 127297 - Corrigidas = 0
# 2021-11-15 18:39:08.372428: Verificando registros do arquivo despesas_pagas_candidatos_2020_SE.csv
# 2021-11-15 18:39:08.768999: Resultado: Normais = 32549 - Corrigidas = 0
# 2021-11-15 18:39:08.768999: Verificando registros do arquivo despesas_pagas_candidatos_2020_SP.csv
# 2021-11-15 18:39:17.375677: Resultado: Normais = 473516 - Corrigidas = 0
# 2021-11-15 18:39:17.375677: Verificando registros do arquivo despesas_pagas_candidatos_2020_TO.csv
# 2021-11-15 18:39:18.461579: Resultado: Normais = 73476 - Corrigidas = 0
# 2021-11-15 18:39:18.461579: Verificando registros do arquivo receitas_candidatos_2020_AC.csv
# 2021-11-15 18:39:18.814016: Resultado: Normais = 17284 - Corrigidas = 0
# 2021-11-15 18:39:18.814016: Verificando registros do arquivo receitas_candidatos_2020_AL.csv
# 2021-11-15 18:39:19.449317: Resultado: Normais = 22941 - Corrigidas = 0
# 2021-11-15 18:39:19.449317: Verificando registros do arquivo receitas_candidatos_2020_AM.csv
# 2021-11-15 18:39:20.155350: Resultado: Normais = 38293 - Corrigidas = 0
# 2021-11-15 18:39:20.155350: Verificando registros do arquivo receitas_candidatos_2020_AP.csv
# 2021-11-15 18:39:20.295939: Resultado: Normais = 6815 - Corrigidas = 0
# 2021-11-15 18:39:20.295939: Verificando registros do arquivo receitas_candidatos_2020_BA.csv
# 2021-11-15 18:39:22.504680: Resultado: Normais = 121160 - Corrigidas = 0
# 2021-11-15 18:39:22.505643: Verificando registros do arquivo receitas_candidatos_2020_BRASIL.csv
# 2021-11-15 18:40:17.512540: Resultado: Normais = 2235329 - Corrigidas = 0
# 2021-11-15 18:40:17.513488: Verificando registros do arquivo receitas_candidatos_2020_CE.csv
# 2021-11-15 18:40:18.738541: Resultado: Normais = 53053 - Corrigidas = 0
# 2021-11-15 18:40:18.738541: Verificando registros do arquivo receitas_candidatos_2020_ES.csv
# 2021-11-15 18:40:19.968882: Resultado: Normais = 59136 - Corrigidas = 0
# 2021-11-15 18:40:19.969880: Verificando registros do arquivo receitas_candidatos_2020_GO.csv
# 2021-11-15 18:40:22.542892: Resultado: Normais = 129400 - Corrigidas = 0
# 2021-11-15 18:40:22.542892: Verificando registros do arquivo receitas_candidatos_2020_MA.csv
# 2021-11-15 18:40:25.283412: Resultado: Normais = 45218 - Corrigidas = 0
# 2021-11-15 18:40:25.283412: Verificando registros do arquivo receitas_candidatos_2020_MG.csv
# 2021-11-15 18:40:33.386286: Resultado: Normais = 372053 - Corrigidas = 0
# 2021-11-15 18:40:33.386286: Verificando registros do arquivo receitas_candidatos_2020_MS.csv
# 2021-11-15 18:40:33.930650: Resultado: Normais = 31925 - Corrigidas = 0
# 2021-11-15 18:40:33.930650: Verificando registros do arquivo receitas_candidatos_2020_MT.csv
# 2021-11-15 18:40:35.281383: Resultado: Normais = 75581 - Corrigidas = 0
# 2021-11-15 18:40:35.281383: Verificando registros do arquivo receitas_candidatos_2020_PA.csv
# 2021-11-15 18:40:36.839677: Resultado: Normais = 89168 - Corrigidas = 0
# 2021-11-15 18:40:36.840690: Verificando registros do arquivo receitas_candidatos_2020_PB.csv
# 2021-11-15 18:40:39.276816: Resultado: Normais = 37673 - Corrigidas = 0
# 2021-11-15 18:40:39.276816: Verificando registros do arquivo receitas_candidatos_2020_PE.csv
# 2021-11-15 18:40:40.810094: Resultado: Normais = 58929 - Corrigidas = 0
# 2021-11-15 18:40:40.810094: Verificando registros do arquivo receitas_candidatos_2020_PI.csv
# 2021-11-15 18:40:41.715555: Resultado: Normais = 41665 - Corrigidas = 0
# 2021-11-15 18:40:41.716553: Verificando registros do arquivo receitas_candidatos_2020_PR.csv
# 2021-11-15 18:40:45.044571: Resultado: Normais = 172700 - Corrigidas = 0
# 2021-11-15 18:40:45.045574: Verificando registros do arquivo receitas_candidatos_2020_RJ.csv
# 2021-11-15 18:40:47.470301: Resultado: Normais = 111829 - Corrigidas = 0
# 2021-11-15 18:40:47.470301: Verificando registros do arquivo receitas_candidatos_2020_RN.csv
# 2021-11-15 18:40:48.161985: Resultado: Normais = 36783 - Corrigidas = 0
# 2021-11-15 18:40:48.161985: Verificando registros do arquivo receitas_candidatos_2020_RO.csv
# 2021-11-15 18:40:48.610519: Resultado: Normais = 26901 - Corrigidas = 0
# 2021-11-15 18:40:48.610519: Verificando registros do arquivo receitas_candidatos_2020_RR.csv
# 2021-11-15 18:40:48.728433: Resultado: Normais = 6002 - Corrigidas = 0
# 2021-11-15 18:40:48.728433: Verificando registros do arquivo receitas_candidatos_2020_RS.csv
# 2021-11-15 18:40:53.793974: Resultado: Normais = 157697 - Corrigidas = 0
# 2021-11-15 18:40:53.793974: Verificando registros do arquivo receitas_candidatos_2020_SC.csv
# 2021-11-15 18:40:55.798754: Resultado: Normais = 104027 - Corrigidas = 0
# 2021-11-15 18:40:55.798754: Verificando registros do arquivo receitas_candidatos_2020_SE.csv
# 2021-11-15 18:40:56.378944: Resultado: Normais = 23902 - Corrigidas = 0
# 2021-11-15 18:40:56.378944: Verificando registros do arquivo receitas_candidatos_2020_SP.csv
# 2021-11-15 18:41:06.000677: Resultado: Normais = 358612 - Corrigidas = 0
# 2021-11-15 18:41:06.000677: Verificando registros do arquivo receitas_candidatos_2020_TO.csv
# 2021-11-15 18:41:06.651889: Resultado: Normais = 36582 - Corrigidas = 0
# 2021-11-15 18:41:06.651889: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_AC.csv
# 2021-11-15 18:41:06.658906: Resultado: Normais = 100 - Corrigidas = 0
# 2021-11-15 18:41:06.658906: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_AL.csv
# 2021-11-15 18:41:06.670065: Resultado: Normais = 430 - Corrigidas = 0
# 2021-11-15 18:41:06.670065: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_AM.csv
# 2021-11-15 18:41:06.683322: Resultado: Normais = 513 - Corrigidas = 0
# 2021-11-15 18:41:06.683322: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_AP.csv
# 2021-11-15 18:41:06.688310: Resultado: Normais = 24 - Corrigidas = 0
# 2021-11-15 18:41:06.688310: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_BA.csv
# 2021-11-15 18:41:06.729918: Resultado: Normais = 3277 - Corrigidas = 0
# 2021-11-15 18:41:06.729918: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_BRASIL.csv
# 2021-11-15 18:41:08.627168: Resultado: Normais = 144716 - Corrigidas = 0
# 2021-11-15 18:41:08.627168: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_CE.csv
# 2021-11-15 18:41:08.668397: Resultado: Normais = 3274 - Corrigidas = 0
# 2021-11-15 18:41:08.669394: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_ES.csv
# 2021-11-15 18:41:08.693644: Resultado: Normais = 1875 - Corrigidas = 0
# 2021-11-15 18:41:08.693644: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_GO.csv
# 2021-11-15 18:41:08.732580: Resultado: Normais = 2937 - Corrigidas = 0
# 2021-11-15 18:41:08.732580: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_MA.csv
# 2021-11-15 18:41:08.741862: Resultado: Normais = 449 - Corrigidas = 0
# 2021-11-15 18:41:08.741862: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_MG.csv
# 2021-11-15 18:41:08.851682: Resultado: Normais = 9371 - Corrigidas = 0
# 2021-11-15 18:41:08.851682: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_MS.csv
# 2021-11-15 18:41:08.906293: Resultado: Normais = 2077 - Corrigidas = 0
# 2021-11-15 18:41:08.906293: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_MT.csv
# 2021-11-15 18:41:08.942262: Resultado: Normais = 2897 - Corrigidas = 0
# 2021-11-15 18:41:08.942262: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_PA.csv
# 2021-11-15 18:41:08.964225: Resultado: Normais = 1267 - Corrigidas = 0
# 2021-11-15 18:41:08.964225: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_PB.csv
# 2021-11-15 18:41:08.976928: Resultado: Normais = 547 - Corrigidas = 0
# 2021-11-15 18:41:08.976928: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_PE.csv
# 2021-11-15 18:41:09.015578: Resultado: Normais = 2902 - Corrigidas = 0
# 2021-11-15 18:41:09.015578: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_PI.csv
# 2021-11-15 18:41:09.027548: Resultado: Normais = 488 - Corrigidas = 0
# 2021-11-15 18:41:09.027548: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_PR.csv
# 2021-11-15 18:41:09.087580: Resultado: Normais = 4840 - Corrigidas = 0
# 2021-11-15 18:41:09.087580: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_RJ.csv
# 2021-11-15 18:41:09.209265: Resultado: Normais = 9995 - Corrigidas = 0
# 2021-11-15 18:41:09.209265: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_RN.csv
# 2021-11-15 18:41:09.254390: Resultado: Normais = 791 - Corrigidas = 0
# 2021-11-15 18:41:09.254390: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_RO.csv
# 2021-11-15 18:41:09.265527: Resultado: Normais = 511 - Corrigidas = 0
# 2021-11-15 18:41:09.266535: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_RR.csv
# 2021-11-15 18:41:09.272509: Resultado: Normais = 34 - Corrigidas = 0
# 2021-11-15 18:41:09.272509: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_RS.csv
# 2021-11-15 18:41:09.492980: Resultado: Normais = 19951 - Corrigidas = 0
# 2021-11-15 18:41:09.492980: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_SC.csv
# 2021-11-15 18:41:09.604201: Resultado: Normais = 7451 - Corrigidas = 0
# 2021-11-15 18:41:09.604201: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_SE.csv
# 2021-11-15 18:41:09.669036: Resultado: Normais = 465 - Corrigidas = 0
# 2021-11-15 18:41:09.669036: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_SP.csv
# 2021-11-15 18:41:10.545502: Resultado: Normais = 67756 - Corrigidas = 0
# 2021-11-15 18:41:10.545502: Verificando registros do arquivo receitas_candidatos_doador_originario_2020_TO.csv
# 2021-11-15 18:41:10.556507: Resultado: Normais = 494 - Corrigidas = 0
# 2021-11-15 18:41:10.556507: Organizacao dos arquivos finalizada.
